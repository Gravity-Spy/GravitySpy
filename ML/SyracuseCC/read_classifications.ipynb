# %%
### Import standard functions ###
import os, time, csv, optparse
import numpy as np
from pylab import *
import json
import pandas as pd

# %%
#####################################
### Define command line arguments ###
#####################################
def parse_commandline():
    parser = optparse.OptionParser()
    parser.add_option("--file", help="Type in the path to the csv file \
    containing the classifications from the vet training set \
    workflow",default="example.csv")
    
    opts, args = parser.parse_args()
    
    return opts

#opts = parse_commandline()
class_file = "gravity-spy-classifications.csv"

# %%
### READ IN DATA ###
data = pd.read_csv(class_file, skiprows=29573, nrows=20008) # This starts with Beta 2.0
data = np.asarray(data)

# %%
### APPEND ALL PERTINENT DATA TO LIST ###

tmp_user= []
tmp_user_id = []
tmp_workflow = []
tmp_task = []
tmp_choice = []
tmp_retired = []
tmp_unique_id = []
for i in range(len(data)):
    # create list to hold to output information of each classification
    output = []
    # Check that there was only 1 choice made...
    annotations = json.loads(data[i][11])
    idcheck = data[i][2]
    if str(annotations).count('choice') == 1 and not np.isnan(idcheck):
        user = data[i,1]
        user_id = data[i,2]
        workflow = data[i,5]
        
        # annotations
        task = annotations[0]["task"]
        choice = annotations[0]["value"][0]["choice"]
        
        # subject data
        subject_data = json.loads(data[i][12])
        for key in subject_data:
            zoo_id = key
            retired = subject_data[key]['retired']
            unique_id = subject_data[key]['subject_id']
        
        # Append this information into a temporary output file
        tmp_user_id.append(user_id)
        tmp_workflow.append(workflow)
        tmp_task.append(task)
        tmp_choice.append(choice)
        tmp_retired.append(retired)
        tmp_unique_id.append(unique_id)
        
# Store each of the classification data
classifications = pd.DataFrame({'imageID':tmp_unique_id,'userID':tmp_user_id,'workflow':tmp_workflow,'task':tmp_task,'label':tmp_choice,'type':tmp_retired})
classifications
# Out:
#           imageID           label task  type   userID  \
# 0      gd5ovM759R             BLP   T1  None   796717
# 1      7cZKPcHEY6             BLP   T1  None   796717
# 2      RvN3cptPEr       PWRLN60HZ   T1  None   796717
# 3      dUjd6wI7A7            KFSH   T1  None   796717
# 4      yBgD8GkFQV             BLP   T1  None   796717
# 5      8S7iCnCoEt             BLP   T1  None   796717
# 6      noDH1uFsHt             BLP   T1  None      123
# 7      zcv28lNmT4             BLP   T1  None      123
# 8      4Pbsza2PMU             BLP   T1  None      123
# 9      PCfcu7enPj            KFSH   T1  None      123
# 10     UrbMmvCAsu       PWRLN60HZ   T1  None      123
# 11     LUZjQW6GWU            KFSH   T1  None      123
# 12     bOug8xBctE            KFSH   T1  None      123
# 13     yHDVjGwiuV             BLP   T1  None      123
# 14     v8L7B9dQ0Y             BLP   T1  None      123
# 15     buHDMm2CTN             BLP   T1  None      123
# 16     R9ymFT9uoA       PWRLN60HZ   T1  None     4284
# 17     fRoPkFs3x0             BLP   T1  None     4284
# 18     pHYHa7ljsH          SCRTCH   T1  None     4284
# 19     0WzSMDFdZR  45MHZLGHTMDLTN   T1  None     4284
# 20     j2xetMMqag  45MHZLGHTMDLTN   T1  None     4284
# 21     ouVpdQVNDl         XTRMLLD   T1  None     4284
# 22     DrgJ06uE6U            KFSH   T1  None     4284
# 23     CtlgK7xjcJ            KFSH   T1  None     4284
# 24     7r2baEJH2n            KFSH   T1  None     4284
# 25     zWyPYTrOkc            KFSH   T1  None     4284
# 26     U0BNebjVF8             BLP   T1  None     4284
# 27     bkB9qm4aI2             BLP   T1  None     4284
# 28     w2db3RDWGS       PWRLN60HZ   T1  None     4284
# 29     ih9XuwKQ7Z       PWRLN60HZ   T1  None     4284
# ...           ...             ...  ...   ...      ...
# 15063  lSt7URga3N             TMT   T1  None       82
# 15064  6ct3spNbQc     LWFRQNCBRST   T1  None       82
# 15065  TxIYLSSF2m     LWFRQNCBRST   T1  None       82
# 15066  W2J3BlDUbS            50HZ   T1  None       82
# 15067  YW8YilC0GD       PWRLN60HZ   T1  None       82
# 15068  reXCm2WM9L     LWFRQNCBRST   T1  None       82
# 15069  XCBuFsHkVE       LWFRQNCLN   T1  None       82
# 15070  IKV0EyYOMi             BLP   T1  None       82
# 15071  qnkjwEKzep       LWFRQNCLN   T1  None       82
# 15072  TCCK87W8ot         NNFTHBV   T1  None       82
# 15073  1N08oYzNoy             BLP   T1  None       82
# 15074  pcVmfFzp4z     LWFRQNCBRST   T1  None       82
# 15075  RjkRT44YNE          NGLTCH   T1  None     5209
# 15076  rr7Xr5oUdk            KFSH   T1  None  1500454
# 15077  xqvqwD3VPr       PWRLN60HZ   T1  None  1500454
# 15078  AAGbIxuAt6             BLP   T1  None  1500454
# 15079  PQ8A98YCxW       PWRLN60HZ   T1  None  1500454
# 15080  lE2NfUNTlU             BLP   T1  None  1500454
# 15081  IIH4yWsm1M         XTRMLLD   T1  None     5209
# 15082  3oRUIeX6Yo             BLP   T1  None  1500454
# 15083  hXtk5iBDjl       PWRLN60HZ   T1  None  1500454
# 15084  zQ2phPnpfe          NGLTCH   T1  None   796717
# 15085  j0xgPFl0E3          NGLTCH   T1  None   796717
# 15086  XBN6g4EMa2         XTRMLLD   T1  None     5209
# 15087  ZjmfidyDgt            KFSH   T1  None  1500454
# 15088  YraWMIbey9             BLP   T1  None  1500454
# 15089  yY4KpfCQIw       LWFRQNCLN   T1  None     2274
# 15090  NUN2yhpvPg     LWFRQNCBRST   T1  None     2274
# 15091  i7kFSq3b2u             HLX   T1  None     2274
# 15092  Nxu3wus6DO     LWFRQNCBRST   T1  None     5209
#
#                                                 workflow
# 0                                             Beginner 3
# 1                                             Beginner 3
# 2                                             Beginner 3
# 3                                             Beginner 3
# 4                                             Beginner 3
# 5                                             Beginner 3
# 6                                             Beginner 3
# 7                                             Beginner 3
# 8                                             Beginner 3
# 9                                             Beginner 3
# 10                                            Beginner 3
# 11                                            Beginner 3
# 12                                            Beginner 3
# 13                                            Beginner 3
# 14                                            Beginner 3
# 15     Apprentice - Jump in here for advanced Glitch ...
# 16     Apprentice - Jump in here for advanced Glitch ...
# 17     Apprentice - Jump in here for advanced Glitch ...
# 18     Apprentice - Jump in here for advanced Glitch ...
# 19     Apprentice - Jump in here for advanced Glitch ...
# 20     Apprentice - Jump in here for advanced Glitch ...
# 21     Apprentice - Jump in here for advanced Glitch ...
# 22     Apprentice - Jump in here for advanced Glitch ...
# 23     Apprentice - Jump in here for advanced Glitch ...
# 24     Apprentice - Jump in here for advanced Glitch ...
# 25     Apprentice - Jump in here for advanced Glitch ...
# 26     Apprentice - Jump in here for advanced Glitch ...
# 27     Apprentice - Jump in here for advanced Glitch ...
# 28     Apprentice - Jump in here for advanced Glitch ...
# 29     Apprentice - Jump in here for advanced Glitch ...
# ...                                                  ...
# 15063  Apprentice - Jump in here for advanced Glitch ...
# 15064  Apprentice - Jump in here for advanced Glitch ...
# 15065  Apprentice - Jump in here for advanced Glitch ...
# 15066  Apprentice - Jump in here for advanced Glitch ...
# 15067  Apprentice - Jump in here for advanced Glitch ...
# 15068  Apprentice - Jump in here for advanced Glitch ...
# 15069  Apprentice - Jump in here for advanced Glitch ...
# 15070  Apprentice - Jump in here for advanced Glitch ...
# 15071  Apprentice - Jump in here for advanced Glitch ...
# 15072  Apprentice - Jump in here for advanced Glitch ...
# 15073  Apprentice - Jump in here for advanced Glitch ...
# 15074  Apprentice - Jump in here for advanced Glitch ...
# 15075  Apprentice - Jump in here for advanced Glitch ...
# 15076                                         Beginner 3
# 15077                                         Beginner 3
# 15078                                         Beginner 3
# 15079                                         Beginner 3
# 15080                                         Beginner 3
# 15081  Apprentice - Jump in here for advanced Glitch ...
# 15082                                         Beginner 3
# 15083                                         Beginner 3
# 15084  Apprentice - Jump in here for advanced Glitch ...
# 15085  Apprentice - Jump in here for advanced Glitch ...
# 15086  Apprentice - Jump in here for advanced Glitch ...
# 15087                                         Beginner 3
# 15088                                         Beginner 3
# 15089  Apprentice - Jump in here for advanced Glitch ...
# 15090  Apprentice - Jump in here for advanced Glitch ...
# 15091  Apprentice - Jump in here for advanced Glitch ...
# 15092  Apprentice - Jump in here for advanced Glitch ...
#
# [15093 rows x 6 columns]

# %%
uniques=np.unique(classifications['imageID'])
len(uniques)
# Out:
# 5460

# %%
np.where(('00LbZLJfCn' == (classifications['imageID'])))
# Out:
# (array([ 1819, 10540, 13533], dtype=int64),)

# %%
images = pd.DataFrame(np.zeros((len(uniques)columns=['type','labels','userIDs','ML_posterior','truelabel','imageID']) #create blank dataframe


for i in classifications: #iterate over classifications
    
    if not(i[6] == images['imageID'].any()): #if imageID is unique
        
        try: #to catch errors from not having userID
            
            line = pd.DataFrame([{'type':'T','labels':i[4],'userIDs':int(i[1]),'ML_posterior':[],'truelabel':-1,'imageID':i[6]}])
            #create line with proper values
            images = images.append(line,ignore_index=True) #append line to images dataframe
       
        except:
            
            pass
    
    else: #if imageID already exists in dataframe
        
        ix = images[images['imageID']==i[6]] #get index of row with corresponding imageID
        
        print(ix)
# Out:
#   File "<ipython-input-128-136e852c82a2>", line 2
#     print images
#                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print(len(np.unique(images['imageID'])))
# Out:
# 5460

# %%
print(images)
# Out:
#       ML_posterior     imageID          labels  truelabel type  userIDs
# 0               []  gd5ovM759R             BLP         -1    T   796717
# 1               []  7cZKPcHEY6             BLP         -1    T   796717
# 2               []  RvN3cptPEr       PWRLN60HZ         -1    T   796717
# 3               []  dUjd6wI7A7            KFSH         -1    T   796717
# 4               []  yBgD8GkFQV             BLP         -1    T   796717
# 5               []  8S7iCnCoEt             BLP         -1    T   796717
# 6               []  noDH1uFsHt             BLP         -1    T      123
# 7               []  zcv28lNmT4             BLP         -1    T      123
# 8               []  4Pbsza2PMU             BLP         -1    T      123
# 9               []  PCfcu7enPj            KFSH         -1    T      123
# 10              []  UrbMmvCAsu       PWRLN60HZ         -1    T      123
# 11              []  LUZjQW6GWU            KFSH         -1    T      123
# 12              []  bOug8xBctE            KFSH         -1    T      123
# 13              []  yHDVjGwiuV             BLP         -1    T      123
# 14              []  v8L7B9dQ0Y             BLP         -1    T      123
# 15              []  buHDMm2CTN             BLP         -1    T      123
# 16              []  R9ymFT9uoA       PWRLN60HZ         -1    T     4284
# 17              []  fRoPkFs3x0             BLP         -1    T     4284
# 18              []  pHYHa7ljsH          SCRTCH         -1    T     4284
# 19              []  0WzSMDFdZR  45MHZLGHTMDLTN         -1    T     4284
# 20              []  j2xetMMqag  45MHZLGHTMDLTN         -1    T     4284
# 21              []  ouVpdQVNDl         XTRMLLD         -1    T     4284
# 22              []  DrgJ06uE6U            KFSH         -1    T     4284
# 23              []  CtlgK7xjcJ            KFSH         -1    T     4284
# 24              []  7r2baEJH2n            KFSH         -1    T     4284
# 25              []  zWyPYTrOkc            KFSH         -1    T     4284
# 26              []  U0BNebjVF8             BLP         -1    T     4284
# 27              []  bkB9qm4aI2             BLP         -1    T     4284
# 28              []  w2db3RDWGS       PWRLN60HZ         -1    T     4284
# 29              []  ih9XuwKQ7Z       PWRLN60HZ         -1    T     4284
# ...            ...         ...             ...        ...  ...      ...
# 15059           []  lSt7URga3N             TMT         -1    T       82
# 15060           []  6ct3spNbQc     LWFRQNCBRST         -1    T       82
# 15061           []  TxIYLSSF2m     LWFRQNCBRST         -1    T       82
# 15062           []  W2J3BlDUbS            50HZ         -1    T       82
# 15063           []  YW8YilC0GD       PWRLN60HZ         -1    T       82
# 15064           []  reXCm2WM9L     LWFRQNCBRST         -1    T       82
# 15065           []  XCBuFsHkVE       LWFRQNCLN         -1    T       82
# 15066           []  IKV0EyYOMi             BLP         -1    T       82
# 15067           []  qnkjwEKzep       LWFRQNCLN         -1    T       82
# 15068           []  TCCK87W8ot         NNFTHBV         -1    T       82
# 15069           []  1N08oYzNoy             BLP         -1    T       82
# 15070           []  pcVmfFzp4z     LWFRQNCBRST         -1    T       82
# 15071           []  RjkRT44YNE          NGLTCH         -1    T     5209
# 15072           []  rr7Xr5oUdk            KFSH         -1    T  1500454
# 15073           []  xqvqwD3VPr       PWRLN60HZ         -1    T  1500454
# 15074           []  AAGbIxuAt6             BLP         -1    T  1500454
# 15075           []  PQ8A98YCxW       PWRLN60HZ         -1    T  1500454
# 15076           []  lE2NfUNTlU             BLP         -1    T  1500454
# 15077           []  IIH4yWsm1M         XTRMLLD         -1    T     5209
# 15078           []  3oRUIeX6Yo             BLP         -1    T  1500454
# 15079           []  hXtk5iBDjl       PWRLN60HZ         -1    T  1500454
# 15080           []  zQ2phPnpfe          NGLTCH         -1    T   796717
# 15081           []  j0xgPFl0E3          NGLTCH         -1    T   796717
# 15082           []  XBN6g4EMa2         XTRMLLD         -1    T     5209
# 15083           []  ZjmfidyDgt            KFSH         -1    T  1500454
# 15084           []  YraWMIbey9             BLP         -1    T  1500454
# 15085           []  yY4KpfCQIw       LWFRQNCLN         -1    T     2274
# 15086           []  NUN2yhpvPg     LWFRQNCBRST         -1    T     2274
# 15087           []  i7kFSq3b2u             HLX         -1    T     2274
# 15088           []  Nxu3wus6DO     LWFRQNCBRST         -1    T     5209
#
# [15089 rows x 6 columns]
