# %%
### Import standard functions ###
import os, time, csv, optparse
import numpy as np
from pylab import *
import json
import pandas as pd

# %%
# Define set of parsing functions
def CustomParser(data):
    j1 = json.loads(data)
    return j1

def filter_json(x):
    x=x[0]
    try:
        x['value']=x['value'][0]
    except:
        x['value'] = {u'answers': {}, u'choice': {}, u'filters': {}}
    return x

def extract_choice(x):
    y = []
    y.append(str(x['value']['choice']))
    return y

def extract_tasks(x):
    x=x['task']
    return x

def extract_answers(x):
    x=x['value']['answers']
    return x

def extract_filters(x):
    x=['value']['filters']
    return x

def extract_zooID(x):
    x=x.keys()[0]
    return x

def extract_FileName1(x):
    try:
        x = x[x.keys()[0]]['Filename1'].split('_')[1]
    except:
        x = []
    return x

def check_upload(x):
    if len(x.split(';')) == 4:
        x = True
    else:
        x = False
    return x

def check_anno(x):
    if len(x) == 1:
        x = True
    else:
        x = False
    return x

def convert_to_int(x):
    try:
        x=int(x)
    except:
        x=False
    return x

# %%
#opts = parse_commandline()
class_file = "gravity-spy-classifications.csv"

# %%
# Reading in csv with custom read for those column in JSON format
data1 = pd.read_csv(class_file,converters={'annotations':CustomParser,'subject_data':CustomParser})

# change ID to int
data1['user_id'] = data1['user_id'].apply(convert_to_int)

# Doing a mild work around for the json format of the annontation column
data1['annotations']    = data1['annotations'].apply(filter_json)
# Extracting choice and making it a column
data1['choice']         = data1['annotations'].apply(extract_choice)
# Extracting the task entry and making it a column
data1['tasks']          = data1['annotations'].apply(extract_tasks)
# Extracting answers and making it a column
data1['answers']        = data1['annotations'].apply(extract_answers)
# Extracting zooniverse ID it gave this subject and making it a column
data1['zooID']          = data1['subject_data'].apply(extract_zooID) 
# Extracting uniqueID assigned to the image during image creation and making it a column
data1['imageID']       = data1['subject_data'].apply(extract_FileName1)
# Making sure that the subject_ids for a given classification is 4. If not I uploaded the images wrong
# for that subject
data1['goodUpload']     = data1['subject_ids'].apply(check_upload)
# Making sure the number of annotation is of size 1 (i.e. they did not do multiple annotation)
data1['numAnnotations'] = data1['choice'].apply(check_anno)

#dropping annotations,subject_data, and subject_ids
data1 = data1.drop('annotations',1)
data1 = data1.drop('subject_data',1)
data1 = data1.drop('subject_ids',1)

# %%
# Workflow Versions we will work with
versions = [36.7,380.7,692.102,714.11399999999992]
data1['goodWorkFlow'] = (data1['workflow_version'].isin(versions))

# %%
# Adding a column to indicate what # annontation this is for a particular user
data1 = data1.sort_values(['user_name','classification_id'])

numOfClassification = []
iN = 1
for iT in data1['user_name'].duplicated():
    if not iT:
        iN = 1
    else:
        iN=iN +1
    numOfClassification.append(iN)
    
data1['numClassification'] = numOfClassification

# %%
data1 = data1.sort_index()
data1
# Out:
#        classification_id        user_name  user_id               user_ip  \
# 0                9525037      lmaesampson  1414392  5f156a8c2b8d034ee3ad
# 1                9604193         crowston   336603  dbc82e33a3b04ead00b1
# 2                9604196         crowston   336603  b520b59e40070c7f7b20
# 3                9604454         crowston   336603  b520b59e40070c7f7b20
# 4                9604601         crowston   336603  b520b59e40070c7f7b20
# 5                9604606         crowston   336603  b520b59e40070c7f7b20
# 6                9604614         crowston   336603  dbc82e33a3b04ead00b1
# 7                9625530  costerlusyr.edu  1303502  dbc82e33a3b04ead00b1
# 8                9625533  costerlusyr.edu  1303502  dbc82e33a3b04ead00b1
# 9               10295716          mzevin1   796717  e0e08dbd7223d98f05c1
# 10              10296637          mzevin1   796717  e0e08dbd7223d98f05c1
# 11              10296695          mzevin1   796717  e0e08dbd7223d98f05c1
# 12              10297006           sbc538   386563  eaafe1d5129d95dcbe9b
# 13              10300327         crowston   336603  97bcc4b46562af68c11b
# 14              10300333         crowston   336603  97bcc4b46562af68c11b
# 15              10300339         crowston   336603  97bcc4b46562af68c11b
# 16              10342622          mzevin1   796717  8e5d603049082740ada4
# 17              10342630          mzevin1   796717  8e5d603049082740ada4
# 18              10342635          mzevin1   796717  8e5d603049082740ada4
# 19              10342637          mzevin1   796717  8e5d603049082740ada4
# 20              10450661           sbc538   386563  60c9b8422c83c9587073
# 21              10465624          mzevin1   796717  bc5c76c423fb345b956c
# 22              10465628          mzevin1   796717  bc5c76c423fb345b956c
# 23              10481232          mzevin1   796717  4c487abfe58e8713a3ae
# 24              10552370           sbc538   386563  97ee87fe76fe5abbc986
# 25              10561376           sbc538   386563  93d977d35b2877edb3fa
# 26              10562354         cavaglia  1455699  93d977d35b2877edb3fa
# 27              10563078              ecm  1455689  93d977d35b2877edb3fa
# 28              10563093              ecm  1455689  93d977d35b2877edb3fa
# 29              10563129              ecm  1455689  93d977d35b2877edb3fa
# ...                  ...              ...      ...                   ...
# 56333           14006456         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56334           14006457       EcceruElme   322252  61f4c722c56b50265613
# 56335           14006461         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56336           14006465         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56337           14006470         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56338           14006479         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56339           14006484       EcceruElme   322252  61f4c722c56b50265613
# 56340           14006491         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56341           14006496       EcceruElme   322252  61f4c722c56b50265613
# 56342           14006498         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56343           14006504         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56344           14006507       EcceruElme   322252  61f4c722c56b50265613
# 56345           14006516       EcceruElme   322252  61f4c722c56b50265613
# 56346           14006518       EcceruElme   322252  61f4c722c56b50265613
# 56347           14006521       EcceruElme   322252  61f4c722c56b50265613
# 56348           14006524         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56349           14006528         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56350           14006530       EcceruElme   322252  61f4c722c56b50265613
# 56351           14006535         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56352           14006536       EcceruElme   322252  61f4c722c56b50265613
# 56353           14006538         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56354           14006544         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56355           14006551       EcceruElme   322252  61f4c722c56b50265613
# 56356           14006553         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56357           14006554       EcceruElme   322252  61f4c722c56b50265613
# 56358           14006558         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56359           14006566         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56360           14006570         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56361           14006587         Melina_t  1502635  f616bb8e0e0d2e008fa9
# 56362           14006592       EcceruElme   322252  61f4c722c56b50265613
#
#        workflow_id                                      workflow_name  \
# 0             1479  Apprentice - Jump in here for advanced Glitch ...
# 1             1479  Apprentice - Jump in here for advanced Glitch ...
# 2             1479  Apprentice - Jump in here for advanced Glitch ...
# 3             1479  Apprentice - Jump in here for advanced Glitch ...
# 4             1479  Apprentice - Jump in here for advanced Glitch ...
# 5             1479  Apprentice - Jump in here for advanced Glitch ...
# 6             1479  Apprentice - Jump in here for advanced Glitch ...
# 7             1479  Apprentice - Jump in here for advanced Glitch ...
# 8             1479  Apprentice - Jump in here for advanced Glitch ...
# 9             1479  Apprentice - Jump in here for advanced Glitch ...
# 10            1479  Apprentice - Jump in here for advanced Glitch ...
# 11            1479  Apprentice - Jump in here for advanced Glitch ...
# 12            1479  Apprentice - Jump in here for advanced Glitch ...
# 13            1479  Apprentice - Jump in here for advanced Glitch ...
# 14            1479  Apprentice - Jump in here for advanced Glitch ...
# 15            1479  Apprentice - Jump in here for advanced Glitch ...
# 16            1479  Apprentice - Jump in here for advanced Glitch ...
# 17            1479  Apprentice - Jump in here for advanced Glitch ...
# 18            1479  Apprentice - Jump in here for advanced Glitch ...
# 19            1479  Apprentice - Jump in here for advanced Glitch ...
# 20            1479  Apprentice - Jump in here for advanced Glitch ...
# 21            1479  Apprentice - Jump in here for advanced Glitch ...
# 22            1479  Apprentice - Jump in here for advanced Glitch ...
# 23            1610                                         Beginner 1
# 24            1479  Apprentice - Jump in here for advanced Glitch ...
# 25            1479  Apprentice - Jump in here for advanced Glitch ...
# 26            1610                                         Beginner 1
# 27            1479  Apprentice - Jump in here for advanced Glitch ...
# 28            1479  Apprentice - Jump in here for advanced Glitch ...
# 29            1479  Apprentice - Jump in here for advanced Glitch ...
# ...            ...                                                ...
# 56333         1479  Apprentice - Jump in here for advanced Glitch ...
# 56334         1479  Apprentice - Jump in here for advanced Glitch ...
# 56335         1479  Apprentice - Jump in here for advanced Glitch ...
# 56336         1479  Apprentice - Jump in here for advanced Glitch ...
# 56337         1479  Apprentice - Jump in here for advanced Glitch ...
# 56338         1479  Apprentice - Jump in here for advanced Glitch ...
# 56339         1479  Apprentice - Jump in here for advanced Glitch ...
# 56340         1479  Apprentice - Jump in here for advanced Glitch ...
# 56341         1479  Apprentice - Jump in here for advanced Glitch ...
# 56342         1479  Apprentice - Jump in here for advanced Glitch ...
# 56343         1479  Apprentice - Jump in here for advanced Glitch ...
# 56344         1479  Apprentice - Jump in here for advanced Glitch ...
# 56345         1479  Apprentice - Jump in here for advanced Glitch ...
# 56346         1479  Apprentice - Jump in here for advanced Glitch ...
# 56347         1479  Apprentice - Jump in here for advanced Glitch ...
# 56348         1479  Apprentice - Jump in here for advanced Glitch ...
# 56349         1479  Apprentice - Jump in here for advanced Glitch ...
# 56350         1479  Apprentice - Jump in here for advanced Glitch ...
# 56351         1479  Apprentice - Jump in here for advanced Glitch ...
# 56352         1479  Apprentice - Jump in here for advanced Glitch ...
# 56353         1479  Apprentice - Jump in here for advanced Glitch ...
# 56354         1479  Apprentice - Jump in here for advanced Glitch ...
# 56355         1479  Apprentice - Jump in here for advanced Glitch ...
# 56356         1479  Apprentice - Jump in here for advanced Glitch ...
# 56357         1479  Apprentice - Jump in here for advanced Glitch ...
# 56358         1479  Apprentice - Jump in here for advanced Glitch ...
# 56359         1479  Apprentice - Jump in here for advanced Glitch ...
# 56360         1479  Apprentice - Jump in here for advanced Glitch ...
# 56361         1479  Apprentice - Jump in here for advanced Glitch ...
# 56362         1479  Apprentice - Jump in here for advanced Glitch ...
#
#        workflow_version               created_at  gold_standard  expert  \
# 0                20.300  2016-01-28 19:43:53 UTC            NaN     NaN
# 1                44.600  2016-02-02 16:10:39 UTC            NaN     NaN
# 2                44.600  2016-02-02 16:10:50 UTC            NaN     NaN
# 3                44.600  2016-02-02 16:21:35 UTC            NaN     NaN
# 4                44.600  2016-02-02 16:26:48 UTC            NaN     NaN
# 5                44.600  2016-02-02 16:26:59 UTC            NaN     NaN
# 6                44.600  2016-02-02 16:27:14 UTC            NaN     NaN
# 7                44.600  2016-02-03 16:57:34 UTC            NaN     NaN
# 8                44.600  2016-02-03 16:57:44 UTC            NaN     NaN
# 9                77.360  2016-03-04 16:40:18 UTC            NaN     NaN
# 10               77.360  2016-03-04 17:06:20 UTC            NaN     NaN
# 11               77.360  2016-03-04 17:07:57 UTC            NaN     NaN
# 12               77.360  2016-03-04 17:13:56 UTC            NaN     NaN
# 13               77.360  2016-03-04 19:08:00 UTC            NaN     NaN
# 14               77.360  2016-03-04 19:08:23 UTC            NaN     NaN
# 15               77.360  2016-03-04 19:08:45 UTC            NaN     NaN
# 16               77.360  2016-03-06 18:56:05 UTC            NaN     NaN
# 17               77.360  2016-03-06 18:56:25 UTC            NaN     NaN
# 18               77.360  2016-03-06 18:56:42 UTC            NaN     NaN
# 19               77.360  2016-03-06 18:56:49 UTC            NaN     NaN
# 20              147.420  2016-03-10 22:25:15 UTC            NaN     NaN
# 21              147.420  2016-03-11 16:35:05 UTC            NaN     NaN
# 22              148.420  2016-03-11 16:35:15 UTC            NaN     NaN
# 23               95.600  2016-03-11 23:21:27 UTC            NaN     NaN
# 24              186.490  2016-03-15 14:47:28 UTC            NaN     NaN
# 25              186.490  2016-03-15 22:19:08 UTC            NaN     NaN
# 26               95.600  2016-03-15 23:50:54 UTC            NaN     NaN
# 27              186.490  2016-03-16 00:44:38 UTC            NaN     NaN
# 28              186.490  2016-03-16 00:45:01 UTC            NaN     NaN
# 29              186.490  2016-03-16 00:45:56 UTC            NaN     NaN
# ...                 ...                      ...            ...     ...
# 56333           714.114  2016-07-13 16:16:15 UTC            NaN     NaN
# 56334           714.114  2016-07-13 16:16:17 UTC            NaN     NaN
# 56335           714.114  2016-07-13 16:16:27 UTC            NaN     NaN
# 56336           714.114  2016-07-13 16:16:38 UTC            NaN     NaN
# 56337           714.114  2016-07-13 16:16:49 UTC            NaN     NaN
# 56338           714.114  2016-07-13 16:17:01 UTC            NaN     NaN
# 56339           714.114  2016-07-13 16:17:11 UTC            NaN     NaN
# 56340           714.114  2016-07-13 16:17:24 UTC            NaN     NaN
# 56341           714.114  2016-07-13 16:17:36 UTC            NaN     NaN
# 56342           714.114  2016-07-13 16:17:37 UTC            NaN     NaN
# 56343           714.114  2016-07-13 16:17:50 UTC            NaN     NaN
# 56344           714.114  2016-07-13 16:17:53 UTC            NaN     NaN
# 56345           714.114  2016-07-13 16:18:07 UTC            NaN     NaN
# 56346           714.114  2016-07-13 16:18:19 UTC            NaN     NaN
# 56347           714.114  2016-07-13 16:18:33 UTC            NaN     NaN
# 56348           714.114  2016-07-13 16:18:40 UTC            NaN     NaN
# 56349           714.114  2016-07-13 16:18:51 UTC            NaN     NaN
# 56350           714.114  2016-07-13 16:18:56 UTC            NaN     NaN
# 56351           714.114  2016-07-13 16:19:03 UTC            NaN     NaN
# 56352           714.114  2016-07-13 16:19:09 UTC            NaN     NaN
# 56353           714.114  2016-07-13 16:19:13 UTC            NaN     NaN
# 56354           714.114  2016-07-13 16:19:24 UTC            NaN     NaN
# 56355           714.114  2016-07-13 16:19:44 UTC            NaN     NaN
# 56356           714.114  2016-07-13 16:19:56 UTC            NaN     NaN
# 56357           714.114  2016-07-13 16:19:57 UTC            NaN     NaN
# 56358           714.114  2016-07-13 16:20:06 UTC            NaN     NaN
# 56359           714.114  2016-07-13 16:20:16 UTC            NaN     NaN
# 56360           714.114  2016-07-13 16:20:27 UTC            NaN     NaN
# 56361           714.114  2016-07-13 16:21:06 UTC            NaN     NaN
# 56362           714.114  2016-07-13 16:21:16 UTC            NaN     NaN
#
#                                                 metadata          choice  \
# 0      {"session":"11eb1a69d6e760c329984c2e8315e0b93d...            [{}]
# 1      {"session":"75c5ec8ed51acbe57ebbf4832889138f12...           [BLP]
# 2      {"session":"75c5ec8ed51acbe57ebbf4832889138f12...    [60HZPWRMNS]
# 3      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...           [BLP]
# 4      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...           [BLP]
# 5      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...       [NNFTHBV]
# 6      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...    [SCTTRDLGHT]
# 7      {"session":"7b60c2f156e7ae1a05fe243bcea06c82ba...        [HRMNCS]
# 8      {"session":"7b60c2f156e7ae1a05fe243bcea06c82ba...    [SCTTRDLGHT]
# 9      {"session":"65e4559affff1d4e2f0592b12c50a37aaf...       [NNFTHBV]
# 10     {"session":"65e4559affff1d4e2f0592b12c50a37aaf...       [XTRMLLD]
# 11     {"session":"d7610273636c2f3b10e72e803f719e11b3...       [NNFTHBV]
# 12     {"session":"bc89d79827eaa6352a0d07afd2d0d8f52c...           [BLP]
# 13     {"session":"8f4f780411ec563e0f42a271272c8b1209...          [KFSH]
# 14     {"session":"8f4f780411ec563e0f42a271272c8b1209...       [NNFTHBV]
# 15     {"session":"8f4f780411ec563e0f42a271272c8b1209...    [60HZPWRMNS]
# 16     {"session":"9c44968912498ed3665e738ffc40467159...    [60HZPWRMNS]
# 17     {"session":"9c44968912498ed3665e738ffc40467159...            [{}]
# 18     {"session":"9c44968912498ed3665e738ffc40467159...    [SCTTRDLGHT]
# 19     {"session":"9c44968912498ed3665e738ffc40467159...       [NNFTHBV]
# 20     {"session":"36fe4083a58664686107474534e0616171...         [WHSTL]
# 21     {"session":"74a4e84bea7ae917dff3c88ebce50bff9a...         [WHSTL]
# 22     {"session":"74a4e84bea7ae917dff3c88ebce50bff9a...         [WHSTL]
# 23     {"session":"9c4f7a348d3aa4751747cb65f259abf397...         [WHSTL]
# 24     {"session":"cfddbe88797eb781b338dd67a9a3a3b4d3...          [KFSH]
# 25     {"session":"af30be4f1f913a65ac225f996fdfcd0a24...          [KFSH]
# 26     {"session":"5de310f91edf11529a02d44ca23b575f3c...         [WHSTL]
# 27     {"session":"f70c5077f236874329cf94582f1c08599f...         [WHSTL]
# 28     {"session":"f70c5077f236874329cf94582f1c08599f...         [WHSTL]
# 29     {"session":"f70c5077f236874329cf94582f1c08599f...          [KFSH]
# ...                                                  ...             ...
# 56333  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...    [SCTTRDLGHT]
# 56334  {"session":"cd23881b638f970fd779646b743f32341c...           [BLP]
# 56335  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56336  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...          [KFSH]
# 56337  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56338  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...  [RCMPRSSR50HZ]
# 56339  {"session":"cd23881b638f970fd779646b743f32341c...        [NGLTCH]
# 56340  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...          [KFSH]
# 56341  {"session":"c4c9f4ce973c4ddd07282532adb403791c...   [LWFRQNCBRST]
# 56342  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56343  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56344  {"session":"c4c9f4ce973c4ddd07282532adb403791c...    [SCTTRDLGHT]
# 56345  {"session":"c4c9f4ce973c4ddd07282532adb403791c...   [LWFRQNCBRST]
# 56346  {"session":"c4c9f4ce973c4ddd07282532adb403791c...        [NGLTCH]
# 56347  {"session":"c4c9f4ce973c4ddd07282532adb403791c...        [SCRTCH]
# 56348  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...     [LGHTMDLTN]
# 56349  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...           [BLP]
# 56350  {"session":"c4c9f4ce973c4ddd07282532adb403791c...     [LWFRQNCLN]
# 56351  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56352  {"session":"c4c9f4ce973c4ddd07282532adb403791c...           [TMT]
# 56353  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56354  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56355  {"session":"c4c9f4ce973c4ddd07282532adb403791c...       [NNFTHBV]
# 56356  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...           [BLP]
# 56357  {"session":"c4c9f4ce973c4ddd07282532adb403791c...     [PWRLN60HZ]
# 56358  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56359  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...     [LWFRQNCLN]
# 56360  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56361  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [SCRTCH]
# 56362  {"session":"c4c9f4ce973c4ddd07282532adb403791c...        [NGLTCH]
#
#       tasks                                            answers    zooID  \
# 0        T1                                                 {}  1075876
# 1        T1                                                 {}  1076285
# 2        T1                                                 {}  1077316
# 3        T1                                                 {}  1076889
# 4        T1                                                 {}  1079043
# 5        T1                                                 {}  1077431
# 6        T1                                                 {}  1078615
# 7        T1                                                 {}  1077431
# 8        T1                                                 {}  1075876
# 9        T1                                                 {}  1688528
# 10       T1                                                 {}  1688148
# 11       T1                                                 {}  1688086
# 12       T1                                                 {}  1688085
# 13       T1                                                 {}  1687896
# 14       T1                                                 {}  1688376
# 15       T1                                                 {}  1689006
# 16       T1                                                 {}  1689037
# 17       T1                                                 {}  1688289
# 18       T1                                                 {}  1688981
# 19       T1                                                 {}  1690522
# 20       T1                                                 {}  1692933
# 21       T1                                                 {}  1692749
# 22       T1                                                 {}  1692811
# 23       T1                                                 {}  1692858
# 24       T1                                                 {}  1688207
# 25       T1                                                 {}  1688309
# 26       T1                                                 {}  1692826
# 27       T1                                                 {}  1692698
# 28       T1                                                 {}  1692633
# 29       T1                                                 {}  1688454
# ...     ...                                                ...      ...
# 56333    T1                                                 {}  2205690
# 56334    T1                                                 {}  2211325
# 56335    T1                                                 {}  2221011
# 56336    T1                                                 {}  2194103
# 56337    T1                                                 {}  2221126
# 56338    T1                                                 {}  2193140
# 56339    T1                                                 {}  2206665
# 56340    T1                                                 {}  2199935
# 56341    T1                                                 {}  2210390
# 56342    T1                                                 {}  2221383
# 56343    T1                                                 {}  2220517
# 56344    T1                                                 {}  2203913
# 56345    T1                                                 {}  2198597
# 56346    T1                                                 {}  2201217
# 56347    T1                                                 {}  2196570
# 56348    T1                                                 {}  2201499
# 56349    T1                                                 {}  2193932
# 56350    T1                                                 {}  2220698
# 56351    T1                                                 {}  2209424
# 56352    T1                                                 {}  2208107
# 56353    T1                                                 {}  2220135
# 56354    T1                                                 {}  2220773
# 56355    T1  {u'WHTSTHFRQNCFTHGLTCH': u'MD501000HZ', u'WHTS...  2196001
# 56356    T1                                                 {}  2199650
# 56357    T1                                                 {}  2217828
# 56358    T1                                                 {}  2201852
# 56359    T1                                                 {}  2218196
# 56360    T1                                                 {}  2194551
# 56361    T1                                                 {}  2198143
# 56362    T1                                                 {}  2200083
#
#           imageID goodUpload numAnnotations goodWorkFlow  numClassification
# 0      Lqw3QB36UT       True           True        False                  1
# 1      HTlgwFjWZn       True           True        False                  1
# 2      suKWBhith1       True           True        False                  2
# 3      6rkFgYSBKl       True           True        False                  3
# 4      IbPP81GsPI       True           True        False                  4
# 5      q9qihm2DAZ       True           True        False                  5
# 6      wIKCHx7qng       True           True        False                  6
# 7      q9qihm2DAZ       True           True        False                  1
# 8      Lqw3QB36UT       True           True        False                  2
# 9              []      False           True        False                  1
# 10             []      False           True        False                  2
# 11             []      False           True        False                  3
# 12             []      False           True        False                  1
# 13             []      False           True        False                  7
# 14             []      False           True        False                  8
# 15             []      False           True        False                  9
# 16             []      False           True        False                  4
# 17             []      False           True        False                  5
# 18             []      False           True        False                  6
# 19             []      False           True        False                  7
# 20             []      False           True        False                  2
# 21             []      False           True        False                  8
# 22             []      False           True        False                  9
# 23             []      False           True        False                 10
# 24             []      False           True        False                  3
# 25             []      False           True        False                  4
# 26             []      False           True        False                  1
# 27             []      False           True        False                  1
# 28             []      False           True        False                  2
# 29             []      False           True        False                  3
# ...           ...        ...            ...          ...                ...
# 56333  RYLTaZ3Q1L       True           True         True                146
# 56334  j1OVn6bJ3t       True           True         True              13727
# 56335  otE8lBEdOk       True           True         True                147
# 56336  8SkfHsDiKx       True           True         True                148
# 56337  nxo9v1Hqu7       True           True         True                149
# 56338  5obnE2ceUt       True           True         True                150
# 56339  ZxQoT6ookw       True           True         True              13728
# 56340  kByNoyJ96S       True           True         True                151
# 56341  KX9OeR8XzT       True           True         True              13729
# 56342  Y6PWSsVORY       True           True         True                152
# 56343  si5CNdCAx3       True           True         True                153
# 56344  nePufS78Dn       True           True         True              13730
# 56345  Cy63bGclpR       True           True         True              13731
# 56346  ha4gKyvEon       True           True         True              13732
# 56347  J3s9g5x8Uh       True           True         True              13733
# 56348  lcC9NilMrM       True           True         True                154
# 56349  20hT0wIxKU       True           True         True                155
# 56350  uz4jRcjuU1       True           True         True              13734
# 56351  LDUQOfhL0n       True           True         True                156
# 56352  xuLTR2AIJa       True           True         True              13735
# 56353  ulfd56vzbx       True           True         True                157
# 56354  nmHqWFl1fo       True           True         True                158
# 56355  3YxyXj4rxs       True           True         True              13736
# 56356  eNPTOwP1r8       True           True         True                159
# 56357  UqcT63Rufc       True           True         True              13737
# 56358  BYfHzVWPwT       True           True         True                160
# 56359  Swe5m5xxXD       True           True         True                161
# 56360  2C17r3UPx6       True           True         True                162
# 56361  MRwCuX00PT       True           True         True                163
# 56362  i9I73iAXS4       True           True         True              13738
#
# [56363 rows x 20 columns]

# %%
for iV in versions:
    version1 = np.unique(data1[data1['workflow_version'] == iV]['choice'])
    print("version {0}".format(iV))
    print("length {0}".format(len(data1[data1['workflow_version'] == iV])))
    print(version1)
    print("end")
# Out:
# version 36.7
# length 8058
# [['BLP'] ['CHRP'] ['KFSH'] ['PWRLN60HZ'] ['SCTTRDLGHT'] ['WHSTL']]
# end
# version 380.7
# length 29132
# [['45MHZLGHTMDLTN'] ['BLP'] ['CHRP'] ['CLBRTNLN300HZ'] ['DNTSGLTCH']
#  ['KFSH'] ['LWFRQNCBRST'] ['NNFTHBV'] ['PWRLN60HZ'] ['SCRTCH']
#  ['SCTTRDLGHT'] ['VLNHRMNC500HZ'] ['WHSTL'] ['WNDRNGLN'] ['XTRMLLD']]
# end
# version 692.102
# length 11874
# [['45MHZLGHTMDLTN'] ['50HZ'] ['BLP'] ['CHRP'] ['HLX'] ['KFSH']
#  ['LWFRQNCBRST'] ['LWFRQNCLN'] ['NGLTCH'] ['NNFTHBV'] ['PRDDVS']
#  ['PWRLN60HZ'] ['RPTNGBLPS'] ['SCRTCH'] ['SCTTRDLGHT'] ['TMT']
#  ['VLNMDHRMNC500HZ'] ['WHSTL'] ['WNDRNGLN'] ['XTRMLLD']]
# end
# version 714.114
# length 6373
# [['BLP'] ['CHRP'] ['HLX'] ['KFSH'] ['LGHTMDLTN'] ['LWFRQNCBRST']
#  ['LWFRQNCLN'] ['NGLTCH'] ['NNFTHBV'] ['PRDDVS'] ['PWRLN60HZ']
#  ['RCMPRSSR50HZ'] ['RPTNGBLPS'] ['SCRTCH'] ['SCTTRDLGHT'] ['TMT']
#  ['VLNMDHRMNC500HZ'] ['WHSTL'] ['WNDRNGLN'] ['XTRMLLD']]
# end

# %%
### DICT FOR CONVERTING LABELS TO INTEGERS ###
label_dict = {'45MHZLGHTMDLTN':1,'LGHTMDLTN':1,'50HZ':2,'RCMPRSSR50HZ':2,'BLP':3,'CHRP':4,'XTRMLLD':5,'HLX':6,'KFSH':7,
              'LWFRQNCBRST':8,'LWFRQNCLN':9,'NGLTCH':10,'DNTSGLTCH':10,'NNFTHBV':11,'PRDDVS':12,'60HZPWRLN':13,'60HZPWRMNS':13,
              'PWRLN60HZ':13,'RPTNGBLPS':14,'SCTTRDLGHT':15,'SCRTCH':16,'TMT':17,'VLNHRMNC500HZ':18,'VLNMDHRMNC500HZ':18,
              'HRMNCS':18,'WNDRNGLN':19,'WHSTL':20}

# %%
### READ FILE FOR CONVERTING imageIDs ###
id_match = pd.read_csv('IDmatchall.txt') #read in file
tmp_new = []
tmp_old = []
no_match = [] #list of imageIDs with no match (timestamp errors)
id_dict = {} #empty dict for converting imageIDs

for i in id_match['# New       Old']:
    if len(i)>10:
        i = i.split(' ')
        tmp_new.append(i[0])
        tmp_old.append(i[1])

id_match = pd.DataFrame({'new':tmp_new,'old':tmp_old})

for a,b in zip(id_match['new'],id_match['old']):
    id_dict[b] = a

# %%
### APPEND ALL PERTINENT DATA TO LIST ###

tmp_user= []
tmp_user_id = []
tmp_workflow = []
tmp_task = []
tmp_choice = []
tmp_retired = []
tmp_unique_id = []
tmp_zoo_id = []

for i in range(len(data)):
    # create list to hold to output information of each classification
    output = []
    # Check that there was only 1 choice made...
    annotations = json.loads(data[i][11])
    idcheck = data[i][2]
    if str(annotations).count('choice') == 1 and not np.isnan(idcheck):
        user = data[i,1]
        user_id = data[i,2]
        workflow = data[i,5]
        
        # annotations
        task = annotations[0]["task"]
        choice = annotations[0]["value"][0]["choice"]
        
        # subject data
        subject_data = json.loads(data[i][12])
        for key in subject_data:
            zoo_id = key
            retired = subject_data[key]['retired']
            unique_id = subject_data[key]['subject_id']
        
        # Append this information into a temporary output file
        tmp_user_id.append(user_id)
        tmp_workflow.append(workflow)
        tmp_task.append(task)
        tmp_choice.append(choice)
        tmp_retired.append(retired)
        tmp_unique_id.append(unique_id)
        tmp_zoo_id.append(zoo_id)
        
# Store each of the classification data
classifications = pd.DataFrame({'imageID':tmp_unique_id,'userID':tmp_user_id,'workflow':tmp_workflow,
                                'task':tmp_task,'label':tmp_choice,'type':tmp_retired, 'zooID':tmp_zoo_id})

# %%
images
# Out:
#      ML_posterior     imageID                           labels  truelabel  \
# 0              []  HauRDnEd8q  [10, 10, 10, 10, 10, 10, 9, 10]         -1
# 1              []  qOOEUMNyGi                              [7]         -1
# 2              []  GGfpUmYtJD                  [9, 9, 9, 9, 9]         -1
# 3              []  N70PSqtshJ                             [11]         -1
# 4              []  j99whZS7hL                  [9, 15, 15, 15]         -1
# 5              []  tRBVjF55Ah                [11, 8, 8, 11, 8]         -1
# 6              []  NCCpMZbVi0                              [9]         -1
# 7              []  EPTjErvJJi                 [15, 13, 13, 11]         -1
# 8              []  FBQL7ephxf                  [9, 9, 9, 9, 9]         -1
# 9              []  RFhohs0FxA                 [13, 13, 13, 11]         -1
# 10             []  Ye0YlVsQSL                          [8, 12]         -1
# 11             []  hvCygv2sfe                             [16]         -1
# 12             []  KWj146vF4P             [16, 16, 16, 16, 10]         -1
# 13             []  fZT7VYXBKo               [3, 3, 4, 3, 3, 3]         -1
# 14             []  QtscIzP4mc                        [8, 8, 8]         -1
# 15             []  0VgsIcsJLL                       [17, 3, 3]         -1
# 16             []  x38EHqIOQu          [15, 15, 15, 9, 15, 15]         -1
# 17             []  gstsWOFQLj                      [15, 11, 8]         -1
# 18             []  Sz2C93FXdu                        [8, 8, 8]         -1
# 19             []  dWcCbWa8nX                     [3, 3, 3, 3]         -1
# 20             []  DSfvfO4P8p                 [2, 2, 2, 11, 2]         -1
# 21             []  6L0PylKCUs                              [8]         -1
# 22             []  Pvq31iPEc6                           [9, 9]         -1
# 23             []  oBum3vWEFf                          [1, 11]         -1
# 24             []  Ja4m8mxDLR                     [13, 13, 13]         -1
# 25             []  t9nfvl8xDg                 [15, 15, 15, 11]         -1
# 26             []  07j5X77abG                     [8, 8, 8, 8]         -1
# 27             []  QRbcP9EHNX                     [12, 12, 11]         -1
# 28             []  cUDm7WAiV4         [10, 10, 10, 11, 11, 10]         -1
# 29             []  1J04lp2Xu0                      [15, 15, 9]         -1
# ...           ...         ...                              ...        ...
# 2946           []  mvoaK2VXE8                              [2]         -1
# 2947           []  GYWD4yZxBR                       [9, 2, 11]         -1
# 2948           []  CEPtXwoFot                           [3, 3]         -1
# 2949           []  kywBsUuC3j                     [13, 11, 13]         -1
# 2950           []  ENpx7Uq6YV        [9, 15, 9, 9, 15, 15, 15]         -1
# 2951           []  gvDB1fn6Lh                     [15, 15, 15]         -1
# 2952           []  uvdcRIlwLY               [8, 9, 8, 9, 8, 8]         -1
# 2953           []  lEnJ3xiYav                        [8, 8, 8]         -1
# 2954           []  Nlf2pGrIqV                           [8, 8]         -1
# 2955           []  8HbYU73sXo                  [3, 11, 14, 14]         -1
# 2956           []  EszqH01Grw                 [8, 8, 8, 9, 11]         -1
# 2957           []  vqvHDF8Isr                           [9, 9]         -1
# 2958           []  5smiMunmU4                     [10, 10, 10]         -1
# 2959           []  rlSwI0qzpA                 [11, 8, 8, 8, 8]         -1
# 2960           []  aU1e5lNTLa                    [11, 8, 8, 9]         -1
# 2961           []  vZhJ5Qmx1e                             [10]         -1
# 2962           []  WArKbCVkUd                        [3, 3, 3]         -1
# 2963           []  f0kRAcubm0                     [12, 14, 14]         -1
# 2964           []  MocthqVAjG         [11, 18, 11, 18, 11, 11]         -1
# 2965           []  ufzHojr6j0                       [11, 7, 5]         -1
# 2966           []  I6YipPOgIz                              [7]         -1
# 2967           []  2bgOJFs8fU                          [8, 11]         -1
# 2968           []  I5UAIeuAxK                  [8, 8, 8, 8, 8]         -1
# 2969           []  LwA2h5Rm3E                              [7]         -1
# 2970           []  TV28OxsWAR                              [8]         -1
# 2971           []  qTyiTZmRGu                         [11, 11]         -1
# 2972           []  IKGRX9EFZe                              [8]         -1
# 2973           []  dbbyqotdem                     [8, 5, 8, 8]         -1
# 2974           []  WpFIXGl7EP                        [8, 8, 8]         -1
# 2975           []  1ls77Zbwak                    [15, 9, 9, 9]         -1
#
#      type                                            userIDs    zooID
# 0       T  [835158, 1498433, 637439, 239792, 132, 82, 227...  2210216
# 1       T                                           [239792]  2207683
# 2       T         [1498519, 1498701, 530281, 239792, 243841]  2209323
# 3       T                                           [322252]  2200834
# 4       T                      [1047240, 239792, 82, 497320]  2211647
# 5       T                [1498519, 239792, 82, 322252, 2274]  2219760
# 6       T                                           [102001]  2215367
# 7       T                         [835158, 239792, 2909, 82]  2209896
# 8       T             [1498519, 1498433, 239792, 82, 322252]  2196270
# 9       T                         [82, 239792, 2274, 322252]  2215595
# 10      T                                     [2260, 497320]  2206173
# 11      T                                           [239792]  2202436
# 12      T            [835158, 1245626, 2260, 18049, 1499092]  2197809
# 13      T        [239792, 2274, 1217655, 529667, 322252, 82]  2200501
# 14      T                                 [2260, 82, 322252]  2217947
# 15      T                                [2260, 132, 497320]  2192006
# 16      T        [2909, 2260, 346679, 31153, 322252, 239792]  2206572
# 17      T                                 [547297, 1562, 82]  2202728
# 18      T                                 [2260, 82, 239792]  2218314
# 19      T                         [637439, 4261, 322252, 82]  2200587
# 20      T               [529667, 239792, 4261, 322252, 2274]  2209877
# 21      T                                          [1498502]  2195189
# 22      T                                   [322252, 239792]  2218018
# 23      T                                         [2909, 82]  2203302
# 24      T                                [82, 18049, 322252]  2198199
# 25      T                   [1221152, 2260, 1397526, 322252]  2206928
# 26      T                         [322252, 2274, 82, 239792]  2191798
# 27      T                              [2260, 18049, 239792]  2205599
# 28      T          [2260, 2909, 239792, 82, 322252, 1217655]  2204172
# 29      T                          [239792, 1499133, 322252]  2194887
# ...   ...                                                ...      ...
# 2946    T                                           [239792]  2221075
# 2947    T                             [2260, 239792, 322252]  2210205
# 2948    T                                     [530281, 2274]  2196265
# 2949    T                                 [2909, 239792, 82]  2214219
# 2950    T   [1460701, 2909, 18049, 2274, 239792, 497320, 82]  2196559
# 2951    T                          [1498785, 637439, 239792]  2202840
# 2952    T           [2909, 835158, 239792, 2274, 346679, 82]  2220535
# 2953    T                                 [2909, 239792, 82]  2212384
# 2954    T                                       [322252, 82]  2217787
# 2955    T                      [31153, 497320, 322252, 1562]  2193816
# 2956    T                  [82, 2260, 1499133, 2274, 322252]  2211241
# 2957    T                                   [637439, 529667]  2224160
# 2958    T                                 [2260, 82, 322252]  2197736
# 2959    T                    [82, 2260, 530281, 18049, 4261]  2220217
# 2960    T                        [1498519, 82, 322252, 2274]  2204140
# 2961    T                                           [322252]  2223701
# 2962    T                             [1498701, 1499096, 82]  2221479
# 2963    T                             [637439, 239792, 4261]  2198843
# 2964    T           [2260, 530281, 239792, 2274, 82, 322252]  2199280
# 2965    T                               [239792, 322252, 82]  2219908
# 2966    T                                           [239792]  2209070
# 2967    T                                   [239792, 322252]  2195770
# 2968    T             [1498433, 2260, 239792, 18049, 322252]  2208998
# 2969    T                                             [2260]  2199309
# 2970    T                                           [239792]  2216826
# 2971    T                                     [2274, 322252]  2207965
# 2972    T                                           [239792]  2209616
# 2973    T                       [2260, 239792, 2274, 322252]  2213161
# 2974    T                                 [2274, 322252, 82]  2222487
# 2975    T                    [239792, 4261, 322252, 1217655]  2192618
#
# [2976 rows x 7 columns]

# %%
uniques = set(np.unique(classifications['imageID'])) #create set of unique imageIDs
keys = set(id_dict.keys()) #create set of new imageIDs from id_dict
uniques = list(uniques.intersection(keys)) #find intersection of sets, convert to list

# %%
#function to create lists of empty lists
def emptylist(x):
    elist = []
    for i in range(x):
        elist.append([])
    return elist

# %%
### READ CLASSIFICATIONS FROM GRAVSPY BETA ###

#turn off unnecessary warning about setting values to slice of dataframe
pd.options.mode.chained_assignment = None  # default='warn'

#create dataframe, length of uniques, without labels or userIDs
images = pd.DataFrame({'type':['T']*len(uniques),'labels':emptylist(len(uniques)),
                        'userIDs':emptylist(len(uniques)),'ML_posterior':emptylist(len(uniques)),
                        'truelabel':[-1]*len(uniques),'imageID':uniques,'zooID':emptylist(len(uniques))})

for i in range(len(uniques)): #iterate over unique imageIDs
    
    classifications_idx = np.where((uniques[i] == classifications['imageID']))[0][0]
    
    images['zooID'][i] = int(classifications.loc[[classifications_idx], 'zooID'])
    
    for locations in np.where(uniques[i] == classifications['imageID']): #iterate over arrays of where unique imageID appears
        
        images_idx = np.where(uniques[i] == images['imageID'])[0][0] #find index of line in images where unique imageID appears
        
        for location in locations: #iterate over elements in array of locations in classifications where unique imageID appears
        
            images['labels'][images_idx].append(label_dict[classifications['label'][location]]) #append numeric label
            images['userIDs'][images_idx].append(int(classifications['userID'][location])) #append userID
            
for imageID in images['imageID']:

    imageID = id_dict[imageID]

# %%
### READ CLASSIFICATIONS OF GOLDEN IMAGES ###

goldendata = pd.read_csv('GLabel.csv')

for i in range(len(goldendata)): #iterate over data
    
    try:
        images_idx = np.where(int(goldendata['zooID'][i]) == images['zooID'])[0][0] #find location in images dataframe
        images['truelabel'][images_idx] = int(goldendata['Classification'][i]) #change true label to golden classification
        images['type'][images_idx] = 'G' #change image type to golden
        
    except:
        pass #to catch errors caused by images in goldendata not being in images dataframe

# %%
images
# Out:
#      ML_posterior     imageID                           labels  truelabel  \
# 0              []  HauRDnEd8q  [10, 10, 10, 10, 10, 10, 9, 10]         -1
# 1              []  qOOEUMNyGi                              [7]         -1
# 2              []  GGfpUmYtJD                  [9, 9, 9, 9, 9]         -1
# 3              []  N70PSqtshJ                             [11]         -1
# 4              []  j99whZS7hL                  [9, 15, 15, 15]         -1
# 5              []  tRBVjF55Ah                [11, 8, 8, 11, 8]         -1
# 6              []  NCCpMZbVi0                              [9]         -1
# 7              []  EPTjErvJJi                 [15, 13, 13, 11]         -1
# 8              []  FBQL7ephxf                  [9, 9, 9, 9, 9]         -1
# 9              []  RFhohs0FxA                 [13, 13, 13, 11]         -1
# 10             []  Ye0YlVsQSL                          [8, 12]         -1
# 11             []  hvCygv2sfe                             [16]         -1
# 12             []  KWj146vF4P             [16, 16, 16, 16, 10]         -1
# 13             []  fZT7VYXBKo               [3, 3, 4, 3, 3, 3]         -1
# 14             []  QtscIzP4mc                        [8, 8, 8]         -1
# 15             []  0VgsIcsJLL                       [17, 3, 3]         -1
# 16             []  x38EHqIOQu          [15, 15, 15, 9, 15, 15]         -1
# 17             []  gstsWOFQLj                      [15, 11, 8]         -1
# 18             []  Sz2C93FXdu                        [8, 8, 8]         -1
# 19             []  dWcCbWa8nX                     [3, 3, 3, 3]         -1
# 20             []  DSfvfO4P8p                 [2, 2, 2, 11, 2]         -1
# 21             []  6L0PylKCUs                              [8]         -1
# 22             []  Pvq31iPEc6                           [9, 9]         -1
# 23             []  oBum3vWEFf                          [1, 11]         -1
# 24             []  Ja4m8mxDLR                     [13, 13, 13]         -1
# 25             []  t9nfvl8xDg                 [15, 15, 15, 11]         -1
# 26             []  07j5X77abG                     [8, 8, 8, 8]         -1
# 27             []  QRbcP9EHNX                     [12, 12, 11]         -1
# 28             []  cUDm7WAiV4         [10, 10, 10, 11, 11, 10]         -1
# 29             []  1J04lp2Xu0                      [15, 15, 9]         -1
# ...           ...         ...                              ...        ...
# 2946           []  mvoaK2VXE8                              [2]         -1
# 2947           []  GYWD4yZxBR                       [9, 2, 11]         -1
# 2948           []  CEPtXwoFot                           [3, 3]         -1
# 2949           []  kywBsUuC3j                     [13, 11, 13]         -1
# 2950           []  ENpx7Uq6YV        [9, 15, 9, 9, 15, 15, 15]         -1
# 2951           []  gvDB1fn6Lh                     [15, 15, 15]         -1
# 2952           []  uvdcRIlwLY               [8, 9, 8, 9, 8, 8]         -1
# 2953           []  lEnJ3xiYav                        [8, 8, 8]         -1
# 2954           []  Nlf2pGrIqV                           [8, 8]         -1
# 2955           []  8HbYU73sXo                  [3, 11, 14, 14]         -1
# 2956           []  EszqH01Grw                 [8, 8, 8, 9, 11]         -1
# 2957           []  vqvHDF8Isr                           [9, 9]         -1
# 2958           []  5smiMunmU4                     [10, 10, 10]         10
# 2959           []  rlSwI0qzpA                 [11, 8, 8, 8, 8]         -1
# 2960           []  aU1e5lNTLa                    [11, 8, 8, 9]         -1
# 2961           []  vZhJ5Qmx1e                             [10]         -1
# 2962           []  WArKbCVkUd                        [3, 3, 3]         -1
# 2963           []  f0kRAcubm0                     [12, 14, 14]         -1
# 2964           []  MocthqVAjG         [11, 18, 11, 18, 11, 11]         -1
# 2965           []  ufzHojr6j0                       [11, 7, 5]          7
# 2966           []  I6YipPOgIz                              [7]         -1
# 2967           []  2bgOJFs8fU                          [8, 11]         -1
# 2968           []  I5UAIeuAxK                  [8, 8, 8, 8, 8]         -1
# 2969           []  LwA2h5Rm3E                              [7]         -1
# 2970           []  TV28OxsWAR                              [8]         -1
# 2971           []  qTyiTZmRGu                         [11, 11]         13
# 2972           []  IKGRX9EFZe                              [8]         -1
# 2973           []  dbbyqotdem                     [8, 5, 8, 8]         -1
# 2974           []  WpFIXGl7EP                        [8, 8, 8]         -1
# 2975           []  1ls77Zbwak                    [15, 9, 9, 9]         -1
#
#      type                                            userIDs    zooID
# 0       T  [835158, 1498433, 637439, 239792, 132, 82, 227...  2210216
# 1       T                                           [239792]  2207683
# 2       T         [1498519, 1498701, 530281, 239792, 243841]  2209323
# 3       T                                           [322252]  2200834
# 4       T                      [1047240, 239792, 82, 497320]  2211647
# 5       T                [1498519, 239792, 82, 322252, 2274]  2219760
# 6       T                                           [102001]  2215367
# 7       T                         [835158, 239792, 2909, 82]  2209896
# 8       T             [1498519, 1498433, 239792, 82, 322252]  2196270
# 9       T                         [82, 239792, 2274, 322252]  2215595
# 10      T                                     [2260, 497320]  2206173
# 11      T                                           [239792]  2202436
# 12      T            [835158, 1245626, 2260, 18049, 1499092]  2197809
# 13      T        [239792, 2274, 1217655, 529667, 322252, 82]  2200501
# 14      T                                 [2260, 82, 322252]  2217947
# 15      T                                [2260, 132, 497320]  2192006
# 16      T        [2909, 2260, 346679, 31153, 322252, 239792]  2206572
# 17      T                                 [547297, 1562, 82]  2202728
# 18      T                                 [2260, 82, 239792]  2218314
# 19      T                         [637439, 4261, 322252, 82]  2200587
# 20      T               [529667, 239792, 4261, 322252, 2274]  2209877
# 21      T                                          [1498502]  2195189
# 22      T                                   [322252, 239792]  2218018
# 23      T                                         [2909, 82]  2203302
# 24      T                                [82, 18049, 322252]  2198199
# 25      T                   [1221152, 2260, 1397526, 322252]  2206928
# 26      T                         [322252, 2274, 82, 239792]  2191798
# 27      T                              [2260, 18049, 239792]  2205599
# 28      T          [2260, 2909, 239792, 82, 322252, 1217655]  2204172
# 29      T                          [239792, 1499133, 322252]  2194887
# ...   ...                                                ...      ...
# 2946    T                                           [239792]  2221075
# 2947    T                             [2260, 239792, 322252]  2210205
# 2948    T                                     [530281, 2274]  2196265
# 2949    T                                 [2909, 239792, 82]  2214219
# 2950    T   [1460701, 2909, 18049, 2274, 239792, 497320, 82]  2196559
# 2951    T                          [1498785, 637439, 239792]  2202840
# 2952    T           [2909, 835158, 239792, 2274, 346679, 82]  2220535
# 2953    T                                 [2909, 239792, 82]  2212384
# 2954    T                                       [322252, 82]  2217787
# 2955    T                      [31153, 497320, 322252, 1562]  2193816
# 2956    T                  [82, 2260, 1499133, 2274, 322252]  2211241
# 2957    T                                   [637439, 529667]  2224160
# 2958    G                                 [2260, 82, 322252]  2197736
# 2959    T                    [82, 2260, 530281, 18049, 4261]  2220217
# 2960    T                        [1498519, 82, 322252, 2274]  2204140
# 2961    T                                           [322252]  2223701
# 2962    T                             [1498701, 1499096, 82]  2221479
# 2963    T                             [637439, 239792, 4261]  2198843
# 2964    T           [2260, 530281, 239792, 2274, 82, 322252]  2199280
# 2965    G                               [239792, 322252, 82]  2219908
# 2966    T                                           [239792]  2209070
# 2967    T                                   [239792, 322252]  2195770
# 2968    T             [1498433, 2260, 239792, 18049, 322252]  2208998
# 2969    T                                             [2260]  2199309
# 2970    T                                           [239792]  2216826
# 2971    G                                     [2274, 322252]  2207965
# 2972    T                                           [239792]  2209616
# 2973    T                       [2260, 239792, 2274, 322252]  2213161
# 2974    T                                 [2274, 322252, 82]  2222487
# 2975    T                    [239792, 4261, 322252, 1217655]  2192618
#
# [2976 rows x 7 columns]
