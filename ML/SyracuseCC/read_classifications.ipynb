# %%
### Import standard modules ###
import numpy as np
import pandas as pd
import json

# %%
### Define set of parsing functions ###

def CustomParser(data):
    j1 = json.loads(data)
    return j1

def filter_json(x):
    x=x[0]
    try:
        x['value']=x['value'][0]
    except:
        x['value'] = {u'answers': {}, u'choice': {}, u'filters': {}}
    return x

def extract_choice(x):
    y = []
    y.append((str(x['value']['choice'])))
    return y

def extract_tasks(x):
    x=x['task']
    return x

def extract_answers(x):
    x=x['value']['answers']
    return x

def extract_filters(x):
    x=['value']['filters']
    return x

def extract_zooID(x):
    x=int(list(x.keys())[0])
    return x

def extract_FileName1(x):
    try:
        x = x[list(x.keys())[0]]['Filename1'].split('_')[1]
    except:
        x = ''
    return x

def check_upload(x):
    if len(x.split(';')) == 4:
        x = True
    else:
        x = False
    return x

def check_anno(x):
    if len(x) == 1:
        x = True
    else:
        x = False
    return x

def convert_to_int(x):
    try:
        x=int(x)
    except:
        x=False
    return x

# %%
### Reading in csv with custom read for those column in JSON format ###

# Define location of classification file
class_file = "gravity-spy-classifications.csv" 

# Create dataframe from csv
data1 = pd.read_csv(class_file,converters={'annotations':CustomParser,'subject_data':CustomParser})

# Change ID to int
data1['user_id']        = data1['user_id'].apply(convert_to_int)
# Doing a mild work around for the json format of the annontation column
data1['annotations']    = data1['annotations'].apply(filter_json)
# Extracting choice and making it a column
data1['choice']         = data1['annotations'].apply(extract_choice)
# Extracting the task entry and making it a column
data1['tasks']          = data1['annotations'].apply(extract_tasks)
# Extracting answers and making it a column
data1['answers']        = data1['annotations'].apply(extract_answers)
# Extracting zooniverse ID it gave this subject and making it a column
data1['zooID']          = data1['subject_data'].apply(extract_zooID) 
# Extracting uniqueID assigned to the image during image creation and making it a column
data1['imageID']        = data1['subject_data'].apply(extract_FileName1)
# Get cumulative count of number of prior classifications by user
data1['classification_number'] = data1.groupby('user_id').cumcount()
# Making sure that the subject_ids for a given classification is 4. If not I uploaded the images wrong for that subject
data1['goodUpload']     = data1['subject_ids'].apply(check_upload)
# Making sure the number of annotation is of size 1 (i.e. they did not do multiple annotation)
data1['numAnnotations'] = data1['choice'].apply(check_anno)


# Dropping annotations,subject_data, and subject_ids
data1 = data1.drop('annotations',1)
data1 = data1.drop('subject_data',1)
data1 = data1.drop('subject_ids',1)

# %%
### Check if workflow version is acceptable ###
versions = [36.7,380.7,692.102,714.11399999999992] # List of acceptable versions
data1['goodWorkFlow'] = (data1['workflow_version'].isin(versions)) # Add column of booleans, true means acceptable

# %%
### Version specific quality checks ###

# Data for converting old to new imageIDs
id_data = pd.read_csv('IDmatchall.txt',delim_whitespace=True,skiprows=1,names=['new_imageID','old_imageID'])

beta_check = ~data1['workflow_version'].isin([692.102, 714.11399999999992]) # Check if classification from beta 2.0
id_check = data1['imageID'].isin(id_data['old_imageID']) # Check if imageID has a new ID

data1['goodID'] = beta_check | id_check # Apply 'bitwise-or' to checks, append to dataframe

# %%
### Apply data quality cuts ###
data1 = data1[data1.goodUpload & data1.numAnnotations & data1.goodWorkFlow & data1.goodID & data1.user_id != False]

# Drop unnecessary columns
data1 = data1.drop('user_ip',1)
data1 = data1.drop('workflow_name',1)
data1 = data1.drop('created_at',1)
data1 = data1.drop('gold_standard',1)
data1 = data1.drop('expert',1)
data1 = data1.drop('tasks',1)
data1 = data1.drop('answers',1)
data1 = data1.drop('goodUpload',1)
data1 = data1.drop('numAnnotations',1)
data1 = data1.drop('goodWorkFlow',1)
data1 = data1.drop('goodID',1)
data1 = data1.drop('metadata',1)

# %%
def lister(x):
    return list(x)

#data1.pivot(index='imageID',columns='choice',values='choice')
#data1.groupby('imageID').sum()
images = pd.pivot_table(data1,index='imageID',values=['choice', 'user_id','workflow_version'],aggfunc=lister)
images
# Out:
#                                                        choice  \
# imageID
# 001JFg1zZn                               [[BLP], [DNTSGLTCH]]
# 001PElpkuv  [[BLP], [BLP], [BLP], [BLP], [BLP], [BLP], [BL...
# 001rVzbSPh                         [[PWRLN60HZ], [DNTSGLTCH]]
# 002U5q9uFK                                            [[BLP]]
# 008zHCoBcj            [[DNTSGLTCH], [DNTSGLTCH], [DNTSGLTCH]]
# 009CGIYfPp                                     [[BLP], [BLP]]
# 009S1uci6w                                            [[BLP]]
# 009SMTyP3u            [[DNTSGLTCH], [DNTSGLTCH], [DNTSGLTCH]]
# 00By4Fnnm6  [[LWFRQNCBRST], [NNFTHBV], [LWFRQNCBRST], [LWF...
# 00CGhqJj1a                         [[DNTSGLTCH], [DNTSGLTCH]]
# 00EFORhdkt                                      [[DNTSGLTCH]]
# 00FBAlrNj7                                        [[NNFTHBV]]
# 00G0vd6UiS                                        [[XTRMLLD]]
# 00I6AqMfE5                         [[DNTSGLTCH], [DNTSGLTCH]]
# 00IayEZ9RK                     [[LWFRQNCBRST], [LWFRQNCBRST]]
# 00J4Xbu6YS                                      [[DNTSGLTCH]]
# 00JtHxfsHi                                            [[BLP]]
# 00KClmaxCh                                      [[DNTSGLTCH]]
# 00KfRdixlz                                        [[NNFTHBV]]
# 00LbZLJfCn                           [[KFSH], [KFSH], [KFSH]]
# 00Lv5cKlwn                                        [[NNFTHBV]]
# 00M1MYhdoy  [[DNTSGLTCH], [DNTSGLTCH], [DNTSGLTCH], [DNTSG...
# 00ME7GHvK2  [[SCTTRDLGHT], [PWRLN60HZ], [LWFRQNCBRST], [LW...
# 00MojM6AAL                                            [[BLP]]
# 00OOLnhvzj                                            [[BLP]]
# 00ObWXtXCl                                 [[BLP], [NNFTHBV]]
# 00R4avWtmE                                      [[DNTSGLTCH]]
# 00RNWMrAU1  [[BLP], [BLP], [BLP], [BLP], [BLP], [BLP], [NN...
# 00SZv0tuJc  [[DNTSGLTCH], [DNTSGLTCH], [DNTSGLTCH], [DNTSG...
# 00SguwBmj5                                      [[DNTSGLTCH]]
# ...                                                       ...
# zeQcNlPItf                           [[KFSH], [KFSH], [KFSH]]
# zf5W7WtjhR                                    [[BLP], [KFSH]]
# zhr9KfUosO                             [[NNFTHBV], [NNFTHBV]]
# ziLuh1ReYd  [[SCTTRDLGHT], [LWFRQNCLN], [LWFRQNCLN], [LWFR...
# zj9PUU4mun  [[LWFRQNCBRST], [LWFRQNCBRST], [NNFTHBV], [LWF...
# zjUolCJR1x                                            [[BLP]]
# zjXY2HamKj                            [[KFSH], [BLP], [KFSH]]
# zjaAgGBdgV  [[LWFRQNCBRST], [LWFRQNCBRST], [LWFRQNCLN], [L...
# zkafAxzIIH  [[SCTTRDLGHT], [LWFRQNCLN], [SCTTRDLGHT], [SCT...
# zkfi6xvKLz  [[LWFRQNCBRST], [LWFRQNCBRST], [LWFRQNCBRST], ...
# zlBFYAyuBP                                      [[PWRLN60HZ]]
# znJ1SCp55f                                      [[LWFRQNCLN]]
# zoQgUKRbxR  [[SCRTCH], [SCRTCH], [SCRTCH], [SCRTCH], [SCRT...
# zocIswi6oA      [[LWFRQNCBRST], [LWFRQNCBRST], [LWFRQNCBRST]]
# zpWvxfFDtu                     [[LWFRQNCBRST], [LWFRQNCBRST]]
# zpZq0UhUY6                                    [[LWFRQNCBRST]]
# zpuz8MMW3x            [[LWFRQNCLN], [LWFRQNCLN], [LWFRQNCLN]]
# zq0CG4I1Jg                              [[BLP], [BLP], [BLP]]
# zqGQOsNkGv  [[BLP], [BLP], [BLP], [BLP], [BLP], [BLP], [BL...
# zqjiASn1Gc                       [[SCTTRDLGHT], [SCTTRDLGHT]]
# zrikbtgjMK  [[LWFRQNCLN], [LWFRQNCLN], [LWFRQNCLN], [LWFRQ...
# ztwftjwluN  [[NNFTHBV], [LWFRQNCLN], [NNFTHBV], [NNFTHBV],...
# zu6k6GNbcV  [[LWFRQNCBRST], [LWFRQNCBRST], [LWFRQNCBRST], ...
# zuJ6crCXRi                                            [[BLP]]
# zvxQ8KlfIC                                            [[BLP]]
# zwPIvpTO0V                                            [[BLP]]
# zxw5baH2nA  [[PWRLN60HZ], [PWRLN60HZ], [PWRLN60HZ], [PWRLN...
# zy9kPFsEsD                                     [[BLP], [BLP]]
# zzQr5OeP19                              [[BLP], [BLP], [BLP]]
# zzgFBWqnHb                              [[BLP], [BLP], [BLP]]
#
#                                                       user_id  \
# imageID
# 001JFg1zZn                                  [1461442, 322252]
# 001PElpkuv  [322285, 1464491, 322252, 5209, 3462, 1430492,...
# 001rVzbSPh                                  [1460714, 322252]
# 002U5q9uFK                                           [322252]
# 008zHCoBcj                          [1428840, 704538, 322252]
# 009CGIYfPp                                  [1347018, 322252]
# 009S1uci6w                                           [322252]
# 009SMTyP3u                          [129311, 1430522, 322252]
# 00By4Fnnm6  [1431517, 5209, 1464491, 1347018, 322252, 1396...
# 00CGhqJj1a                                   [317055, 322252]
# 00EFORhdkt                                           [322252]
# 00FBAlrNj7                                           [322252]
# 00G0vd6UiS                                           [322252]
# 00I6AqMfE5                                  [1369081, 322252]
# 00IayEZ9RK                                   [318458, 322252]
# 00J4Xbu6YS                                           [322252]
# 00JtHxfsHi                                           [322252]
# 00KClmaxCh                                           [322252]
# 00KfRdixlz                                           [322252]
# 00LbZLJfCn                            [1498668, 289539, 2274]
# 00Lv5cKlwn                                           [322252]
# 00M1MYhdoy  [1431942, 1430578, 2677, 1460831, 190502, 3222...
# 00ME7GHvK2       [322252, 1464491, 1428460, 1461442, 1347018]
# 00MojM6AAL                                           [322252]
# 00OOLnhvzj                                           [322252]
# 00ObWXtXCl                                  [1369081, 322252]
# 00R4avWtmE                                           [322252]
# 00RNWMrAU1  [322285, 1430492, 5209, 322252, 1464491, 14284...
# 00SZv0tuJc  [1368254, 1437878, 2677, 315614, 4261, 1461442...
# 00SguwBmj5                                           [322252]
# ...                                                       ...
# zeQcNlPItf                           [349364, 289539, 679725]
# zf5W7WtjhR                                       [82, 289539]
# zhr9KfUosO                                       [82, 322252]
# ziLuh1ReYd                         [2909, 2260, 529667, 5209]
# zj9PUU4mun  [1498433, 2260, 239792, 82, 322252, 59701, 520...
# zjUolCJR1x                                          [1499170]
# zjXY2HamKj                                  [123, 4578, 2274]
# zjaAgGBdgV              [239792, 2274, 322252, 5209, 1502635]
# zkafAxzIIH              [239792, 2260, 322252, 5209, 1498433]
# zkfi6xvKLz  [82, 2260, 2909, 1397526, 239792, 4261, 530281...
# zlBFYAyuBP                                          [1499467]
# znJ1SCp55f                                           [322252]
# zoQgUKRbxR       [835158, 239792, 2274, 497320, 4261, 157033]
# zocIswi6oA                               [82, 322252, 239792]
# zpWvxfFDtu                                   [322252, 239792]
# zpZq0UhUY6                                           [239792]
# zpuz8MMW3x                                 [239792, 82, 2260]
# zq0CG4I1Jg                             [239792, 5209, 322252]
# zqGQOsNkGv  [314771, 324799, 1430596, 1430948, 310622, 143...
# zqjiASn1Gc                                     [5209, 322252]
# zrikbtgjMK               [835158, 4261, 322252, 322252, 5209]
# ztwftjwluN          [2260, 637439, 239792, 82, 5209, 1498433]
# zu6k6GNbcV         [835158, 82, 239792, 322252, 4261, 157033]
# zuJ6crCXRi                                             [2274]
# zvxQ8KlfIC                                           [322252]
# zwPIvpTO0V                                               [82]
# zxw5baH2nA                  [1217655, 1365905, 2274, 1499361]
# zy9kPFsEsD                                    [1498502, 2274]
# zzQr5OeP19                             [637439, 2274, 289539]
# zzgFBWqnHb                                 [322252, 82, 4261]
#
#                                              workflow_version
# imageID
# 001JFg1zZn                                     [380.7, 380.7]
# 001PElpkuv  [380.7, 380.7, 380.7, 380.7, 380.7, 380.7, 380...
# 001rVzbSPh                                     [380.7, 380.7]
# 002U5q9uFK                                            [380.7]
# 008zHCoBcj                              [380.7, 380.7, 380.7]
# 009CGIYfPp                                     [380.7, 380.7]
# 009S1uci6w                                            [380.7]
# 009SMTyP3u                              [380.7, 380.7, 380.7]
# 00By4Fnnm6         [380.7, 380.7, 380.7, 380.7, 380.7, 380.7]
# 00CGhqJj1a                                     [380.7, 380.7]
# 00EFORhdkt                                            [380.7]
# 00FBAlrNj7                                            [380.7]
# 00G0vd6UiS                                            [380.7]
# 00I6AqMfE5                                     [380.7, 380.7]
# 00IayEZ9RK                                     [380.7, 380.7]
# 00J4Xbu6YS                                            [380.7]
# 00JtHxfsHi                                            [380.7]
# 00KClmaxCh                                            [380.7]
# 00KfRdixlz                                            [380.7]
# 00LbZLJfCn                                 [36.7, 36.7, 36.7]
# 00Lv5cKlwn                                            [380.7]
# 00M1MYhdoy  [380.7, 380.7, 380.7, 380.7, 380.7, 380.7, 380...
# 00ME7GHvK2                [380.7, 380.7, 380.7, 380.7, 380.7]
# 00MojM6AAL                                            [380.7]
# 00OOLnhvzj                                            [380.7]
# 00ObWXtXCl                                     [380.7, 380.7]
# 00R4avWtmE                                            [380.7]
# 00RNWMrAU1  [380.7, 380.7, 380.7, 380.7, 380.7, 380.7, 380...
# 00SZv0tuJc  [380.7, 380.7, 380.7, 380.7, 380.7, 380.7, 380...
# 00SguwBmj5                                            [380.7]
# ...                                                       ...
# zeQcNlPItf                                 [36.7, 36.7, 36.7]
# zf5W7WtjhR                                       [36.7, 36.7]
# zhr9KfUosO                                 [692.102, 692.102]
# ziLuh1ReYd               [692.102, 692.102, 692.102, 714.114]
# zj9PUU4mun  [692.102, 692.102, 692.102, 692.102, 692.102, ...
# zjUolCJR1x                                             [36.7]
# zjXY2HamKj                                 [36.7, 36.7, 36.7]
# zjaAgGBdgV      [692.102, 692.102, 692.102, 714.114, 714.114]
# zkafAxzIIH      [692.102, 714.114, 714.114, 714.114, 714.114]
# zkfi6xvKLz  [692.102, 692.102, 692.102, 692.102, 692.102, ...
# zlBFYAyuBP                                             [36.7]
# znJ1SCp55f                                          [714.114]
# zoQgUKRbxR  [692.102, 692.102, 692.102, 692.102, 714.114, ...
# zocIswi6oA                        [692.102, 692.102, 714.114]
# zpWvxfFDtu                                 [714.114, 714.114]
# zpZq0UhUY6                                          [692.102]
# zpuz8MMW3x                        [692.102, 692.102, 714.114]
# zq0CG4I1Jg                        [714.114, 714.114, 714.114]
# zqGQOsNkGv  [380.7, 380.7, 380.7, 380.7, 380.7, 380.7, 380...
# zqjiASn1Gc                                 [714.114, 714.114]
# zrikbtgjMK      [692.102, 692.102, 714.114, 714.114, 714.114]
# ztwftjwluN  [692.102, 692.102, 692.102, 692.102, 714.114, ...
# zu6k6GNbcV  [692.102, 692.102, 692.102, 692.102, 692.102, ...
# zuJ6crCXRi                                             [36.7]
# zvxQ8KlfIC                                          [714.114]
# zwPIvpTO0V                                          [692.102]
# zxw5baH2nA                           [36.7, 36.7, 36.7, 36.7]
# zy9kPFsEsD                                       [36.7, 36.7]
# zzQr5OeP19                                 [36.7, 36.7, 36.7]
# zzgFBWqnHb                        [692.102, 714.114, 714.114]
#
# [15982 rows x 3 columns]

# %%
### Code to check label options for each workflow version ###

for iV in versions:
    version = np.unique(data1[data1['workflow_version'] == iV]['choice'])
    print("version {0}".format(iV))
    print("length {0}".format(len(data1[data1['workflow_version'] == iV])))
    print(version)
    print("end")
# Out:
# version 36.7
# length 4184
# [['BLP'] ['CHRP'] ['KFSH'] ['PWRLN60HZ'] ['SCTTRDLGHT'] ['WHSTL']]
# end
# version 380.7
# length 26047
# [['45MHZLGHTMDLTN'] ['BLP'] ['CHRP'] ['CLBRTNLN300HZ'] ['DNTSGLTCH']
#  ['KFSH'] ['LWFRQNCBRST'] ['NNFTHBV'] ['PWRLN60HZ'] ['SCRTCH']
#  ['SCTTRDLGHT'] ['VLNHRMNC500HZ'] ['WHSTL'] ['WNDRNGLN'] ['XTRMLLD']]
# end
# version 692.102
# length 9755
# [['45MHZLGHTMDLTN'] ['50HZ'] ['BLP'] ['CHRP'] ['HLX'] ['KFSH']
#  ['LWFRQNCBRST'] ['LWFRQNCLN'] ['NGLTCH'] ['NNFTHBV'] ['PRDDVS']
#  ['PWRLN60HZ'] ['RPTNGBLPS'] ['SCRTCH'] ['SCTTRDLGHT'] ['TMT']
#  ['VLNMDHRMNC500HZ'] ['WHSTL'] ['WNDRNGLN'] ['XTRMLLD']]
# end
# version 714.1139999999999
# length 5223
# [['BLP'] ['CHRP'] ['HLX'] ['KFSH'] ['LGHTMDLTN'] ['LWFRQNCBRST']
#  ['LWFRQNCLN'] ['NGLTCH'] ['NNFTHBV'] ['PRDDVS'] ['PWRLN60HZ']
#  ['RCMPRSSR50HZ'] ['RPTNGBLPS'] ['SCRTCH'] ['SCTTRDLGHT'] ['TMT']
#  ['VLNMDHRMNC500HZ'] ['WHSTL'] ['WNDRNGLN'] ['XTRMLLD']]
# end

# %%
### Dict for converting alpha labels to int labels ###
label_dict = {'45MHZLGHTMDLTN':0,'LGHTMDLTN':0,'50HZ':1,'RCMPRSSR50HZ':1,'BLP':2,'CHRP':3,'XTRMLLD':4,'HLX':5,'KFSH':6,
              'LWFRQNCBRST':7,'LWFRQNCLN':8,'NGLTCH':9,'DNTSGLTCH':9,'NNFTHBV':10,'PRDDVS':11,'60HZPWRLN':12,'60HZPWRMNS':12,
              'PWRLN60HZ':12,'RPTNGBLPS':13,'SCTTRDLGHT':14,'SCRTCH':15,'TMT':16,'VLNHRMNC500HZ':17,'VLNMDHRMNC500HZ':17,
              'HRMNCS':17,'WNDRNGLN':18,'WHSTL':19}

# %%
data1.dtypes
images.dtypes
#len(images) == len(np.unique(data1['imageID']))
# Out:
# choice              object
# user_id             object
# workflow_version    object
# dtype: object

# %%
### READ FILE FOR CONVERTING imageIDs ###
id_match = pd.read_csv('IDmatchall.txt') #read in file
tmp_new = []
tmp_old = []
no_match = [] #list of imageIDs with no match (timestamp errors)
id_dict = {} #empty dict for converting imageIDs

for i in id_match['# New       Old']:
    if len(i)>10:
        i = i.split(' ')
        tmp_new.append(i[0])
        tmp_old.append(i[1])

id_match = pd.DataFrame({'new':tmp_new,'old':tmp_old})

for a,b in zip(id_match['new'],id_match['old']):
    id_dict[b] = a

# %%
### APPEND ALL PERTINENT DATA TO LIST ###

tmp_user= []
tmp_user_id = []
tmp_workflow = []
tmp_task = []
tmp_choice = []
tmp_retired = []
tmp_unique_id = []
tmp_zoo_id = []

for i in range(len(data)):
    # create list to hold to output information of each classification
    output = []
    # Check that there was only 1 choice made...
    annotations = json.loads(data[i][11])
    idcheck = data[i][2]
    if str(annotations).count('choice') == 1 and not np.isnan(idcheck):
        user = data[i,1]
        user_id = data[i,2]
        workflow = data[i,5]
        
        # annotations
        task = annotations[0]["task"]
        choice = annotations[0]["value"][0]["choice"]
        
        # subject data
        subject_data = json.loads(data[i][12])
        for key in subject_data:
            zoo_id = key
            retired = subject_data[key]['retired']
            unique_id = subject_data[key]['subject_id']
        
        # Append this information into a temporary output file
        tmp_user_id.append(user_id)
        tmp_workflow.append(workflow)
        tmp_task.append(task)
        tmp_choice.append(choice)
        tmp_retired.append(retired)
        tmp_unique_id.append(unique_id)
        tmp_zoo_id.append(zoo_id)
        
# Store each of the classification data
classifications = pd.DataFrame({'imageID':tmp_unique_id,'userID':tmp_user_id,'workflow':tmp_workflow,
                                'task':tmp_task,'label':tmp_choice,'type':tmp_retired, 'zooID':tmp_zoo_id})

# %%
data1
# Out:
#        classification_id                                          user_name  \
# 0                9525037  0            lmaesampson\n1               crow...
# 1                9604193  0            lmaesampson\n1               crow...
# 2                9604196  0            lmaesampson\n1               crow...
# 3                9604454  0            lmaesampson\n1               crow...
# 4                9604601  0            lmaesampson\n1               crow...
# 5                9604606  0            lmaesampson\n1               crow...
# 6                9604614  0            lmaesampson\n1               crow...
# 7                9625530  0            lmaesampson\n1               crow...
# 8                9625533  0            lmaesampson\n1               crow...
# 9               10295716  0            lmaesampson\n1               crow...
# 10              10296637  0            lmaesampson\n1               crow...
# 11              10296695  0            lmaesampson\n1               crow...
# 12              10297006  0            lmaesampson\n1               crow...
# 13              10300327  0            lmaesampson\n1               crow...
# 14              10300333  0            lmaesampson\n1               crow...
# 15              10300339  0            lmaesampson\n1               crow...
# 16              10342622  0            lmaesampson\n1               crow...
# 17              10342630  0            lmaesampson\n1               crow...
# 18              10342635  0            lmaesampson\n1               crow...
# 19              10342637  0            lmaesampson\n1               crow...
# 20              10450661  0            lmaesampson\n1               crow...
# 21              10465624  0            lmaesampson\n1               crow...
# 22              10465628  0            lmaesampson\n1               crow...
# 23              10481232  0            lmaesampson\n1               crow...
# 24              10552370  0            lmaesampson\n1               crow...
# 25              10561376  0            lmaesampson\n1               crow...
# 26              10562354  0            lmaesampson\n1               crow...
# 27              10563078  0            lmaesampson\n1               crow...
# 28              10563093  0            lmaesampson\n1               crow...
# 29              10563129  0            lmaesampson\n1               crow...
# ...                  ...                                                ...
# 56333           14006456  0            lmaesampson\n1               crow...
# 56334           14006457  0            lmaesampson\n1               crow...
# 56335           14006461  0            lmaesampson\n1               crow...
# 56336           14006465  0            lmaesampson\n1               crow...
# 56337           14006470  0            lmaesampson\n1               crow...
# 56338           14006479  0            lmaesampson\n1               crow...
# 56339           14006484  0            lmaesampson\n1               crow...
# 56340           14006491  0            lmaesampson\n1               crow...
# 56341           14006496  0            lmaesampson\n1               crow...
# 56342           14006498  0            lmaesampson\n1               crow...
# 56343           14006504  0            lmaesampson\n1               crow...
# 56344           14006507  0            lmaesampson\n1               crow...
# 56345           14006516  0            lmaesampson\n1               crow...
# 56346           14006518  0            lmaesampson\n1               crow...
# 56347           14006521  0            lmaesampson\n1               crow...
# 56355  2016-07-13 16:19:44 UTC            NaN     NaN
# 56356  2016-07-13 16:19:56 UTC            NaN     NaN
# 56357  2016-07-13 16:19:57 UTC            NaN     NaN
# 56358  2016-07-13 16:20:06 UTC            NaN     NaN
# 56359  2016-07-13 16:20:16 UTC            NaN     NaN
# 56360  2016-07-13 16:20:27 UTC            NaN     NaN
# 56361  2016-07-13 16:21:06 UTC            NaN     NaN
# 56362  2016-07-13 16:21:16 UTC            NaN     NaN
#
#                                                 metadata          choice  \
# 0      {"session":"11eb1a69d6e760c329984c2e8315e0b93d...            [{}]
# 1      {"session":"75c5ec8ed51acbe57ebbf4832889138f12...           [BLP]
# 2      {"session":"75c5ec8ed51acbe57ebbf4832889138f12...    [60HZPWRMNS]
# 3      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...           [BLP]
# 4      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...           [BLP]
# 5      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...       [NNFTHBV]
# 6      {"session":"cb966ac7ba0eaf72b90dd9b3a38a850bf9...    [SCTTRDLGHT]
# 7      {"session":"7b60c2f156e7ae1a05fe243bcea06c82ba...        [HRMNCS]
# 8      {"session":"7b60c2f156e7ae1a05fe243bcea06c82ba...    [SCTTRDLGHT]
# 9      {"session":"65e4559affff1d4e2f0592b12c50a37aaf...       [NNFTHBV]
# 10     {"session":"65e4559affff1d4e2f0592b12c50a37aaf...       [XTRMLLD]
# 11     {"session":"d7610273636c2f3b10e72e803f719e11b3...       [NNFTHBV]
# 12     {"session":"bc89d79827eaa6352a0d07afd2d0d8f52c...           [BLP]
# 13     {"session":"8f4f780411ec563e0f42a271272c8b1209...          [KFSH]
# 14     {"session":"8f4f780411ec563e0f42a271272c8b1209...       [NNFTHBV]
# 15     {"session":"8f4f780411ec563e0f42a271272c8b1209...    [60HZPWRMNS]
# 16     {"session":"9c44968912498ed3665e738ffc40467159...    [60HZPWRMNS]
# 17     {"session":"9c44968912498ed3665e738ffc40467159...            [{}]
# 18     {"session":"9c44968912498ed3665e738ffc40467159...    [SCTTRDLGHT]
# 19     {"session":"9c44968912498ed3665e738ffc40467159...       [NNFTHBV]
# 20     {"session":"36fe4083a58664686107474534e0616171...         [WHSTL]
# 21     {"session":"74a4e84bea7ae917dff3c88ebce50bff9a...         [WHSTL]
# 22     {"session":"74a4e84bea7ae917dff3c88ebce50bff9a...         [WHSTL]
# 23     {"session":"9c4f7a348d3aa4751747cb65f259abf397...         [WHSTL]
# 24     {"session":"cfddbe88797eb781b338dd67a9a3a3b4d3...          [KFSH]
# 25     {"session":"af30be4f1f913a65ac225f996fdfcd0a24...          [KFSH]
# 26     {"session":"5de310f91edf11529a02d44ca23b575f3c...         [WHSTL]
# 27     {"session":"f70c5077f236874329cf94582f1c08599f...         [WHSTL]
# 28     {"session":"f70c5077f236874329cf94582f1c08599f...         [WHSTL]
# 29     {"session":"f70c5077f236874329cf94582f1c08599f...          [KFSH]
# ...                                                  ...             ...
# 56333  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...    [SCTTRDLGHT]
# 56334  {"session":"cd23881b638f970fd779646b743f32341c...           [BLP]
# 56335  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56336  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...          [KFSH]
# 56337  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56338  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...  [RCMPRSSR50HZ]
# 56339  {"session":"cd23881b638f970fd779646b743f32341c...        [NGLTCH]
# 56340  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...          [KFSH]
# 56341  {"session":"c4c9f4ce973c4ddd07282532adb403791c...   [LWFRQNCBRST]
# 56342  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56343  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56344  {"session":"c4c9f4ce973c4ddd07282532adb403791c...    [SCTTRDLGHT]
# 56345  {"session":"c4c9f4ce973c4ddd07282532adb403791c...   [LWFRQNCBRST]
# 56346  {"session":"c4c9f4ce973c4ddd07282532adb403791c...        [NGLTCH]
# 56347  {"session":"c4c9f4ce973c4ddd07282532adb403791c...        [SCRTCH]
# 56348  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...     [LGHTMDLTN]
# 56349  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...           [BLP]
# 56350  {"session":"c4c9f4ce973c4ddd07282532adb403791c...     [LWFRQNCLN]
# 56351  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [NGLTCH]
# 56352  {"session":"c4c9f4ce973c4ddd07282532adb403791c...           [TMT]
# 56353  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56354  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56355  {"session":"c4c9f4ce973c4ddd07282532adb403791c...       [NNFTHBV]
# 56356  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...           [BLP]
# 56357  {"session":"c4c9f4ce973c4ddd07282532adb403791c...     [PWRLN60HZ]
# 56358  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56359  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...     [LWFRQNCLN]
# 56360  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...   [LWFRQNCBRST]
# 56361  {"session":"6b1f4a787dea04b06a0747f02c67cdfb70...        [SCRTCH]
# 56362  {"session":"c4c9f4ce973c4ddd07282532adb403791c...        [NGLTCH]
#
#       tasks                                            answers    zooID  \
# 0        T1                                                 {}  1075876
# 1        T1                                                 {}  1076285
# 2        T1                                                 {}  1077316
# 3        T1                                                 {}  1076889
# 4        T1                                                 {}  1079043
# 5        T1                                                 {}  1077431
# 6        T1                                                 {}  1078615
# 7        T1                                                 {}  1077431
# 8        T1                                                 {}  1075876
# 9        T1                                                 {}  1688528
# 10       T1                                                 {}  1688148
# 11       T1                                                 {}  1688086
# 12       T1                                                 {}  1688085
# 13       T1                                                 {}  1687896
# 14       T1                                                 {}  1688376
# 15       T1                                                 {}  1689006
# 16       T1                                                 {}  1689037
# 17       T1                                                 {}  1688289
# 18       T1                                                 {}  1688981
# 19       T1                                                 {}  1690522
# 20       T1                                                 {}  1692933
# 21       T1                                                 {}  1692749
# 22       T1                                                 {}  1692811
# 23       T1                                                 {}  1692858
# 24       T1                                                 {}  1688207
# 25       T1                                                 {}  1688309
# 26       T1                                                 {}  1692826
# 27       T1                                                 {}  1692698
# 28       T1                                                 {}  1692633
# 29       T1                                                 {}  1688454
# ...     ...                                                ...      ...
# 56333    T1                                                 {}  2205690
# 56334    T1                                                 {}  2211325
# 56335    T1                                                 {}  2221011
# 56336    T1                                                 {}  2194103
# 56337    T1                                                 {}  2221126
# 56338    T1                                                 {}  2193140
# 56339    T1                                                 {}  2206665
# 56340    T1                                                 {}  2199935
# 56341    T1                                                 {}  2210390
# 56342    T1                                                 {}  2221383
# 56343    T1                                                 {}  2220517
# 56344    T1                                                 {}  2203913
# 56345    T1                                                 {}  2198597
# 56346    T1                                                 {}  2201217
# 56347    T1                                                 {}  2196570
# 56348    T1                                                 {}  2201499
# 56349    T1                                                 {}  2193932
# 56350    T1                                                 {}  2220698
# 56351    T1                                                 {}  2209424
# 56352    T1                                                 {}  2208107
# 56353    T1                                                 {}  2220135
# 56354    T1                                                 {}  2220773
# 56355    T1  {'WHTSTHFRQNCFTHGLTCH': 'MD501000HZ', 'STHGLTC...  2196001
# 56356    T1                                                 {}  2199650
# 56357    T1                                                 {}  2217828
# 56358    T1                                                 {}  2201852
# 56359    T1                                                 {}  2218196
# 56360    T1                                                 {}  2194551
# 56361    T1                                                 {}  2198143
# 56362    T1                                                 {}  2200083
#
#           imageID  classification_number goodUpload numAnnotations
# 0      Lqw3QB36UT                      0       True           True
# 1      HTlgwFjWZn                      0       True           True
# 2      suKWBhith1                      1       True           True
# 3      6rkFgYSBKl                      2       True           True
# 4      IbPP81GsPI                      3       True           True
# 5      q9qihm2DAZ                      4       True           True
# 6      wIKCHx7qng                      5       True           True
# 7      q9qihm2DAZ                      0       True           True
# 8      Lqw3QB36UT                      1       True           True
# 9                                      0      False           True
# 10                                     1      False           True
# 11                                     2      False           True
# 12                                     0      False           True
# 13                                     6      False           True
# 14                                     7      False           True
# 15                                     8      False           True
# 16                                     3      False           True
# 17                                     4      False           True
# 18                                     5      False           True
# 19                                     6      False           True
# 20                                     1      False           True
# 21                                     7      False           True
# 22                                     8      False           True
# 23                                     9      False           True
# 24                                     2      False           True
# 25                                     3      False           True
# 26                                     0      False           True
# 27                                     0      False           True
# 28                                     1      False           True
# 29                                     2      False           True
# ...           ...                    ...        ...            ...
# 56333  RYLTaZ3Q1L                    145       True           True
# 56334  j1OVn6bJ3t                  13726       True           True
# 56335  otE8lBEdOk                    146       True           True
# 56336  8SkfHsDiKx                    147       True           True
# 56337  nxo9v1Hqu7                    148       True           True
# 56338  5obnE2ceUt                    149       True           True
# 56339  ZxQoT6ookw                  13727       True           True
# 56340  kByNoyJ96S                    150       True           True
# 56341  KX9OeR8XzT                  13728       True           True
# 56342  Y6PWSsVORY                    151       True           True
# 56343  si5CNdCAx3                    152       True           True
# 56344  nePufS78Dn                  13729       True           True
# 56345  Cy63bGclpR                  13730       True           True
# 56346  ha4gKyvEon                  13731       True           True
# 56347  J3s9g5x8Uh                  13732       True           True
# 56348  lcC9NilMrM                    153       True           True
# 56349  20hT0wIxKU                    154       True           True
# 56350  uz4jRcjuU1                  13733       True           True
# 56351  LDUQOfhL0n                    155       True           True
# 56352  xuLTR2AIJa                  13734       True           True
# 56353  ulfd56vzbx                    156       True           True
# 56354  nmHqWFl1fo                    157       True           True
# 56355  3YxyXj4rxs                  13735       True           True
# 56356  eNPTOwP1r8                    158       True           True
# 56357  UqcT63Rufc                  13736       True           True
# 56358  BYfHzVWPwT                    159       True           True
# 56359  Swe5m5xxXD                    160       True           True
# 56360  2C17r3UPx6                    161       True           True
# 56361  MRwCuX00PT                    162       True           True
# 56362  i9I73iAXS4                  13737       True           True
#
# [56363 rows x 19 columns]

# %%
uniques = set(np.unique(classifications['imageID'])) #create set of unique imageIDs
keys = set(id_dict.keys()) #create set of new imageIDs from id_dict
uniques = list(uniques.intersection(keys)) #find intersection of sets, convert to list

# %%
#function to create lists of empty lists
def emptylist(x):
    elist = []
    for i in range(x):
        elist.append([])
    return elist

# %%
### READ CLASSIFICATIONS FROM GRAVSPY BETA ###

#turn off unnecessary warning about setting values to slice of dataframe
pd.options.mode.chained_assignment = None  # default='warn'

#create dataframe, length of uniques, without labels or userIDs
images = pd.DataFrame({'type':['T']*len(uniques),'labels':emptylist(len(uniques)),
                        'userIDs':emptylist(len(uniques)),'ML_posterior':emptylist(len(uniques)),
                        'truelabel':[-1]*len(uniques),'imageID':uniques,'zooID':emptylist(len(uniques))})

for i in range(len(uniques)): #iterate over unique imageIDs
    
    classifications_idx = np.where((uniques[i] == classifications['imageID']))[0][0]
    
    images['zooID'][i] = int(classifications.loc[[classifications_idx], 'zooID'])
    
    for locations in np.where(uniques[i] == classifications['imageID']): #iterate over arrays of where unique imageID appears
        
        images_idx = np.where(uniques[i] == images['imageID'])[0][0] #find index of line in images where unique imageID appears
        
        for location in locations: #iterate over elements in array of locations in classifications where unique imageID appears
        
            images['labels'][images_idx].append(label_dict[classifications['label'][location]]) #append numeric label
            images['userIDs'][images_idx].append(int(classifications['userID'][location])) #append userID
            
for imageID in images['imageID']:

    imageID = id_dict[imageID]

# %%
### READ CLASSIFICATIONS OF GOLDEN IMAGES ###

goldendata = pd.read_csv('GLabel.csv')

for i in range(len(goldendata)): #iterate over data
    
    try:
        images_idx = np.where(int(goldendata['zooID'][i]) == images['zooID'])[0][0] #find location in images dataframe
        images['truelabel'][images_idx] = int(goldendata['Classification'][i]) #change true label to golden classification
        images['type'][images_idx] = 'G' #change image type to golden
        
    except:
        pass #to catch errors caused by images in goldendata not being in images dataframe

# %%
images
# Out:
#      ML_posterior     imageID                           labels  truelabel  \
# 0              []  HauRDnEd8q  [10, 10, 10, 10, 10, 10, 9, 10]         -1
# 1              []  qOOEUMNyGi                              [7]         -1
# 2              []  GGfpUmYtJD                  [9, 9, 9, 9, 9]         -1
# 3              []  N70PSqtshJ                             [11]         -1
# 4              []  j99whZS7hL                  [9, 15, 15, 15]         -1
# 5              []  tRBVjF55Ah                [11, 8, 8, 11, 8]         -1
# 6              []  NCCpMZbVi0                              [9]         -1
# 7              []  EPTjErvJJi                 [15, 13, 13, 11]         -1
# 8              []  FBQL7ephxf                  [9, 9, 9, 9, 9]         -1
# 9              []  RFhohs0FxA                 [13, 13, 13, 11]         -1
# 10             []  Ye0YlVsQSL                          [8, 12]         -1
# 11             []  hvCygv2sfe                             [16]         -1
# 12             []  KWj146vF4P             [16, 16, 16, 16, 10]         -1
# 13             []  fZT7VYXBKo               [3, 3, 4, 3, 3, 3]         -1
# 14             []  QtscIzP4mc                        [8, 8, 8]         -1
# 15             []  0VgsIcsJLL                       [17, 3, 3]         -1
# 16             []  x38EHqIOQu          [15, 15, 15, 9, 15, 15]         -1
# 17             []  gstsWOFQLj                      [15, 11, 8]         -1
# 18             []  Sz2C93FXdu                        [8, 8, 8]         -1
# 19             []  dWcCbWa8nX                     [3, 3, 3, 3]         -1
# 20             []  DSfvfO4P8p                 [2, 2, 2, 11, 2]         -1
# 21             []  6L0PylKCUs                              [8]         -1
# 22             []  Pvq31iPEc6                           [9, 9]         -1
# 23             []  oBum3vWEFf                          [1, 11]         -1
# 24             []  Ja4m8mxDLR                     [13, 13, 13]         -1
# 25             []  t9nfvl8xDg                 [15, 15, 15, 11]         -1
# 26             []  07j5X77abG                     [8, 8, 8, 8]         -1
# 27             []  QRbcP9EHNX                     [12, 12, 11]         -1
# 28             []  cUDm7WAiV4         [10, 10, 10, 11, 11, 10]         -1
# 29             []  1J04lp2Xu0                      [15, 15, 9]         -1
# ...           ...         ...                              ...        ...
# 2946           []  mvoaK2VXE8                              [2]         -1
# 2947           []  GYWD4yZxBR                       [9, 2, 11]         -1
# 2948           []  CEPtXwoFot                           [3, 3]         -1
# 2949           []  kywBsUuC3j                     [13, 11, 13]         -1
# 2950           []  ENpx7Uq6YV        [9, 15, 9, 9, 15, 15, 15]         -1
# 2951           []  gvDB1fn6Lh                     [15, 15, 15]         -1
# 2952           []  uvdcRIlwLY               [8, 9, 8, 9, 8, 8]         -1
# 2953           []  lEnJ3xiYav                        [8, 8, 8]         -1
# 2954           []  Nlf2pGrIqV                           [8, 8]         -1
# 2955           []  8HbYU73sXo                  [3, 11, 14, 14]         -1
# 2956           []  EszqH01Grw                 [8, 8, 8, 9, 11]         -1
# 2957           []  vqvHDF8Isr                           [9, 9]         -1
# 2958           []  5smiMunmU4                     [10, 10, 10]         10
# 2959           []  rlSwI0qzpA                 [11, 8, 8, 8, 8]         -1
# 2960           []  aU1e5lNTLa                    [11, 8, 8, 9]         -1
# 2961           []  vZhJ5Qmx1e                             [10]         -1
# 2962           []  WArKbCVkUd                        [3, 3, 3]         -1
# 2963           []  f0kRAcubm0                     [12, 14, 14]         -1
# 2964           []  MocthqVAjG         [11, 18, 11, 18, 11, 11]         -1
# 2965           []  ufzHojr6j0                       [11, 7, 5]          7
# 2966           []  I6YipPOgIz                              [7]         -1
# 2967           []  2bgOJFs8fU                          [8, 11]         -1
# 2968           []  I5UAIeuAxK                  [8, 8, 8, 8, 8]         -1
# 2969           []  LwA2h5Rm3E                              [7]         -1
# 2970           []  TV28OxsWAR                              [8]         -1
# 2971           []  qTyiTZmRGu                         [11, 11]         13
# 2972           []  IKGRX9EFZe                              [8]         -1
# 2973           []  dbbyqotdem                     [8, 5, 8, 8]         -1
# 2974           []  WpFIXGl7EP                        [8, 8, 8]         -1
# 2975           []  1ls77Zbwak                    [15, 9, 9, 9]         -1
#
#      type                                            userIDs    zooID
# 0       T  [835158, 1498433, 637439, 239792, 132, 82, 227...  2210216
# 1       T                                           [239792]  2207683
