# %%
### Import standard functions ###
import os, time, csv, optparse
import numpy as np
from pylab import *
import json
import pandas as pd

# %%
#####################################
### Define command line arguments ###
#####################################
def parse_commandline():
    parser = optparse.OptionParser()
    parser.add_option("--file", help="Type in the path to the csv file \
    containing the classifications from the vet training set \
    workflow",default="example.csv")
    
    opts, args = parser.parse_args()
    
    return opts

#opts = parse_commandline()
class_file = "gravity-spy-classifications.csv"

# %%
### READ IN DATA ###
data = pd.read_csv(class_file, skiprows=29573, nrows=20008) # This starts with Beta 2.0
data = np.asarray(data)

# %%
IDmatch = np.genfromtxt('IDmatchall.txt',dtype='str',skip_header=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-327-89a1a49c9565> in <module>()
# ----> 1 IDmatch = np.genfromtxt('IDmatchall.txt',dtype='str',skip_header=1)
#
# C:\Users\Luke\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1764             # Raise an exception ?
#    1765             if invalid_raise:
# -> 1766                 raise ValueError(errmsg)
#    1767             # Issue a warning ?
#    1768             else:
#
# ValueError: Some errors were detected !
#     Line #36 (got 1 columns instead of 2)
#     Line #60 (got 1 columns instead of 2)
#     Line #62 (got 1 columns instead of 2)
#     Line #66 (got 1 columns instead of 2)
#     Line #68 (got 1 columns instead of 2)
#     Line #110 (got 1 columns instead of 2)
#     Line #170 (got 1 columns instead of 2)
#     Line #206 (got 1 columns instead of 2)
#     Line #208 (got 1 columns instead of 2)
#     Line #228 (got 1 columns instead of 2)
#     Line #236 (got 1 columns instead of 2)
#     Line #240 (got 1 columns instead of 2)
#     Line #252 (got 1 columns instead of 2)
#     Line #254 (got 1 columns instead of 2)
#     Line #270 (got 1 columns instead of 2)
#     Line #310 (got 1 columns instead of 2)
#     Line #366 (got 1 columns instead of 2)
#     Line #370 (got 1 columns instead of 2)
#     Line #372 (got 1 columns instead of 2)
#     Line #374 (got 1 columns instead of 2)
#     Line #400 (got 1 columns instead of 2)
#     Line #406 (got 1 columns instead of 2)
#     Line #424 (got 1 columns instead of 2)
#     Line #430 (got 1 columns instead of 2)
#     Line #458 (got 1 columns instead of 2)
#     Line #472 (got 1 columns instead of 2)
#     Line #482 (got 1 columns instead of 2)
#     Line #508 (got 1 columns instead of 2)
#     Line #518 (got 1 columns instead of 2)
#     Line #532 (got 1 columns instead of 2)
#     Line #538 (got 1 columns instead of 2)
#     Line #576 (got 1 columns instead of 2)
#     Line #584 (got 1 columns instead of 2)
#     Line #620 (got 1 columns instead of 2)
#     Line #622 (got 1 columns instead of 2)
#     Line #636 (got 1 columns instead of 2)
#     Line #644 (got 1 columns instead of 2)
#     Line #650 (got 1 columns instead of 2)
#     Line #676 (got 1 columns instead of 2)
#     Line #692 (got 1 columns instead of 2)
#     Line #708 (got 1 columns instead of 2)
#     Line #712 (got 1 columns instead of 2)
#     Line #726 (got 1 columns instead of 2)
#     Line #732 (got 1 columns instead of 2)
#     Line #734 (got 1 columns instead of 2)
#     Line #740 (got 1 columns instead of 2)
#     Line #752 (got 1 columns instead of 2)
#     Line #762 (got 1 columns instead of 2)
#     Line #780 (got 1 columns instead of 2)
#     Line #784 (got 1 columns instead of 2)
#     Line #790 (got 1 columns instead of 2)
#     Line #820 (got 1 columns instead of 2)
#     Line #830 (got 1 columns instead of 2)
#     Line #844 (got 1 columns instead of 2)
#     Line #856 (got 1 columns instead of 2)
#     Line #858 (got 1 columns instead of 2)
#     Line #860 (got 1 columns instead of 2)
#     Line #864 (got 1 columns instead of 2)
#     Line #874 (got 1 columns instead of 2)
#     Line #880 (got 1 columns instead of 2)
#     Line #894 (got 1 columns instead of 2)
#     Line #896 (got 1 columns instead of 2)
#     Line #906 (got 1 columns instead of 2)
#     Line #926 (got 1 columns instead of 2)
#     Line #938 (got 1 columns instead of 2)
#     Line #948 (got 1 columns instead of 2)
#     Line #962 (got 1 columns instead of 2)
#     Line #966 (got 1 columns instead of 2)
#     Line #984 (got 1 columns instead of 2)
#     Line #1004 (got 1 columns instead of 2)
#     Line #1012 (got 1 columns instead of 2)
#     Line #1016 (got 1 columns instead of 2)
#     Line #1028 (got 1 columns instead of 2)
#     Line #1032 (got 1 columns instead of 2)
#     Line #1050 (got 1 columns instead of 2)
#     Line #1054 (got 1 columns instead of 2)
#     Line #1072 (got 1 columns instead of 2)
#     Line #1074 (got 1 columns instead of 2)
#     Line #1120 (got 1 columns instead of 2)
#     Line #1130 (got 1 columns instead of 2)
#     Line #1144 (got 1 columns instead of 2)
#     Line #1152 (got 1 columns instead of 2)
#     Line #1158 (got 1 columns instead of 2)
#     Line #1162 (got 1 columns instead of 2)
#     Line #1166 (got 1 columns instead of 2)
#     Line #1176 (got 1 columns instead of 2)
#     Line #1192 (got 1 columns instead of 2)
#     Line #1228 (got 1 columns instead of 2)
#     Line #1238 (got 1 columns instead of 2)
#     Line #1240 (got 1 columns instead of 2)
#     Line #1250 (got 1 columns instead of 2)
#     Line #1266 (got 1 columns instead of 2)
#     Line #1324 (got 1 columns instead of 2)
#     Line #1330 (got 1 columns instead of 2)
#     Line #1336 (got 1 columns instead of 2)
#     Line #1352 (got 1 columns instead of 2)
#     Line #1356 (got 1 columns instead of 2)
#     Line #1360 (got 1 columns instead of 2)
#     Line #1374 (got 1 columns instead of 2)
#     Line #1378 (got 1 columns instead of 2)
#     Line #1380 (got 1 columns instead of 2)
#     Line #1392 (got 1 columns instead of 2)
#     Line #1400 (got 1 columns instead of 2)
#     Line #1408 (got 1 columns instead of 2)
#     Line #1416 (got 1 columns instead of 2)
#     Line #1426 (got 1 columns instead of 2)
#     Line #1436 (got 1 columns instead of 2)
#     Line #1442 (got 1 columns instead of 2)
#     Line #1462 (got 1 columns instead of 2)
#     Line #1468 (got 1 columns instead of 2)
#     Line #1470 (got 1 columns instead of 2)
#     Line #1480 (got 1 columns instead of 2)
#     Line #1496 (got 1 columns instead of 2)
#     Line #1514 (got 1 columns instead of 2)
#     Line #1520 (got 1 columns instead of 2)
#     Line #1526 (got 1 columns instead of 2)
#     Line #1564 (got 1 columns instead of 2)
#     Line #1568 (got 1 columns instead of 2)
#     Line #1574 (got 1 columns instead of 2)
#     Line #1590 (got 1 columns instead of 2)
#     Line #1614 (got 1 columns instead of 2)
#     Line #1616 (got 1 columns instead of 2)
#     Line #1630 (got 1 columns instead of 2)
#     Line #1652 (got 1 columns instead of 2)
#     Line #1662 (got 1 columns instead of 2)
#     Line #1668 (got 1 columns instead of 2)
#     Line #1674 (got 1 columns instead of 2)
#     Line #1688 (got 1 columns instead of 2)
#     Line #1696 (got 1 columns instead of 2)
#     Line #1718 (got 1 columns instead of 2)
#     Line #1730 (got 1 columns instead of 2)
#     Line #1758 (got 1 columns instead of 2)
#     Line #1764 (got 1 columns instead of 2)
#     Line #1778 (got 1 columns instead of 2)
#     Line #1818 (got 1 columns instead of 2)
#     Line #1824 (got 1 columns instead of 2)
#     Line #1848 (got 1 columns instead of 2)
#     Line #1858 (got 1 columns instead of 2)
#     Line #1912 (got 1 columns instead of 2)
#     Line #1936 (got 1 columns instead of 2)
#     Line #1942 (got 1 columns instead of 2)
#     Line #1944 (got 1 columns instead of 2)
#     Line #1958 (got 1 columns instead of 2)
#     Line #1976 (got 1 columns instead of 2)
#     Line #1984 (got 1 columns instead of 2)
#     Line #2016 (got 1 columns instead of 2)
#     Line #2018 (got 1 columns instead of 2)
#     Line #2066 (got 1 columns instead of 2)
#     Line #2086 (got 1 columns instead of 2)
#     Line #2092 (got 1 columns instead of 2)
#     Line #2134 (got 1 columns instead of 2)
#     Line #2136 (got 1 columns instead of 2)
#     Line #2182 (got 1 columns instead of 2)
#     Line #2198 (got 1 columns instead of 2)
#     Line #2214 (got 1 columns instead of 2)
#     Line #2232 (got 1 columns instead of 2)
#     Line #2242 (got 1 columns instead of 2)
#     Line #2296 (got 1 columns instead of 2)
#     Line #2318 (got 1 columns instead of 2)
#     Line #2326 (got 1 columns instead of 2)
#     Line #2334 (got 1 columns instead of 2)
#     Line #2340 (got 1 columns instead of 2)
#     Line #2352 (got 1 columns instead of 2)
#     Line #2358 (got 1 columns instead of 2)
#     Line #2366 (got 1 columns instead of 2)
#     Line #2376 (got 1 columns instead of 2)
#     Line #2406 (got 1 columns instead of 2)
#     Line #2416 (got 1 columns instead of 2)
#     Line #2418 (got 1 columns instead of 2)
#     Line #2424 (got 1 columns instead of 2)
#     Line #2436 (got 1 columns instead of 2)
#     Line #2462 (got 1 columns instead of 2)
#     Line #2466 (got 1 columns instead of 2)
#     Line #2496 (got 1 columns instead of 2)
#     Line #2506 (got 1 columns instead of 2)
#     Line #2550 (got 1 columns instead of 2)
#     Line #2554 (got 1 columns instead of 2)
#     Line #2560 (got 1 columns instead of 2)
#     Line #2576 (got 1 columns instead of 2)
#     Line #2618 (got 1 columns instead of 2)
#     Line #2626 (got 1 columns instead of 2)
#     Line #2680 (got 1 columns instead of 2)
#     Line #2732 (got 1 columns instead of 2)
#     Line #2736 (got 1 columns instead of 2)
#     Line #2750 (got 1 columns instead of 2)
#     Line #2758 (got 1 columns instead of 2)
#     Line #2766 (got 1 columns instead of 2)
#     Line #2784 (got 1 columns instead of 2)
#     Line #2786 (got 1 columns instead of 2)
#     Line #2790 (got 1 columns instead of 2)
#     Line #2824 (got 1 columns instead of 2)
#     Line #2826 (got 1 columns instead of 2)
#     Line #2836 (got 1 columns instead of 2)
#     Line #2850 (got 1 columns instead of 2)
#     Line #2862 (got 1 columns instead of 2)
#     Line #2868 (got 1 columns instead of 2)
#     Line #2884 (got 1 columns instead of 2)
#     Line #2888 (got 1 columns instead of 2)
#     Line #2902 (got 1 columns instead of 2)
#     Line #2920 (got 1 columns instead of 2)
#     Line #2940 (got 1 columns instead of 2)
#     Line #2942 (got 1 columns instead of 2)
#     Line #2958 (got 1 columns instead of 2)
#     Line #2968 (got 1 columns instead of 2)
#     Line #2976 (got 1 columns instead of 2)
#     Line #2978 (got 1 columns instead of 2)
#     Line #2980 (got 1 columns instead of 2)
#     Line #2984 (got 1 columns instead of 2)
#     Line #2990 (got 1 columns instead of 2)
#     Line #3010 (got 1 columns instead of 2)
#     Line #3038 (got 1 columns instead of 2)
#     Line #3046 (got 1 columns instead of 2)
#     Line #3050 (got 1 columns instead of 2)
#     Line #3056 (got 1 columns instead of 2)
#     Line #3068 (got 1 columns instead of 2)
#     Line #3078 (got 1 columns instead of 2)
#     Line #3082 (got 1 columns instead of 2)
#     Line #3192 (got 1 columns instead of 2)
#     Line #3202 (got 1 columns instead of 2)
#     Line #3272 (got 1 columns instead of 2)
#     Line #3274 (got 1 columns instead of 2)
#     Line #3306 (got 1 columns instead of 2)
#     Line #3328 (got 1 columns instead of 2)
#     Line #3342 (got 1 columns instead of 2)
#     Line #3350 (got 1 columns instead of 2)
#     Line #3356 (got 1 columns instead of 2)
#     Line #3358 (got 1 columns instead of 2)
#     Line #3386 (got 1 columns instead of 2)
#     Line #3388 (got 1 columns instead of 2)
#     Line #3402 (got 1 columns instead of 2)
#     Line #3412 (got 1 columns instead of 2)
#     Line #3422 (got 1 columns instead of 2)
#     Line #3424 (got 1 columns instead of 2)
#     Line #3432 (got 1 columns instead of 2)
#     Line #3478 (got 1 columns instead of 2)
#     Line #3480 (got 1 columns instead of 2)
#     Line #3492 (got 1 columns instead of 2)
#     Line #3502 (got 1 columns instead of 2)
#     Line #3504 (got 1 columns instead of 2)
#     Line #3512 (got 1 columns instead of 2)
#     Line #3524 (got 1 columns instead of 2)
#     Line #3526 (got 1 columns instead of 2)
#     Line #3532 (got 1 columns instead of 2)
#     Line #3534 (got 1 columns instead of 2)
#     Line #3540 (got 1 columns instead of 2)
#     Line #3572 (got 1 columns instead of 2)
#     Line #3614 (got 1 columns instead of 2)
#     Line #3626 (got 1 columns instead of 2)
#     Line #3640 (got 1 columns instead of 2)
#     Line #3646 (got 1 columns instead of 2)
#     Line #3688 (got 1 columns instead of 2)
#     Line #3728 (got 1 columns instead of 2)
#     Line #3734 (got 1 columns instead of 2)
#     Line #3774 (got 1 columns instead of 2)
#     Line #3780 (got 1 columns instead of 2)
#     Line #3784 (got 1 columns instead of 2)
#     Line #3790 (got 1 columns instead of 2)
#     Line #3838 (got 1 columns instead of 2)
#     Line #3870 (got 1 columns instead of 2)
#     Line #3874 (got 1 columns instead of 2)
#     Line #3886 (got 1 columns instead of 2)
#     Line #3890 (got 1 columns instead of 2)
#     Line #3892 (got 1 columns instead of 2)
#     Line #3896 (got 1 columns instead of 2)
#     Line #3930 (got 1 columns instead of 2)
#     Line #3936 (got 1 columns instead of 2)
#     Line #3948 (got 1 columns instead of 2)
#     Line #3980 (got 1 columns instead of 2)
#     Line #4032 (got 1 columns instead of 2)
#     Line #4034 (got 1 columns instead of 2)
#     Line #4050 (got 1 columns instead of 2)
#     Line #4060 (got 1 columns instead of 2)
#     Line #4082 (got 1 columns instead of 2)
#     Line #4098 (got 1 columns instead of 2)
#     Line #4102 (got 1 columns instead of 2)
#     Line #4106 (got 1 columns instead of 2)
#     Line #4108 (got 1 columns instead of 2)
#     Line #4110 (got 1 columns instead of 2)
#     Line #4118 (got 1 columns instead of 2)
#     Line #4138 (got 1 columns instead of 2)
#     Line #4158 (got 1 columns instead of 2)
#     Line #4170 (got 1 columns instead of 2)
#     Line #4206 (got 1 columns instead of 2)
#     Line #4234 (got 1 columns instead of 2)
#     Line #4240 (got 1 columns instead of 2)
#     Line #4254 (got 1 columns instead of 2)
#     Line #4276 (got 1 columns instead of 2)
#     Line #4280 (got 1 columns instead of 2)
#     Line #4288 (got 1 columns instead of 2)
#     Line #4296 (got 1 columns instead of 2)
#     Line #4340 (got 1 columns instead of 2)
#     Line #4344 (got 1 columns instead of 2)
#     Line #4352 (got 1 columns instead of 2)
#     Line #4358 (got 1 columns instead of 2)
#     Line #4384 (got 1 columns instead of 2)
#     Line #4408 (got 1 columns instead of 2)
#     Line #4410 (got 1 columns instead of 2)
#     Line #4430 (got 1 columns instead of 2)
#     Line #4458 (got 1 columns instead of 2)
#     Line #4468 (got 1 columns instead of 2)
#     Line #4478 (got 1 columns instead of 2)
#     Line #4482 (got 1 columns instead of 2)
#     Line #4508 (got 1 columns instead of 2)
#     Line #4512 (got 1 columns instead of 2)
#     Line #4518 (got 1 columns instead of 2)
#     Line #4548 (got 1 columns instead of 2)
#     Line #4554 (got 1 columns instead of 2)
#     Line #4574 (got 1 columns instead of 2)
#     Line #4586 (got 1 columns instead of 2)
#     Line #4638 (got 1 columns instead of 2)
#     Line #4650 (got 1 columns instead of 2)
#     Line #4654 (got 1 columns instead of 2)
#     Line #4666 (got 1 columns instead of 2)
#     Line #4740 (got 1 columns instead of 2)
#     Line #4750 (got 1 columns instead of 2)
#     Line #4772 (got 1 columns instead of 2)
#     Line #4824 (got 1 columns instead of 2)
#     Line #4854 (got 1 columns instead of 2)
#     Line #4856 (got 1 columns instead of 2)
#     Line #4860 (got 1 columns instead of 2)
#     Line #4862 (got 1 columns instead of 2)
#     Line #4864 (got 1 columns instead of 2)
#     Line #4866 (got 1 columns instead of 2)
#     Line #4876 (got 1 columns instead of 2)
#     Line #4880 (got 1 columns instead of 2)
#     Line #4894 (got 1 columns instead of 2)
#     Line #4906 (got 1 columns instead of 2)
#     Line #4914 (got 1 columns instead of 2)
#     Line #4926 (got 1 columns instead of 2)
#     Line #4956 (got 1 columns instead of 2)
#     Line #4962 (got 1 columns instead of 2)
#     Line #4970 (got 1 columns instead of 2)
#     Line #4972 (got 1 columns instead of 2)
#     Line #4994 (got 1 columns instead of 2)
#     Line #5014 (got 1 columns instead of 2)
#     Line #5028 (got 1 columns instead of 2)
#     Line #5038 (got 1 columns instead of 2)
#     Line #5040 (got 1 columns instead of 2)
#     Line #5066 (got 1 columns instead of 2)
#     Line #5072 (got 1 columns instead of 2)
#     Line #5076 (got 1 columns instead of 2)
#     Line #5078 (got 1 columns instead of 2)
#     Line #5086 (got 1 columns instead of 2)
#     Line #5132 (got 1 columns instead of 2)
#     Line #5152 (got 1 columns instead of 2)
#     Line #5154 (got 1 columns instead of 2)
#     Line #5160 (got 1 columns instead of 2)
#     Line #5162 (got 1 columns instead of 2)
#     Line #5168 (got 1 columns instead of 2)
#     Line #5170 (got 1 columns instead of 2)
#     Line #5212 (got 1 columns instead of 2)
#     Line #5216 (got 1 columns instead of 2)
#     Line #5230 (got 1 columns instead of 2)
#     Line #5242 (got 1 columns instead of 2)
#     Line #5246 (got 1 columns instead of 2)
#     Line #5260 (got 1 columns instead of 2)
#     Line #5264 (got 1 columns instead of 2)
#     Line #5278 (got 1 columns instead of 2)
#     Line #5288 (got 1 columns instead of 2)
#     Line #5292 (got 1 columns instead of 2)
#     Line #5298 (got 1 columns instead of 2)
#     Line #5310 (got 1 columns instead of 2)
#     Line #5312 (got 1 columns instead of 2)
#     Line #5358 (got 1 columns instead of 2)
#     Line #5368 (got 1 columns instead of 2)
#     Line #5390 (got 1 columns instead of 2)
#     Line #5398 (got 1 columns instead of 2)
#     Line #5414 (got 1 columns instead of 2)
#     Line #5418 (got 1 columns instead of 2)
#     Line #5448 (got 1 columns instead of 2)
#     Line #5454 (got 1 columns instead of 2)
#     Line #5468 (got 1 columns instead of 2)
#     Line #5488 (got 1 columns instead of 2)
#     Line #5490 (got 1 columns instead of 2)
#     Line #5506 (got 1 columns instead of 2)
#     Line #5512 (got 1 columns instead of 2)
#     Line #5526 (got 1 columns instead of 2)
#     Line #5530 (got 1 columns instead of 2)
#     Line #5560 (got 1 columns instead of 2)
#     Line #5566 (got 1 columns instead of 2)
#     Line #5582 (got 1 columns instead of 2)
#     Line #5590 (got 1 columns instead of 2)
#     Line #5596 (got 1 columns instead of 2)
#     Line #5608 (got 1 columns instead of 2)
#     Line #5620 (got 1 columns instead of 2)
#     Line #5622 (got 1 columns instead of 2)
#     Line #5668 (got 1 columns instead of 2)
#     Line #5690 (got 1 columns instead of 2)
#     Line #5698 (got 1 columns instead of 2)
#     Line #5706 (got 1 columns instead of 2)
#     Line #5718 (got 1 columns instead of 2)
#     Line #5730 (got 1 columns instead of 2)
#     Line #5744 (got 1 columns instead of 2)
#     Line #5810 (got 1 columns instead of 2)
#     Line #5818 (got 1 columns instead of 2)
#     Line #5820 (got 1 columns instead of 2)
#     Line #5844 (got 1 columns instead of 2)
#     Line #5848 (got 1 columns instead of 2)
#     Line #5864 (got 1 columns instead of 2)
#     Line #5886 (got 1 columns instead of 2)
#     Line #5900 (got 1 columns instead of 2)
#     Line #5902 (got 1 columns instead of 2)
#     Line #5916 (got 1 columns instead of 2)
#     Line #5928 (got 1 columns instead of 2)
#     Line #5996 (got 1 columns instead of 2)
#     Line #6014 (got 1 columns instead of 2)
#     Line #6032 (got 1 columns instead of 2)
#     Line #6034 (got 1 columns instead of 2)
#     Line #6088 (got 1 columns instead of 2)
#     Line #6104 (got 1 columns instead of 2)
#     Line #6138 (got 1 columns instead of 2)
#     Line #6140 (got 1 columns instead of 2)
#     Line #6158 (got 1 columns instead of 2)
#     Line #6172 (got 1 columns instead of 2)
#     Line #6182 (got 1 columns instead of 2)
#     Line #6184 (got 1 columns instead of 2)
#     Line #6192 (got 1 columns instead of 2)
#     Line #6194 (got 1 columns instead of 2)
#     Line #6200 (got 1 columns instead of 2)
#     Line #6202 (got 1 columns instead of 2)
#     Line #6226 (got 1 columns instead of 2)
#     Line #6238 (got 1 columns instead of 2)
#     Line #6252 (got 1 columns instead of 2)
#     Line #6256 (got 1 columns instead of 2)
#     Line #6268 (got 1 columns instead of 2)
#     Line #6276 (got 1 columns instead of 2)
#     Line #6286 (got 1 columns instead of 2)
#     Line #6314 (got 1 columns instead of 2)
#     Line #6348 (got 1 columns instead of 2)
#     Line #6352 (got 1 columns instead of 2)
#     Line #6376 (got 1 columns instead of 2)
#     Line #6404 (got 1 columns instead of 2)
#     Line #6420 (got 1 columns instead of 2)
#     Line #6430 (got 1 columns instead of 2)
#     Line #6456 (got 1 columns instead of 2)
#     Line #6466 (got 1 columns instead of 2)
#     Line #6472 (got 1 columns instead of 2)
#     Line #6530 (got 1 columns instead of 2)
#     Line #6558 (got 1 columns instead of 2)
#     Line #6614 (got 1 columns instead of 2)
#     Line #6636 (got 1 columns instead of 2)
#     Line #6654 (got 1 columns instead of 2)
#     Line #6680 (got 1 columns instead of 2)
#     Line #6690 (got 1 columns instead of 2)
#     Line #6732 (got 1 columns instead of 2)
#     Line #6746 (got 1 columns instead of 2)
#     Line #6748 (got 1 columns instead of 2)
#     Line #6760 (got 1 columns instead of 2)
#     Line #6772 (got 1 columns instead of 2)
#     Line #6788 (got 1 columns instead of 2)
#     Line #6798 (got 1 columns instead of 2)
#     Line #6800 (got 1 columns instead of 2)
#     Line #6802 (got 1 columns instead of 2)
#     Line #6846 (got 1 columns instead of 2)
#     Line #6878 (got 1 columns instead of 2)
#     Line #6890 (got 1 columns instead of 2)
#     Line #6912 (got 1 columns instead of 2)
#     Line #6920 (got 1 columns instead of 2)
#     Line #6922 (got 1 columns instead of 2)
#     Line #6928 (got 1 columns instead of 2)
#     Line #6930 (got 1 columns instead of 2)
#     Line #6948 (got 1 columns instead of 2)
#     Line #7008 (got 1 columns instead of 2)
#     Line #7010 (got 1 columns instead of 2)
#     Line #7032 (got 1 columns instead of 2)
#     Line #7036 (got 1 columns instead of 2)
#     Line #7050 (got 1 columns instead of 2)
#     Line #7106 (got 1 columns instead of 2)
#     Line #7112 (got 1 columns instead of 2)
#     Line #7120 (got 1 columns instead of 2)
#     Line #7122 (got 1 columns instead of 2)
#     Line #7144 (got 1 columns instead of 2)
#     Line #7160 (got 1 columns instead of 2)
#     Line #7170 (got 1 columns instead of 2)
#     Line #7202 (got 1 columns instead of 2)
#     Line #7214 (got 1 columns instead of 2)
#     Line #7234 (got 1 columns instead of 2)
#     Line #7236 (got 1 columns instead of 2)
#     Line #7252 (got 1 columns instead of 2)
#     Line #7254 (got 1 columns instead of 2)
#     Line #7272 (got 1 columns instead of 2)
#     Line #7300 (got 1 columns instead of 2)
#     Line #7326 (got 1 columns instead of 2)
#     Line #7330 (got 1 columns instead of 2)
#     Line #7334 (got 1 columns instead of 2)
#     Line #7362 (got 1 columns instead of 2)
#     Line #7398 (got 1 columns instead of 2)
#     Line #7400 (got 1 columns instead of 2)
#     Line #7406 (got 1 columns instead of 2)
#     Line #7416 (got 1 columns instead of 2)
#     Line #7428 (got 1 columns instead of 2)
#     Line #7436 (got 1 columns instead of 2)
#     Line #7440 (got 1 columns instead of 2)
#     Line #7486 (got 1 columns instead of 2)
#     Line #7492 (got 1 columns instead of 2)
#     Line #7510 (got 1 columns instead of 2)
#     Line #7516 (got 1 columns instead of 2)
#     Line #7540 (got 1 columns instead of 2)
#     Line #7554 (got 1 columns instead of 2)
#     Line #7556 (got 1 columns instead of 2)
#     Line #7594 (got 1 columns instead of 2)
#     Line #7606 (got 1 columns instead of 2)
#     Line #7614 (got 1 columns instead of 2)
#     Line #7616 (got 1 columns instead of 2)
#     Line #7662 (got 1 columns instead of 2)
#     Line #7680 (got 1 columns instead of 2)
#     Line #7700 (got 1 columns instead of 2)
#     Line #7720 (got 1 columns instead of 2)
#     Line #7728 (got 1 columns instead of 2)
#     Line #7732 (got 1 columns instead of 2)
#     Line #7744 (got 1 columns instead of 2)
#     Line #7750 (got 1 columns instead of 2)
#     Line #7760 (got 1 columns instead of 2)
#     Line #7798 (got 1 columns instead of 2)
#     Line #7830 (got 1 columns instead of 2)
#     Line #7882 (got 1 columns instead of 2)
#     Line #7894 (got 1 columns instead of 2)
#     Line #7896 (got 1 columns instead of 2)
#     Line #7912 (got 1 columns instead of 2)
#     Line #7914 (got 1 columns instead of 2)
#     Line #7918 (got 1 columns instead of 2)
#     Line #7926 (got 1 columns instead of 2)
#     Line #7946 (got 1 columns instead of 2)
#     Line #7976 (got 1 columns instead of 2)
#     Line #8006 (got 1 columns instead of 2)
#     Line #8016 (got 1 columns instead of 2)
#     Line #8028 (got 1 columns instead of 2)
#     Line #8036 (got 1 columns instead of 2)
#     Line #8058 (got 1 columns instead of 2)
#     Line #8064 (got 1 columns instead of 2)
#     Line #8068 (got 1 columns instead of 2)
#     Line #8088 (got 1 columns instead of 2)
#     Line #8092 (got 1 columns instead of 2)
#     Line #8110 (got 1 columns instead of 2)
#     Line #8126 (got 1 columns instead of 2)
#     Line #8152 (got 1 columns instead of 2)
#     Line #8154 (got 1 columns instead of 2)
#     Line #8180 (got 1 columns instead of 2)
#     Line #8200 (got 1 columns instead of 2)
#     Line #8202 (got 1 columns instead of 2)
#     Line #8230 (got 1 columns instead of 2)
#     Line #8248 (got 1 columns instead of 2)
#     Line #8296 (got 1 columns instead of 2)
#     Line #8298 (got 1 columns instead of 2)
#     Line #8336 (got 1 columns instead of 2)
#     Line #8374 (got 1 columns instead of 2)
#     Line #8376 (got 1 columns instead of 2)
#     Line #8386 (got 1 columns instead of 2)
#     Line #8394 (got 1 columns instead of 2)
#     Line #8402 (got 1 columns instead of 2)
#     Line #8414 (got 1 columns instead of 2)
#     Line #8420 (got 1 columns instead of 2)
#     Line #8430 (got 1 columns instead of 2)
#     Line #8434 (got 1 columns instead of 2)
#     Line #8436 (got 1 columns instead of 2)
#     Line #8438 (got 1 columns instead of 2)
#     Line #8454 (got 1 columns instead of 2)
#     Line #8474 (got 1 columns instead of 2)
#     Line #8478 (got 1 columns instead of 2)
#     Line #8494 (got 1 columns instead of 2)
#     Line #8498 (got 1 columns instead of 2)
#     Line #8522 (got 1 columns instead of 2)
#     Line #8526 (got 1 columns instead of 2)
#     Line #8536 (got 1 columns instead of 2)
#     Line #8540 (got 1 columns instead of 2)
#     Line #8556 (got 1 columns instead of 2)
#     Line #8602 (got 1 columns instead of 2)
#     Line #8608 (got 1 columns instead of 2)
#     Line #8616 (got 1 columns instead of 2)
#     Line #8644 (got 1 columns instead of 2)
#     Line #8676 (got 1 columns instead of 2)
#     Line #8688 (got 1 columns instead of 2)
#     Line #8692 (got 1 columns instead of 2)
#     Line #8714 (got 1 columns instead of 2)
#     Line #8742 (got 1 columns instead of 2)
#     Line #8798 (got 1 columns instead of 2)
#     Line #8806 (got 1 columns instead of 2)
#     Line #8830 (got 1 columns instead of 2)
#     Line #8836 (got 1 columns instead of 2)
#     Line #8838 (got 1 columns instead of 2)
#     Line #8840 (got 1 columns instead of 2)
#     Line #8842 (got 1 columns instead of 2)
#     Line #8846 (got 1 columns instead of 2)
#     Line #8848 (got 1 columns instead of 2)
#     Line #8862 (got 1 columns instead of 2)
#     Line #8886 (got 1 columns instead of 2)
#     Line #8902 (got 1 columns instead of 2)
#     Line #8908 (got 1 columns instead of 2)
#     Line #8910 (got 1 columns instead of 2)
#     Line #8938 (got 1 columns instead of 2)
#     Line #8940 (got 1 columns instead of 2)
#     Line #8944 (got 1 columns instead of 2)
#     Line #8970 (got 1 columns instead of 2)
#     Line #8986 (got 1 columns instead of 2)
#     Line #8992 (got 1 columns instead of 2)
#     Line #9012 (got 1 columns instead of 2)
#     Line #9024 (got 1 columns instead of 2)
#     Line #9056 (got 1 columns instead of 2)
#     Line #9108 (got 1 columns instead of 2)
#     Line #9156 (got 1 columns instead of 2)
#     Line #9226 (got 1 columns instead of 2)
#     Line #9238 (got 1 columns instead of 2)
#     Line #9240 (got 1 columns instead of 2)
#     Line #9314 (got 1 columns instead of 2)
#     Line #9328 (got 1 columns instead of 2)
#     Line #9342 (got 1 columns instead of 2)
#     Line #9348 (got 1 columns instead of 2)
#     Line #9380 (got 1 columns instead of 2)
#     Line #9412 (got 1 columns instead of 2)
#     Line #9484 (got 1 columns instead of 2)
#     Line #9488 (got 1 columns instead of 2)
#     Line #9490 (got 1 columns instead of 2)
#     Line #9492 (got 1 columns instead of 2)
#     Line #9496 (got 1 columns instead of 2)
#     Line #9508 (got 1 columns instead of 2)
#     Line #9514 (got 1 columns instead of 2)
#     Line #9516 (got 1 columns instead of 2)
#     Line #9524 (got 1 columns instead of 2)
#     Line #9530 (got 1 columns instead of 2)
#     Line #9540 (got 1 columns instead of 2)
#     Line #9562 (got 1 columns instead of 2)
#     Line #9592 (got 1 columns instead of 2)
#     Line #9608 (got 1 columns instead of 2)
#     Line #9626 (got 1 columns instead of 2)
#     Line #9632 (got 1 columns instead of 2)
#     Line #9646 (got 1 columns instead of 2)
#     Line #9690 (got 1 columns instead of 2)
#     Line #9730 (got 1 columns instead of 2)
#     Line #9786 (got 1 columns instead of 2)
#     Line #9788 (got 1 columns instead of 2)
#     Line #9790 (got 1 columns instead of 2)
#     Line #9812 (got 1 columns instead of 2)
#     Line #9814 (got 1 columns instead of 2)
#     Line #9820 (got 1 columns instead of 2)
#     Line #9826 (got 1 columns instead of 2)
#     Line #9828 (got 1 columns instead of 2)
#     Line #9832 (got 1 columns instead of 2)
#     Line #9926 (got 1 columns instead of 2)
#     Line #9928 (got 1 columns instead of 2)
#     Line #9932 (got 1 columns instead of 2)
#     Line #9934 (got 1 columns instead of 2)
#     Line #10000 (got 1 columns instead of 2)
#     Line #10030 (got 1 columns instead of 2)
#     Line #10052 (got 1 columns instead of 2)
#     Line #10054 (got 1 columns instead of 2)
#     Line #10060 (got 1 columns instead of 2)
#     Line #10062 (got 1 columns instead of 2)
#     Line #10078 (got 1 columns instead of 2)
#     Line #10092 (got 1 columns instead of 2)
#     Line #10094 (got 1 columns instead of 2)
#     Line #10108 (got 1 columns instead of 2)
#     Line #10110 (got 1 columns instead of 2)
#     Line #10112 (got 1 columns instead of 2)
#     Line #10174 (got 1 columns instead of 2)
#     Line #10188 (got 1 columns instead of 2)
#     Line #10192 (got 1 columns instead of 2)
#     Line #10218 (got 1 columns instead of 2)
#     Line #10260 (got 1 columns instead of 2)
#     Line #10294 (got 1 columns instead of 2)
#     Line #10304 (got 1 columns instead of 2)
#     Line #10322 (got 1 columns instead of 2)
#     Line #10330 (got 1 columns instead of 2)
#     Line #10334 (got 1 columns instead of 2)
#     Line #10372 (got 1 columns instead of 2)
#     Line #10374 (got 1 columns instead of 2)
#     Line #10386 (got 1 columns instead of 2)
#     Line #10394 (got 1 columns instead of 2)
#     Line #10434 (got 1 columns instead of 2)
#     Line #10450 (got 1 columns instead of 2)
#     Line #10460 (got 1 columns instead of 2)
#     Line #10462 (got 1 columns instead of 2)
#     Line #10476 (got 1 columns instead of 2)
#     Line #10498 (got 1 columns instead of 2)
#     Line #10516 (got 1 columns instead of 2)
#     Line #10522 (got 1 columns instead of 2)
#     Line #10540 (got 1 columns instead of 2)
#     Line #10550 (got 1 columns instead of 2)
#     Line #10568 (got 1 columns instead of 2)
#     Line #10580 (got 1 columns instead of 2)
#     Line #10602 (got 1 columns instead of 2)
#     Line #10604 (got 1 columns instead of 2)
#     Line #10606 (got 1 columns instead of 2)
#     Line #10614 (got 1 columns instead of 2)
#     Line #10620 (got 1 columns instead of 2)
#     Line #10642 (got 1 columns instead of 2)
#     Line #10660 (got 1 columns instead of 2)
#     Line #10692 (got 1 columns instead of 2)
#     Line #10706 (got 1 columns instead of 2)
#     Line #10724 (got 1 columns instead of 2)
#     Line #10750 (got 1 columns instead of 2)
#     Line #10880 (got 1 columns instead of 2)
#     Line #10906 (got 1 columns instead of 2)
#     Line #10912 (got 1 columns instead of 2)
#     Line #10932 (got 1 columns instead of 2)
#     Line #10936 (got 1 columns instead of 2)
#     Line #10946 (got 1 columns instead of 2)
#     Line #10970 (got 1 columns instead of 2)
#     Line #10976 (got 1 columns instead of 2)
#     Line #10998 (got 1 columns instead of 2)
#     Line #11032 (got 1 columns instead of 2)
#     Line #11038 (got 1 columns instead of 2)
#     Line #11046 (got 1 columns instead of 2)
#     Line #11050 (got 1 columns instead of 2)
#     Line #11066 (got 1 columns instead of 2)
#     Line #11124 (got 1 columns instead of 2)
#     Line #11148 (got 1 columns instead of 2)
#     Line #11152 (got 1 columns instead of 2)
#     Line #11196 (got 1 columns instead of 2)
#     Line #11210 (got 1 columns instead of 2)
#     Line #11222 (got 1 columns instead of 2)
#     Line #11240 (got 1 columns instead of 2)
#     Line #11250 (got 1 columns instead of 2)
#     Line #11262 (got 1 columns instead of 2)
#     Line #11274 (got 1 columns instead of 2)
#     Line #11290 (got 1 columns instead of 2)
#     Line #11294 (got 1 columns instead of 2)
#     Line #11300 (got 1 columns instead of 2)
#     Line #11302 (got 1 columns instead of 2)
#     Line #11316 (got 1 columns instead of 2)
#     Line #11318 (got 1 columns instead of 2)
#     Line #11350 (got 1 columns instead of 2)
#     Line #11374 (got 1 columns instead of 2)
#     Line #11378 (got 1 columns instead of 2)
#     Line #11396 (got 1 columns instead of 2)
#     Line #11418 (got 1 columns instead of 2)
#     Line #11472 (got 1 columns instead of 2)
#     Line #11478 (got 1 columns instead of 2)
#     Line #11488 (got 1 columns instead of 2)
#     Line #11494 (got 1 columns instead of 2)
#     Line #11498 (got 1 columns instead of 2)
#     Line #11510 (got 1 columns instead of 2)
#     Line #11526 (got 1 columns instead of 2)
#     Line #11544 (got 1 columns instead of 2)
#     Line #11576 (got 1 columns instead of 2)
#     Line #11598 (got 1 columns instead of 2)
#     Line #11614 (got 1 columns instead of 2)
#     Line #11622 (got 1 columns instead of 2)
#     Line #11632 (got 1 columns instead of 2)
#     Line #11638 (got 1 columns instead of 2)
#     Line #11650 (got 1 columns instead of 2)
#     Line #11660 (got 1 columns instead of 2)
#     Line #11670 (got 1 columns instead of 2)
#     Line #11682 (got 1 columns instead of 2)
#     Line #11696 (got 1 columns instead of 2)
#     Line #11722 (got 1 columns instead of 2)
#     Line #11740 (got 1 columns instead of 2)
#     Line #11744 (got 1 columns instead of 2)
#     Line #11792 (got 1 columns instead of 2)
#     Line #11816 (got 1 columns instead of 2)
#     Line #11820 (got 1 columns instead of 2)
#     Line #11826 (got 1 columns instead of 2)
#     Line #11914 (got 1 columns instead of 2)
#     Line #11918 (got 1 columns instead of 2)
#     Line #11938 (got 1 columns instead of 2)
#     Line #11940 (got 1 columns instead of 2)
#     Line #11962 (got 1 columns instead of 2)
#     Line #11982 (got 1 columns instead of 2)
#     Line #11990 (got 1 columns instead of 2)
#     Line #11996 (got 1 columns instead of 2)
#     Line #12018 (got 1 columns instead of 2)
#     Line #12024 (got 1 columns instead of 2)
#     Line #12036 (got 1 columns instead of 2)
#     Line #12044 (got 1 columns instead of 2)
#     Line #12048 (got 1 columns instead of 2)
#     Line #12056 (got 1 columns instead of 2)
#     Line #12070 (got 1 columns instead of 2)
#     Line #12084 (got 1 columns instead of 2)
#     Line #12100 (got 1 columns instead of 2)
#     Line #12112 (got 1 columns instead of 2)
#     Line #12134 (got 1 columns instead of 2)
#     Line #12138 (got 1 columns instead of 2)
#     Line #12166 (got 1 columns instead of 2)
#     Line #12220 (got 1 columns instead of 2)
#     Line #12230 (got 1 columns instead of 2)
#     Line #12246 (got 1 columns instead of 2)
#     Line #12264 (got 1 columns instead of 2)
#     Line #12270 (got 1 columns instead of 2)
#     Line #12274 (got 1 columns instead of 2)
#     Line #12342 (got 1 columns instead of 2)
#     Line #12380 (got 1 columns instead of 2)
#     Line #12386 (got 1 columns instead of 2)
#     Line #12392 (got 1 columns instead of 2)
#     Line #12398 (got 1 columns instead of 2)
#     Line #12406 (got 1 columns instead of 2)
#     Line #12410 (got 1 columns instead of 2)
#     Line #12418 (got 1 columns instead of 2)
#     Line #12426 (got 1 columns instead of 2)
#     Line #12430 (got 1 columns instead of 2)
#     Line #12506 (got 1 columns instead of 2)
#     Line #12546 (got 1 columns instead of 2)
#     Line #12550 (got 1 columns instead of 2)
#     Line #12554 (got 1 columns instead of 2)
#     Line #12558 (got 1 columns instead of 2)
#     Line #12562 (got 1 columns instead of 2)
#     Line #12568 (got 1 columns instead of 2)
#     Line #12586 (got 1 columns instead of 2)
#     Line #12594 (got 1 columns instead of 2)
#     Line #12608 (got 1 columns instead of 2)
#     Line #12620 (got 1 columns instead of 2)
#     Line #12622 (got 1 columns instead of 2)
#     Line #12630 (got 1 columns instead of 2)
#     Line #12660 (got 1 columns instead of 2)
#     Line #12682 (got 1 columns instead of 2)
#     Line #12726 (got 1 columns instead of 2)
#     Line #12760 (got 1 columns instead of 2)
#     Line #12762 (got 1 columns instead of 2)
#     Line #12784 (got 1 columns instead of 2)
#     Line #12808 (got 1 columns instead of 2)
#     Line #12828 (got 1 columns instead of 2)
#     Line #12832 (got 1 columns instead of 2)
#     Line #12842 (got 1 columns instead of 2)
#     Line #12856 (got 1 columns instead of 2)
#     Line #12870 (got 1 columns instead of 2)
#     Line #12884 (got 1 columns instead of 2)
#     Line #12888 (got 1 columns instead of 2)
#     Line #12890 (got 1 columns instead of 2)
#     Line #12892 (got 1 columns instead of 2)
#     Line #12906 (got 1 columns instead of 2)
#     Line #12914 (got 1 columns instead of 2)
#     Line #12930 (got 1 columns instead of 2)
#     Line #12932 (got 1 columns instead of 2)
#     Line #12948 (got 1 columns instead of 2)
#     Line #12954 (got 1 columns instead of 2)
#     Line #12964 (got 1 columns instead of 2)
#     Line #12970 (got 1 columns instead of 2)
#     Line #12976 (got 1 columns instead of 2)
#     Line #12978 (got 1 columns instead of 2)
#     Line #12996 (got 1 columns instead of 2)
#     Line #13002 (got 1 columns instead of 2)
#     Line #13044 (got 1 columns instead of 2)
#     Line #13080 (got 1 columns instead of 2)
#     Line #13086 (got 1 columns instead of 2)
#     Line #13094 (got 1 columns instead of 2)
#     Line #13098 (got 1 columns instead of 2)
#     Line #13100 (got 1 columns instead of 2)
#     Line #13102 (got 1 columns instead of 2)
#     Line #13106 (got 1 columns instead of 2)
#     Line #13146 (got 1 columns instead of 2)
#     Line #13154 (got 1 columns instead of 2)
#     Line #13246 (got 1 columns instead of 2)
#     Line #13300 (got 1 columns instead of 2)
#     Line #13302 (got 1 columns instead of 2)
#     Line #13304 (got 1 columns instead of 2)
#     Line #13348 (got 1 columns instead of 2)
#     Line #13352 (got 1 columns instead of 2)
#     Line #13366 (got 1 columns instead of 2)
#     Line #13464 (got 1 columns instead of 2)
#     Line #13494 (got 1 columns instead of 2)
#     Line #13504 (got 1 columns instead of 2)
#     Line #13514 (got 1 columns instead of 2)
#     Line #13548 (got 1 columns instead of 2)
#     Line #13550 (got 1 columns instead of 2)
#     Line #13564 (got 1 columns instead of 2)
#     Line #13590 (got 1 columns instead of 2)
#     Line #13604 (got 1 columns instead of 2)
#     Line #13618 (got 1 columns instead of 2)
#     Line #13634 (got 1 columns instead of 2)
#     Line #13644 (got 1 columns instead of 2)
#     Line #13668 (got 1 columns instead of 2)
#     Line #13680 (got 1 columns instead of 2)
#     Line #13690 (got 1 columns instead of 2)
#     Line #13696 (got 1 columns instead of 2)
#     Line #13700 (got 1 columns instead of 2)
#     Line #13746 (got 1 columns instead of 2)
#     Line #13754 (got 1 columns instead of 2)
#     Line #13762 (got 1 columns instead of 2)
#     Line #13780 (got 1 columns instead of 2)
#     Line #13806 (got 1 columns instead of 2)
#     Line #13852 (got 1 columns instead of 2)
#     Line #13854 (got 1 columns instead of 2)
#     Line #13858 (got 1 columns instead of 2)
#     Line #13862 (got 1 columns instead of 2)
#     Line #13894 (got 1 columns instead of 2)
#     Line #13916 (got 1 columns instead of 2)
#     Line #13954 (got 1 columns instead of 2)
#     Line #13994 (got 1 columns instead of 2)
#     Line #13998 (got 1 columns instead of 2)
#     Line #14022 (got 1 columns instead of 2)
#     Line #14024 (got 1 columns instead of 2)
#     Line #14048 (got 1 columns instead of 2)
#     Line #14060 (got 1 columns instead of 2)
#     Line #14086 (got 1 columns instead of 2)
#     Line #14102 (got 1 columns instead of 2)
#     Line #14110 (got 1 columns instead of 2)
#     Line #14132 (got 1 columns instead of 2)
#     Line #14138 (got 1 columns instead of 2)
#     Line #14156 (got 1 columns instead of 2)
#     Line #14162 (got 1 columns instead of 2)
#     Line #14176 (got 1 columns instead of 2)
#     Line #14180 (got 1 columns instead of 2)
#     Line #14196 (got 1 columns instead of 2)
#     Line #14212 (got 1 columns instead of 2)
#     Line #14230 (got 1 columns instead of 2)
#     Line #14240 (got 1 columns instead of 2)
#     Line #14244 (got 1 columns instead of 2)
#     Line #14256 (got 1 columns instead of 2)
#     Line #14286 (got 1 columns instead of 2)
#     Line #14304 (got 1 columns instead of 2)
#     Line #14326 (got 1 columns instead of 2)
#     Line #14344 (got 1 columns instead of 2)
#     Line #14380 (got 1 columns instead of 2)
#     Line #14386 (got 1 columns instead of 2)
#     Line #14392 (got 1 columns instead of 2)
#     Line #14456 (got 1 columns instead of 2)
#     Line #14460 (got 1 columns instead of 2)
#     Line #14474 (got 1 columns instead of 2)
#     Line #14476 (got 1 columns instead of 2)
#     Line #14494 (got 1 columns instead of 2)
#     Line #14506 (got 1 columns instead of 2)
#     Line #14544 (got 1 columns instead of 2)
#     Line #14546 (got 1 columns instead of 2)
#     Line #14576 (got 1 columns instead of 2)
#     Line #14602 (got 1 columns instead of 2)
#     Line #14618 (got 1 columns instead of 2)
#     Line #14642 (got 1 columns instead of 2)
#     Line #14650 (got 1 columns instead of 2)
#     Line #14660 (got 1 columns instead of 2)
#     Line #14678 (got 1 columns instead of 2)
#     Line #14680 (got 1 columns instead of 2)
#     Line #14692 (got 1 columns instead of 2)
#     Line #14708 (got 1 columns instead of 2)
#     Line #14716 (got 1 columns instead of 2)
#     Line #14746 (got 1 columns instead of 2)
#     Line #14748 (got 1 columns instead of 2)
#     Line #14750 (got 1 columns instead of 2)
#     Line #14764 (got 1 columns instead of 2)
#     Line #14786 (got 1 columns instead of 2)
#     Line #14792 (got 1 columns instead of 2)
#     Line #14804 (got 1 columns instead of 2)
#     Line #14824 (got 1 columns instead of 2)
#     Line #14836 (got 1 columns instead of 2)
#     Line #14842 (got 1 columns instead of 2)
#     Line #14848 (got 1 columns instead of 2)
#     Line #14854 (got 1 columns instead of 2)
#     Line #14856 (got 1 columns instead of 2)
#     Line #14868 (got 1 columns instead of 2)
#     Line #14878 (got 1 columns instead of 2)
#     Line #14910 (got 1 columns instead of 2)
#     Line #14968 (got 1 columns instead of 2)
#     Line #14980 (got 1 columns instead of 2)
#     Line #14988 (got 1 columns instead of 2)
#     Line #15062 (got 1 columns instead of 2)
#     Line #15080 (got 1 columns instead of 2)
#     Line #15090 (got 1 columns instead of 2)
#     Line #15150 (got 1 columns instead of 2)
#     Line #15162 (got 1 columns instead of 2)
#     Line #15174 (got 1 columns instead of 2)
#     Line #15178 (got 1 columns instead of 2)
#     Line #15180 (got 1 columns instead of 2)
#     Line #15226 (got 1 columns instead of 2)
#     Line #15234 (got 1 columns instead of 2)
#     Line #15252 (got 1 columns instead of 2)
#     Line #15266 (got 1 columns instead of 2)
#     Line #15270 (got 1 columns instead of 2)
#     Line #15272 (got 1 columns instead of 2)
#     Line #15290 (got 1 columns instead of 2)
#     Line #15300 (got 1 columns instead of 2)
#     Line #15348 (got 1 columns instead of 2)
#     Line #15352 (got 1 columns instead of 2)
#     Line #15358 (got 1 columns instead of 2)
#     Line #15362 (got 1 columns instead of 2)
#     Line #15368 (got 1 columns instead of 2)
#     Line #15382 (got 1 columns instead of 2)
#     Line #15390 (got 1 columns instead of 2)
#     Line #15436 (got 1 columns instead of 2)
#     Line #15440 (got 1 columns instead of 2)
#     Line #15446 (got 1 columns instead of 2)
#     Line #15448 (got 1 columns instead of 2)
#     Line #15450 (got 1 columns instead of 2)
#     Line #15458 (got 1 columns instead of 2)
#     Line #15478 (got 1 columns instead of 2)
#     Line #15484 (got 1 columns instead of 2)
#     Line #15496 (got 1 columns instead of 2)
#     Line #15524 (got 1 columns instead of 2)
#     Line #15530 (got 1 columns instead of 2)
#     Line #15538 (got 1 columns instead of 2)
#     Line #15560 (got 1 columns instead of 2)
#     Line #15596 (got 1 columns instead of 2)
#     Line #15598 (got 1 columns instead of 2)
#     Line #15622 (got 1 columns instead of 2)
#     Line #15638 (got 1 columns instead of 2)
#     Line #15650 (got 1 columns instead of 2)
#     Line #15652 (got 1 columns instead of 2)
#     Line #15654 (got 1 columns instead of 2)
#     Line #15664 (got 1 columns instead of 2)
#     Line #15680 (got 1 columns instead of 2)
#     Line #15686 (got 1 columns instead of 2)
#     Line #15740 (got 1 columns instead of 2)
#     Line #15744 (got 1 columns instead of 2)
#     Line #15746 (got 1 columns instead of 2)
#     Line #15750 (got 1 columns instead of 2)
#     Line #15770 (got 1 columns instead of 2)
#     Line #15776 (got 1 columns instead of 2)
#     Line #15782 (got 1 columns instead of 2)
#     Line #15810 (got 1 columns instead of 2)
#     Line #15814 (got 1 columns instead of 2)
#     Line #15838 (got 1 columns instead of 2)
#     Line #15840 (got 1 columns instead of 2)
#     Line #15868 (got 1 columns instead of 2)
#     Line #15880 (got 1 columns instead of 2)
#     Line #15896 (got 1 columns instead of 2)
#     Line #15920 (got 1 columns instead of 2)
#     Line #15942 (got 1 columns instead of 2)
#     Line #15950 (got 1 columns instead of 2)
#     Line #15968 (got 1 columns instead of 2)
#     Line #15990 (got 1 columns instead of 2)
#     Line #16016 (got 1 columns instead of 2)
#     Line #16024 (got 1 columns instead of 2)
#     Line #16032 (got 1 columns instead of 2)
#     Line #16050 (got 1 columns instead of 2)
#     Line #16052 (got 1 columns instead of 2)
#     Line #16180 (got 1 columns instead of 2)
#     Line #16272 (got 1 columns instead of 2)
#     Line #16274 (got 1 columns instead of 2)
#     Line #16284 (got 1 columns instead of 2)
#     Line #16288 (got 1 columns instead of 2)
#     Line #16290 (got 1 columns instead of 2)
#     Line #16302 (got 1 columns instead of 2)
#     Line #16358 (got 1 columns instead of 2)
#     Line #16376 (got 1 columns instead of 2)
#     Line #16384 (got 1 columns instead of 2)
#     Line #16406 (got 1 columns instead of 2)
#     Line #16512 (got 1 columns instead of 2)
#     Line #16532 (got 1 columns instead of 2)
#     Line #16562 (got 1 columns instead of 2)
#     Line #16594 (got 1 columns instead of 2)
#     Line #16596 (got 1 columns instead of 2)
#     Line #16600 (got 1 columns instead of 2)
#     Line #16608 (got 1 columns instead of 2)
#     Line #16628 (got 1 columns instead of 2)
#     Line #16640 (got 1 columns instead of 2)
#     Line #16662 (got 1 columns instead of 2)
#     Line #16680 (got 1 columns instead of 2)
#     Line #16684 (got 1 columns instead of 2)
#     Line #16704 (got 1 columns instead of 2)
#     Line #16720 (got 1 columns instead of 2)
#     Line #16730 (got 1 columns instead of 2)
#     Line #16736 (got 1 columns instead of 2)
#     Line #16740 (got 1 columns instead of 2)
#     Line #16748 (got 1 columns instead of 2)
#     Line #16752 (got 1 columns instead of 2)
#     Line #16812 (got 1 columns instead of 2)
#     Line #16816 (got 1 columns instead of 2)
#     Line #16822 (got 1 columns instead of 2)
#     Line #16846 (got 1 columns instead of 2)
#     Line #16850 (got 1 columns instead of 2)
#     Line #16854 (got 1 columns instead of 2)
#     Line #16860 (got 1 columns instead of 2)
#     Line #16864 (got 1 columns instead of 2)
#     Line #16872 (got 1 columns instead of 2)
#     Line #16894 (got 1 columns instead of 2)
#     Line #16898 (got 1 columns instead of 2)
#     Line #16914 (got 1 columns instead of 2)
#     Line #16932 (got 1 columns instead of 2)
#     Line #16936 (got 1 columns instead of 2)
#     Line #16942 (got 1 columns instead of 2)
#     Line #16944 (got 1 columns instead of 2)
#     Line #16946 (got 1 columns instead of 2)
#     Line #16964 (got 1 columns instead of 2)
#     Line #17018 (got 1 columns instead of 2)
#     Line #17024 (got 1 columns instead of 2)
#     Line #17026 (got 1 columns instead of 2)
#     Line #17038 (got 1 columns instead of 2)
# ...
#     Line #54946 (got 1 columns instead of 2)
#     Line #54994 (got 1 columns instead of 2)
#     Line #55030 (got 1 columns instead of 2)
#     Line #55058 (got 1 columns instead of 2)
#     Line #55062 (got 1 columns instead of 2)
#     Line #55074 (got 1 columns instead of 2)
#     Line #55134 (got 1 columns instead of 2)
#     Line #55180 (got 1 columns instead of 2)
#     Line #55192 (got 1 columns instead of 2)
#     Line #55196 (got 1 columns instead of 2)
#     Line #55256 (got 1 columns instead of 2)
#     Line #55308 (got 1 columns instead of 2)
#     Line #55386 (got 1 columns instead of 2)
#     Line #55404 (got 1 columns instead of 2)
#     Line #55416 (got 1 columns instead of 2)
#     Line #55428 (got 1 columns instead of 2)
#     Line #55442 (got 1 columns instead of 2)
#     Line #55464 (got 1 columns instead of 2)
#     Line #55472 (got 1 columns instead of 2)
#     Line #55494 (got 1 columns instead of 2)
#     Line #55500 (got 1 columns instead of 2)
#     Line #55508 (got 1 columns instead of 2)
#     Line #55518 (got 1 columns instead of 2)
#     Line #55582 (got 1 columns instead of 2)
#     Line #55586 (got 1 columns instead of 2)
#     Line #55588 (got 1 columns instead of 2)
#     Line #55600 (got 1 columns instead of 2)
#     Line #55602 (got 1 columns instead of 2)
#     Line #55754 (got 1 columns instead of 2)
#     Line #55762 (got 1 columns instead of 2)
#     Line #55802 (got 1 columns instead of 2)
#     Line #55814 (got 1 columns instead of 2)
#     Line #55824 (got 1 columns instead of 2)
#     Line #55840 (got 1 columns instead of 2)
#     Line #55856 (got 1 columns instead of 2)
#     Line #55858 (got 1 columns instead of 2)
#     Line #55884 (got 1 columns instead of 2)
#     Line #55896 (got 1 columns instead of 2)
#     Line #55902 (got 1 columns instead of 2)
#     Line #55904 (got 1 columns instead of 2)
#     Line #55916 (got 1 columns instead of 2)
#     Line #55936 (got 1 columns instead of 2)
#     Line #55954 (got 1 columns instead of 2)
#     Line #55962 (got 1 columns instead of 2)
#     Line #55974 (got 1 columns instead of 2)
#     Line #55986 (got 1 columns instead of 2)
#     Line #56002 (got 1 columns instead of 2)
#     Line #56010 (got 1 columns instead of 2)
#     Line #56020 (got 1 columns instead of 2)
#     Line #56032 (got 1 columns instead of 2)
#     Line #56052 (got 1 columns instead of 2)
#     Line #56068 (got 1 columns instead of 2)
#     Line #56072 (got 1 columns instead of 2)
#     Line #56088 (got 1 columns instead of 2)
#     Line #56116 (got 1 columns instead of 2)
#     Line #56148 (got 1 columns instead of 2)
#     Line #56154 (got 1 columns instead of 2)
#     Line #56172 (got 1 columns instead of 2)
#     Line #56174 (got 1 columns instead of 2)
#     Line #56190 (got 1 columns instead of 2)
#     Line #56218 (got 1 columns instead of 2)
#     Line #56242 (got 1 columns instead of 2)
#     Line #56304 (got 1 columns instead of 2)
#     Line #56318 (got 1 columns instead of 2)
#     Line #56350 (got 1 columns instead of 2)
#     Line #56372 (got 1 columns instead of 2)
#     Line #56392 (got 1 columns instead of 2)
#     Line #56422 (got 1 columns instead of 2)
#     Line #56426 (got 1 columns instead of 2)
#     Line #56464 (got 1 columns instead of 2)
#     Line #56482 (got 1 columns instead of 2)
#     Line #56484 (got 1 columns instead of 2)
#     Line #56516 (got 1 columns instead of 2)
#     Line #56518 (got 1 columns instead of 2)
#     Line #56568 (got 1 columns instead of 2)
#     Line #56570 (got 1 columns instead of 2)
#     Line #56586 (got 1 columns instead of 2)
#     Line #56614 (got 1 columns instead of 2)
#     Line #56700 (got 1 columns instead of 2)
#     Line #56702 (got 1 columns instead of 2)
#     Line #56722 (got 1 columns instead of 2)
#     Line #56744 (got 1 columns instead of 2)
#     Line #56782 (got 1 columns instead of 2)
#     Line #56794 (got 1 columns instead of 2)
#     Line #56852 (got 1 columns instead of 2)
#     Line #56858 (got 1 columns instead of 2)
#     Line #56942 (got 1 columns instead of 2)
#     Line #56962 (got 1 columns instead of 2)
#     Line #56992 (got 1 columns instead of 2)
#     Line #57006 (got 1 columns instead of 2)
#     Line #57010 (got 1 columns instead of 2)
#     Line #57030 (got 1 columns instead of 2)
#     Line #57032 (got 1 columns instead of 2)
#     Line #57070 (got 1 columns instead of 2)
#     Line #57076 (got 1 columns instead of 2)
#     Line #57082 (got 1 columns instead of 2)
#     Line #57120 (got 1 columns instead of 2)
#     Line #57124 (got 1 columns instead of 2)
#     Line #57144 (got 1 columns instead of 2)
#     Line #57146 (got 1 columns instead of 2)
#     Line #57166 (got 1 columns instead of 2)
#     Line #57200 (got 1 columns instead of 2)
#     Line #57210 (got 1 columns instead of 2)
#     Line #57260 (got 1 columns instead of 2)
#     Line #57270 (got 1 columns instead of 2)
#     Line #57274 (got 1 columns instead of 2)
#     Line #57286 (got 1 columns instead of 2)
#     Line #57288 (got 1 columns instead of 2)
#     Line #57326 (got 1 columns instead of 2)
#     Line #57330 (got 1 columns instead of 2)
#     Line #57338 (got 1 columns instead of 2)
#     Line #57350 (got 1 columns instead of 2)
#     Line #57356 (got 1 columns instead of 2)
#     Line #57384 (got 1 columns instead of 2)
#     Line #57414 (got 1 columns instead of 2)
#     Line #57422 (got 1 columns instead of 2)
#     Line #57450 (got 1 columns instead of 2)
#     Line #57464 (got 1 columns instead of 2)
#     Line #57482 (got 1 columns instead of 2)
#     Line #57486 (got 1 columns instead of 2)
#     Line #57516 (got 1 columns instead of 2)
#     Line #57568 (got 1 columns instead of 2)
#     Line #57578 (got 1 columns instead of 2)
#     Line #57588 (got 1 columns instead of 2)
#     Line #57656 (got 1 columns instead of 2)
#     Line #57686 (got 1 columns instead of 2)
#     Line #57710 (got 1 columns instead of 2)
#     Line #57734 (got 1 columns instead of 2)
#     Line #57744 (got 1 columns instead of 2)
#     Line #57768 (got 1 columns instead of 2)
#     Line #57778 (got 1 columns instead of 2)
#     Line #57788 (got 1 columns instead of 2)
#     Line #57790 (got 1 columns instead of 2)
#     Line #57844 (got 1 columns instead of 2)
#     Line #57850 (got 1 columns instead of 2)
#     Line #57854 (got 1 columns instead of 2)
#     Line #57926 (got 1 columns instead of 2)
#     Line #57944 (got 1 columns instead of 2)
#     Line #57956 (got 1 columns instead of 2)
#     Line #57964 (got 1 columns instead of 2)
#     Line #58014 (got 1 columns instead of 2)
#     Line #58024 (got 1 columns instead of 2)
#     Line #58026 (got 1 columns instead of 2)
#     Line #58062 (got 1 columns instead of 2)
#     Line #58068 (got 1 columns instead of 2)
#     Line #58088 (got 1 columns instead of 2)
#     Line #58110 (got 1 columns instead of 2)
#     Line #58122 (got 1 columns instead of 2)
#     Line #58130 (got 1 columns instead of 2)
#     Line #58174 (got 1 columns instead of 2)
#     Line #58182 (got 1 columns instead of 2)
#     Line #58196 (got 1 columns instead of 2)
#     Line #58222 (got 1 columns instead of 2)
#     Line #58242 (got 1 columns instead of 2)
#     Line #58272 (got 1 columns instead of 2)
#     Line #58306 (got 1 columns instead of 2)
#     Line #58316 (got 1 columns instead of 2)
#     Line #58366 (got 1 columns instead of 2)
#     Line #58384 (got 1 columns instead of 2)
#     Line #58402 (got 1 columns instead of 2)
#     Line #58412 (got 1 columns instead of 2)
#     Line #58448 (got 1 columns instead of 2)
#     Line #58454 (got 1 columns instead of 2)
#     Line #58462 (got 1 columns instead of 2)
#     Line #58482 (got 1 columns instead of 2)
#     Line #58496 (got 1 columns instead of 2)
#     Line #58512 (got 1 columns instead of 2)
#     Line #58542 (got 1 columns instead of 2)
#     Line #58544 (got 1 columns instead of 2)
#     Line #58586 (got 1 columns instead of 2)
#     Line #58614 (got 1 columns instead of 2)
#     Line #58674 (got 1 columns instead of 2)
#     Line #58700 (got 1 columns instead of 2)
#     Line #58706 (got 1 columns instead of 2)
#     Line #58718 (got 1 columns instead of 2)
#     Line #58738 (got 1 columns instead of 2)
#     Line #58882 (got 1 columns instead of 2)
#     Line #58922 (got 1 columns instead of 2)
#     Line #58932 (got 1 columns instead of 2)
#     Line #58948 (got 1 columns instead of 2)
#     Line #59000 (got 1 columns instead of 2)
#     Line #59010 (got 1 columns instead of 2)
#     Line #59014 (got 1 columns instead of 2)
#     Line #59018 (got 1 columns instead of 2)
#     Line #59028 (got 1 columns instead of 2)
#     Line #59056 (got 1 columns instead of 2)
#     Line #59078 (got 1 columns instead of 2)
#     Line #59114 (got 1 columns instead of 2)
#     Line #59140 (got 1 columns instead of 2)
#     Line #59170 (got 1 columns instead of 2)
#     Line #59250 (got 1 columns instead of 2)
#     Line #59252 (got 1 columns instead of 2)
#     Line #59286 (got 1 columns instead of 2)
#     Line #59292 (got 1 columns instead of 2)
#     Line #59306 (got 1 columns instead of 2)
#     Line #59322 (got 1 columns instead of 2)
#     Line #59330 (got 1 columns instead of 2)
#     Line #59378 (got 1 columns instead of 2)
#     Line #59418 (got 1 columns instead of 2)
#     Line #59430 (got 1 columns instead of 2)
#     Line #59448 (got 1 columns instead of 2)
#     Line #59456 (got 1 columns instead of 2)
#     Line #59462 (got 1 columns instead of 2)
#     Line #59478 (got 1 columns instead of 2)
#     Line #59506 (got 1 columns instead of 2)
#     Line #59528 (got 1 columns instead of 2)
#     Line #59542 (got 1 columns instead of 2)
#     Line #59572 (got 1 columns instead of 2)
#     Line #59606 (got 1 columns instead of 2)
#     Line #59644 (got 1 columns instead of 2)
#     Line #59664 (got 1 columns instead of 2)
#     Line #59668 (got 1 columns instead of 2)
#     Line #59688 (got 1 columns instead of 2)
#     Line #59706 (got 1 columns instead of 2)
#     Line #59710 (got 1 columns instead of 2)
#     Line #59714 (got 1 columns instead of 2)
#     Line #59720 (got 1 columns instead of 2)
#     Line #59722 (got 1 columns instead of 2)
#     Line #59746 (got 1 columns instead of 2)
#     Line #59792 (got 1 columns instead of 2)
#     Line #59864 (got 1 columns instead of 2)
#     Line #59874 (got 1 columns instead of 2)
#     Line #59896 (got 1 columns instead of 2)
#     Line #59898 (got 1 columns instead of 2)
#     Line #59916 (got 1 columns instead of 2)
#     Line #59954 (got 1 columns instead of 2)
#     Line #59964 (got 1 columns instead of 2)
#     Line #60056 (got 1 columns instead of 2)
#     Line #60084 (got 1 columns instead of 2)
#     Line #60136 (got 1 columns instead of 2)
#     Line #60154 (got 1 columns instead of 2)
#     Line #60156 (got 1 columns instead of 2)
#     Line #60168 (got 1 columns instead of 2)
#     Line #60206 (got 1 columns instead of 2)
#     Line #60210 (got 1 columns instead of 2)
#     Line #60246 (got 1 columns instead of 2)
#     Line #60258 (got 1 columns instead of 2)
#     Line #60262 (got 1 columns instead of 2)
#     Line #60302 (got 1 columns instead of 2)
#     Line #60314 (got 1 columns instead of 2)
#     Line #60360 (got 1 columns instead of 2)
#     Line #60368 (got 1 columns instead of 2)
#     Line #60392 (got 1 columns instead of 2)
#     Line #60456 (got 1 columns instead of 2)
#     Line #60482 (got 1 columns instead of 2)
#     Line #60518 (got 1 columns instead of 2)
#     Line #60538 (got 1 columns instead of 2)
#     Line #60556 (got 1 columns instead of 2)
#     Line #60558 (got 1 columns instead of 2)
#     Line #60596 (got 1 columns instead of 2)
#     Line #60612 (got 1 columns instead of 2)
#     Line #60630 (got 1 columns instead of 2)
#     Line #60742 (got 1 columns instead of 2)
#     Line #60744 (got 1 columns instead of 2)
#     Line #60766 (got 1 columns instead of 2)
#     Line #60852 (got 1 columns instead of 2)
#     Line #60860 (got 1 columns instead of 2)
#     Line #60874 (got 1 columns instead of 2)
#     Line #60936 (got 1 columns instead of 2)
#     Line #60952 (got 1 columns instead of 2)
#     Line #60972 (got 1 columns instead of 2)
#     Line #60990 (got 1 columns instead of 2)
#     Line #61000 (got 1 columns instead of 2)
#     Line #61022 (got 1 columns instead of 2)
#     Line #61050 (got 1 columns instead of 2)
#     Line #61056 (got 1 columns instead of 2)
#     Line #61092 (got 1 columns instead of 2)
#     Line #61128 (got 1 columns instead of 2)
#     Line #61160 (got 1 columns instead of 2)
#     Line #61188 (got 1 columns instead of 2)
#     Line #61234 (got 1 columns instead of 2)
#     Line #61244 (got 1 columns instead of 2)
#     Line #61258 (got 1 columns instead of 2)
#     Line #61296 (got 1 columns instead of 2)
#     Line #61298 (got 1 columns instead of 2)
#     Line #61320 (got 1 columns instead of 2)
#     Line #61326 (got 1 columns instead of 2)
#     Line #61384 (got 1 columns instead of 2)
#     Line #61396 (got 1 columns instead of 2)
#     Line #61398 (got 1 columns instead of 2)
#     Line #61402 (got 1 columns instead of 2)
#     Line #61428 (got 1 columns instead of 2)
#     Line #61440 (got 1 columns instead of 2)
#     Line #61460 (got 1 columns instead of 2)
#     Line #61470 (got 1 columns instead of 2)
#     Line #61490 (got 1 columns instead of 2)
#     Line #61496 (got 1 columns instead of 2)
#     Line #61526 (got 1 columns instead of 2)
#     Line #61528 (got 1 columns instead of 2)
#     Line #61534 (got 1 columns instead of 2)
#     Line #61536 (got 1 columns instead of 2)
#     Line #61540 (got 1 columns instead of 2)
#     Line #61542 (got 1 columns instead of 2)
#     Line #61550 (got 1 columns instead of 2)
#     Line #61586 (got 1 columns instead of 2)
#     Line #61598 (got 1 columns instead of 2)
#     Line #61628 (got 1 columns instead of 2)
#     Line #61650 (got 1 columns instead of 2)
#     Line #61656 (got 1 columns instead of 2)
#     Line #61682 (got 1 columns instead of 2)
#     Line #61706 (got 1 columns instead of 2)
#     Line #61710 (got 1 columns instead of 2)
#     Line #61728 (got 1 columns instead of 2)
#     Line #61756 (got 1 columns instead of 2)
#     Line #61762 (got 1 columns instead of 2)
#     Line #61786 (got 1 columns instead of 2)
#     Line #61794 (got 1 columns instead of 2)
#     Line #61842 (got 1 columns instead of 2)
#     Line #61858 (got 1 columns instead of 2)
#     Line #61868 (got 1 columns instead of 2)
#     Line #61886 (got 1 columns instead of 2)
#     Line #61914 (got 1 columns instead of 2)
#     Line #61932 (got 1 columns instead of 2)
#     Line #61998 (got 1 columns instead of 2)
#     Line #62002 (got 1 columns instead of 2)
#     Line #62004 (got 1 columns instead of 2)
#     Line #62018 (got 1 columns instead of 2)
#     Line #62044 (got 1 columns instead of 2)
#     Line #62062 (got 1 columns instead of 2)
#     Line #62116 (got 1 columns instead of 2)
#     Line #62142 (got 1 columns instead of 2)
#     Line #62162 (got 1 columns instead of 2)
#     Line #62164 (got 1 columns instead of 2)
#     Line #62170 (got 1 columns instead of 2)
#     Line #62176 (got 1 columns instead of 2)
#     Line #62198 (got 1 columns instead of 2)
#     Line #62232 (got 1 columns instead of 2)
#     Line #62250 (got 1 columns instead of 2)
#     Line #62308 (got 1 columns instead of 2)
#     Line #62334 (got 1 columns instead of 2)
#     Line #62346 (got 1 columns instead of 2)
#     Line #62360 (got 1 columns instead of 2)
#     Line #62368 (got 1 columns instead of 2)
#     Line #62374 (got 1 columns instead of 2)
#     Line #62378 (got 1 columns instead of 2)
#     Line #62388 (got 1 columns instead of 2)
#     Line #62404 (got 1 columns instead of 2)
#     Line #62412 (got 1 columns instead of 2)
#     Line #62422 (got 1 columns instead of 2)
#     Line #62428 (got 1 columns instead of 2)
#     Line #62432 (got 1 columns instead of 2)
#     Line #62506 (got 1 columns instead of 2)
#     Line #62512 (got 1 columns instead of 2)
#     Line #62538 (got 1 columns instead of 2)
#     Line #62570 (got 1 columns instead of 2)
#     Line #62586 (got 1 columns instead of 2)
#     Line #62626 (got 1 columns instead of 2)
#     Line #62638 (got 1 columns instead of 2)
#     Line #62648 (got 1 columns instead of 2)
#     Line #62670 (got 1 columns instead of 2)
#     Line #62692 (got 1 columns instead of 2)
#     Line #62702 (got 1 columns instead of 2)
#     Line #62714 (got 1 columns instead of 2)
#     Line #62740 (got 1 columns instead of 2)
#     Line #62760 (got 1 columns instead of 2)

# %%
### READ FILE FOR CONVERTING imageIDs ###
id_match = pd.read_csv('IDmatchall.txt') #read in file
tmp_new = []
tmp_old = []
no_match = [] #list of imageIDs with no match (timestamp errors)
id_dict = {} #empty dict for converting imageIDs

for i in id_match['# New       Old']:
    if len(i)>10:
        i = i.split(' ')
        tmp_new.append(i[0])
        tmp_old.append(i[1])

id_match = pd.DataFrame({'new':tmp_new,'old':tmp_old})

for a,b in zip(id_match['new'],id_match['old']):
    id_dict[b] = a
# Out:
#               new         old
# 0      tav4WFOGcM  xoayp726e4
# 1      r9NzEPDi5W  1wXbvs8OVh
# 2      lBpeig0TzZ  Jm2alELkJm
# 3      0bZgeIRomd  Rd1MVGtQey
# 4      yi4dXmHhzZ  Yvoh4OoHwT
# 5      VRzf8J2CF6  0nBG4qHDUW
# 6      3m6D1sfq1n  p0rIPeN1l4
# 7      TTv2Dut6Al  AXO15HOYra
# 8      UGNwkGKD3e  DBGM4wV4d2
# 9      Q9ouOyHgMD  Bzz176XBUX
# 10     4Xow1SgUNq  eYunaMz21d
# 11     PWwqcdRdtl  r60pB6D7Ca
# 12     L4SjwEV9x4  pNWBIdkHOy
# 13     64ENUOUuRN  vQ9xo5LZ1i
# 14     UzS68djamd  W6v4KgZPKr
# 15     uOz5dLHymj  5mnLHbE4hG
# 16     0IfMGlWSqa  FtGZJdNoOZ
# 17     cV7RIbmCQH  QOfe5VqnHV
# 18     WfALfz0qk3  A6bXld6bbm
# 19     gvyOyTLK1u  FCBFaTqYz8
# 20     OIlve2fRYd  3yvPRKIaqa
# 21     3GWbxIGVLp  1cSG7xAc7N
# 22     mTELQsJMiU  5N33O48QmW
# 23     XKvLniCq7c  kKHChAODtL
# 24     h1afrT2YFU  lUyrPM7IiP
# 25     L9tMI30hw4  B0A6dxvcfw
# 26     PJ62Nao5Pn  hnIbBSwS32
# 27     K4gsIqdhfk  NnxtA4ga1G
# 28     UPSUPBhyDV  gsapSKJxVF
# 29     Pz927ABPEz  sQnFZ75c9M
# ...           ...         ...
# 28125  PUqaUUtg7T  mor9t0FJ0g
# 28126  lwbKLNbmU2  nbbL0gxL50
# 28127  y27U8ysb1c  mXlynm2Y5f
# 28128  JIpxeXZ9f7  Idvo1ie4gO
# 28129  egKOef8LmR  eMPFl1UGII
# 28130  guvoJL2CFG  cWGRfdH3Fs
# 28131  Exc8xc7TWh  YHD2OcIHpc
# 28132  M6TniK4KtU  nLl2fG0Xjx
# 28133  bq4eYLKBsN  qcw44ri6MR
# 28134  Z9my6e13SL  Rfj9ylBYgi
# 28135  lLQOMS7oAY  2aWXVqqudn
# 28136  7p2PVmpgJU  gR2dT1EEnF
# 28137  WLjGhl7kio  a4nSGnOrzF
# 28138  DuRHp8poiQ  bmQJwhHIKx
# 28139  dUqMPxm2FL  tbvL1lgFOB
# 28140  vkKqH9vU2e  dwV5fs3jYZ
# 28141  9z8yKEYbd2  sM7Cj7an0Y
# 28142  RGXN3p3yGH  VXEgZg5SdR
# 28143  1PgxlUUA7V  nPgkEZm9Hx
# 28144  TlJg6WMcXY  d6bHgyfJ0c
# 28145  p0R39H6edM  6afFwLU8Au
# 28146  hKkCNCZ6QL  IW1E9SubA2
# 28147  4rM0NMrJsz  oljgSuR0HN
# 28148  GIUIQkeWzg  MuJL3EjO3i
# 28149  EYauNgR9VM  RRQnFMQIbn
# 28150  xyQtZcTjzL  dtYOnLDiIn
# 28151  XSVGi2P717  hlXcGEltBX
# 28152  mY8eM0JdUT  j82UjrNe9f
# 28153  vufBsTzro8  DWPh0G2PkS
# 28154  e0DtDFLaS7  hBxPGenVIC
#
# [28155 rows x 2 columns]

# %%
### APPEND ALL PERTINENT DATA TO LIST ###

tmp_user= []
tmp_user_id = []
tmp_workflow = []
tmp_task = []
tmp_choice = []
tmp_retired = []
tmp_unique_id = []
for i in range(len(data)):
    # create list to hold to output information of each classification
    output = []
    # Check that there was only 1 choice made...
    annotations = json.loads(data[i][11])
    idcheck = data[i][2]
    if str(annotations).count('choice') == 1 and not np.isnan(idcheck):
        user = data[i,1]
        user_id = data[i,2]
        workflow = data[i,5]
        
        # annotations
        task = annotations[0]["task"]
        choice = annotations[0]["value"][0]["choice"]
        
        # subject data
        subject_data = json.loads(data[i][12])
        for key in subject_data:
            zoo_id = key
            retired = subject_data[key]['retired']
            unique_id = subject_data[key]['subject_id']
        
        # Append this information into a temporary output file
        tmp_user_id.append(user_id)
        tmp_workflow.append(workflow)
        tmp_task.append(task)
        tmp_choice.append(choice)
        tmp_retired.append(retired)
        tmp_unique_id.append(unique_id)
        
# Store each of the classification data
classifications = pd.DataFrame({'imageID':tmp_unique_id,'userID':tmp_user_id,'workflow':tmp_workflow,'task':tmp_task,'label':tmp_choice,'type':tmp_retired})

# %%
print(id_dict.keys())
# Out:
# dict_keys(['n2Y4r1cm9p', 'x4NJbj3Xyz', 'fEZerQcXTK', 'W2kD7qKwkJ', '8pfeqVkFaE', '2WkrM8ileC', 'fW9B1OvZk8', 'MWV25zOYIl', 'nMq1jFddZ8', 'DocGNGpOsu', 'ehs1rsmSKa', 'ZvFautSrA8', 'tBf2l4Cwem', 'WsZ0Mejuh1', 'YGkn89SC68', 'AqEUTf0bt1', 'huIm6gcxKO', 'v9PZPfnFcR', 'HFBvUq4CAQ', 'BGkdXIJMev', 'aqCJo60754', 'BZTEA8PPUO', 'mrnD0KxZ0Z', '9Vlb8gCU85', 'LO3PJ01qXG', '3rnVhkxQLP', '89yp8z0QnU', '2Jalz7eLkv', 'QWfQihV2Sp', 'PQYPkOYhxH', 'n5NRrjpDcP', 'GXDqAHrmjW', 'w8Oto4EOvo', 'ZgfvN5QadL', 'dBg9UqH1dS', 'ZU6RubOHZ7', 'NVhvYSFe0Y', '2EbP83UcWY', 'oh023XPXyr', '9eoOEMgTc5', 'MhtK6Z72Sa', 'eca2Xq0n6N', 'y2z3wDjAV8', 'ifQbCTdSa2', 'SAVmteq965', 'ZkT3a7QCfe', 'gpP8oXVSg8', '9nPjOYDjRD', 'Noc75tHYDC', 'YKhpioD7kl', 'DzvTBhPAZp', 'odq2LhlW0L', 'ex0KBkoD2j', '9nAzyjGdgb', 'axfzQCQWjd', 'cxhdzsBj5I', 'ptCp12vB67', 'dPccE3WXCb', '2XRCzur3OE', 'AoxHTsPn8w', 'EPYF7hjHYa', 'NBvGP5pYOx', 'tpK300kZmm', 'nBXZTlJlJR', 'VSxPj7vsBf', 'Tms07Z1ski', '7HGhYMU5NR', 'ypYqZtFd91', 'Tg9C6EZRkz', 'QRCdJud56Q', 'Ozps9hKHYk', 'BRxMRoEs15', 'wxnHTpi1fj', 'iAhGe7eqTC', 'NmDDGh61WW', 'Nw4b6mzLES', 'nVDQQoM9Hx', 'tWzUSy0WRy', '4YUpv5lscj', 'V1Az5rMkuu', '3umh0HehwZ', 'tmfsFtblCZ', 'XRUsvoBZb5', 'UlqIXvQLxr', 'BQ1oHbkoq0', 'wA3TCR3K6e', 's9vsuB4F9D', '6eUBMbZLVS', 'Y0MH0GtDbW', 'aVxayq8cR5', '3DWCAU8WWo', 'LIukOmtV9a', 'PVmODjV6Oq', 'dc4nwgkOla', '1Y2PjjYXpf', 'eHzdhn7KK1', 'TVTUWTfMaW', 'q7CrCugL7N', 't1e3nASdUQ', 'Yw3M26GUca', '14kCLrsSYm', 'fkllHOUKAA', 'GMw6eKnkWr', 'MiCR7MdVcc', 'QZ4cLatDLm', 'ucbf5nvRUI', 'qW8pOjjfej', 'DZgkPqnwjJ', 'PNvEjfszQi', 'anQZ8ezkn2', 'ZHYr3uQVps', '5QEFyASDa4', 'LGLbgeHe7s', 'dxIx90Ggg1', '6vc5JAeybE', 'BuxATTjUUX', 'dsN9iHYL4f', 'S65nv4zyFI', 'm31rmBWgBM', 'kGdLYoNv4Y', 'nUPsUOnodY', 'riGNGhFrWx', 'I3ulhacnvJ', 'nlbXXMokrL', 'Uw4w31DAO5', '0DjH9TWq0A', 'SSxqdTfgx6', 'm02mehmGkB', 'arEDuA830n', 'Nx3YXOYC9q', 'Pj5wmH5bgo', 'CCgO9EbcjS', 'zseNo2xuRn', 'CjpG7d77R9', 'C4h2sekkFY', 'sVZMGxNHPu', 'H8CvcTVHYo', '0KgIbXgWGF', 'NhW8q3VTUg', '9FTYFvHTk8', 'ppBCQfAXbh', 'IznWzCTQmv', '9MoWHppKTR', '7wRdXjUGBz', 'ayowcvs9Uz', 'H5xml0S5mP', 'dDfkvG5ed0', 'adZRLOjV2o', 'rzRDoCx9CQ', 'AK9lSemA1q', 'HN3Xu6SHd4', 'nsdXZqyWhm', 'Xckz6ufJBq', 'wEwR9gHSNb', 'mfakcda7Qo', 'SpGeo6Le0d', 'TIx4mW067e', 'GXZuESyDgJ', 'lkgDQqdge7', 'MNp46a8xkD', 'iMR5uxUkCe', 'F1O3PDayeM', 'A7gCkR1SAA', 'acZOv58pfw', 'pmBYg0dGON', 'JWptJOAWXt', '14iFJIlnhY', 'Ji6Nni30lv', 'SvGtdYraqN', 'Zbno5zxBNH', 'es3cVeb38Y', 'ZP0T1CLIxl', 'N2xj4ef4LX', 'Xf42YEDDry', '8nhaWQdFDR', '6soPKdIDv5', 'lbILRdyfyQ', '59cLnREZ9h', 'UAPC0a620A', 'vc95GCIMEL', 'XUNX1sWPrS', 'NanJw8ip2W', 'Mzw8DFpKxe', 'r4ylOQbKbF', '1bc51s4tsI', 'yDZwwSx8u2', 'MXUrzyavKS', 'ig9hSzwd9q', '9fu836cNJO', 'iJV8WPJvBS', 'O4nHM9ZhTB', 'fmfrvO9u8h', 'LgV1093nKK', 'KvxlMKV5XR', '5M2Sw740xE', 'ahh8I46Ylv', '4KSzAztdqJ', 'x2ZMzrmgqR', 'ijnLj21mHD', '6CIgVsZzRy', 'yZwpx4oE6H', 'o4CqYU9JsF', '33WhqPLyiW', 'ICivNni6Ew', 'sDGVJcUBY2', 'q7FIjLiKUi', '1v4c1qETwW', '4MBZK40ksI', 'ILU2IaPLkK', 'y6ED7cNnfl', '7ea0ejaCcY', 'AaZIcfAbsd', 'kPKTsN5Vls', 'Hts4DQ1vAj', 'Z5oC8WTFcV', 'HNTouiMGLO', 'lbl182wi5d', 'lG9RuKTgb8', 'QEcO3cCj99', 'bqfM4lwRSg', 'EV3ALXM3wj', 'oG4140DHIU', 'wROSEtVlKE', 'mslUd0LAzp', 'LZNhVyO50Q', 'B9FVz5250N', 'x4BYZyX2gn', 'ssTMrFmqIo', 'fqZLTIJKY8', 'kbbgJvjMj2', 'a7ydOY7Ozf', 'zsNVZ5SgUn', 'A55be6RyJw', '0c9fWq8tZr', '054Y1Ev4lQ', 'HVImXuVoIS', 'DyKK27Czqr', 'vFYryFhJN8', '3Mv6omqmiL', 'REXT7cV4v7', 'ZJTsxAhltr', 'WUr2GuCThW', 'vc1Pt015HS', 'pZ0i53y8ij', 'Aeore1OTPh', 'qArHfJLevg', 'YSZbMLYsdZ', '3nkRDirD1H', '8wJA6JmeMz', 'ELOCUhVNZI', 'UkwW1e3dRG', 'wkmiNX7GLu', 'tgTp44jgdk', '4NaP50fRuV', 'D9rWmSXxMG', '5RfurFTIAX', 'AkegjCFFvs', 'Xx9L2Y8hxk', 'FujSDwGZx9', 'uGZESHfab9', 'UUQQ7tucEh', 'hO9bXUo3oy', 'jpBq99iwgp', 'ADIEaEfjGj', 'gRZD3P6H7U', '8CVP9hwmAT', 'aFM3mRrwTG', 'iDBM1CTE7h', 'qfLbnJLmr9', 'xldSexo69j', 'dfKHosdVzj', 'iM7u6ZM0y2', 'QGmyVBvLYL', 'udgX8yv2pL', 'duDSc7PxKG', 'maPibuE85L', '8ji0saRzQG', 'ZwYrWpE0eS', 'pCpHcdMhSn', 'VSC6opUfox', 'IOUsEHnryu', 'CsxliuqZZr', 'syPyxLd99T', 'IuY8foJNQF', 'PPmoWPcu4L', ...

# %%
uniques=list(np.unique(classifications['imageID'])) #create list of unique imageIDs
#print(np.where(id_dict.keys() == '03qNWhxN7S'))
for i in uniques: #loop to remove imageIDs with no match
    #print('03O7vKIljc' == id_dict.keys())
    if i not in list(id_dict.keys()):
        uniques.remove(i)
        
print(uniques)
# Out:
# ['00goZDyvwn', '027HEi6T8W', '02RBj3giIk', '02zQsfIXKN', '03qNWhxN7S', '04wd5cKqLP', '05Y14VvDvq', '060fMVbro9', '06Tlf7WxJ8', '07PXw7zxqA', '07j5X77abG', '097G1fXvLO', '0ALycEnWDj', '0Cmippk6vf', '0E3rWJCjps', '0EFWeogLXX', '0FEVGrzLRS', '0Fpvg6fa9M', '0GaIBrLl7J', '0L0XfnUWg9', '0OZFGbGEIq', '0PYjU3TSN1', '0R89IpOedS', '0RR71fjreU', '0RRPaWVMIk', '0Sug0tqkoL', '0VIzKFyRll', '0VWrQ6qp1z', '0VgsIcsJLL', '0VzQ4leQI7', '0WC9W84pC8', '0WRtl8CiWE', '0Y9f93YSan', '0a0am0hT1S', '0eIGky5drv', '0fQWfzF83F', '0hTIwAtvOI', '0hg1zOpyP8', '0j61amEQss', '0kdG5l4Qxk', '0keQ13ASBs', '0lqHI2AiTY', '0maW8hNlUf', '0oK1RfZHQV', '0olGQm7g5Z', '0pClklZm03', '0pcNBKp4S0', '0pmslPzWzA', '0qaqQsrv9q', '0rIe5r4hhl', '0rVk21nUNT', '0rhIOs52Hr', '0tGqwaapJF', '0wgHboRmsl', '10Yv1PqS1V', '10ZEWXGkQR', '11OOHqE1I5', '13rpXWtDir', '149mlax90f', '16LsDjE73q', '16TiI7kHXA', '17LEBedyRF', '17l14AB7e9', '18ZSja5Gdz', '1AiLeGzXE8', '1B2WkLI4Hw', '1BPvFS6Eed', '1CWfJlN8yh', '1Dj94oPL85', '1EBz7M1wrx', '1FqUECtzTK', '1GWctiTUE2', '1J04lp2Xu0', '1KY78x8zI8', '1KoKUYWvJy', '1L2F5urlGz', '1LVcttOTVi', '1LwdgNQWMR', '1MIhAQrO4Z', '1MoMiFOdh0', '1N08oYzNoy', '1PWSYMIhGE', '1S5zBRiVFw', '1SXA3Wwrvn', '1Smq5WCiWu', '1TpLn6Twz7', '1TxCkl20P4', '1ZXU126dda', '1a8qdC2C2x', '1bMBUAYfXw', '1c8v2JzAlG', '1cbwnkmh2Z', '1fqerQsNv5', '1gRLLMWtMI', '1h42aSskfN', '1hFFAvotlm', '1iLMW8c0vv', '1khq2IVJ0S', '1lDkkG6KTf', '1ls77Zbwak', '1nF4MHpyah', '1oI1bF9FCm', '1ssu6koaaz', '1vlWQkaKPz', '1wmLSpaKwr', '1wnhOP0REA', '1xvpm4mSaS', '1y5SQQCzwN', '1yXi2VLRx7', '1yd0brpe2L', '20QpYRsgh6', '20hT0wIxKU', '219kydXu4R', '21jGoQPy2Y', '21t3k5IONf', '22X8ScghR4', '23AEtPFV9w', '245fOYmmum', '26sqWN2Ri5', '28I6oKm06H', '29Af14qpDQ', '29OTpj6mQq', '2AJvn4PAKc', '2C17r3UPx6', '2CZzGH1QSK', '2D9hDC8Rjj', '2EbP83UcWY', '2FSYeBzUmL', '2HH1bKKDph', '2HlgS5CzYT', '2HwfMH797E', '2KYXWlDSEp', '2Lj779Z79P', '2NPt7xDTVg', '2NvoNbpncu', '2PlXhmGfBa', '2Q3GPnJv6C', '2QJOFhdhPz', '2QMRbwuguN', '2RgzVZvkcR', '2SxX5S2th8', '2UQd8MYExs', '2VMQWa9iXP', '2X9NYXH0lQ', '2XSZW9ezxU', '2Z1VYc6a4J', '2Z78K9M7Mx', '2ZQ4ilfdXc', '2aNi61qxIw', '2bCYF22hD3', '2bgOJFs8fU', '2buxjC5QoN', '2db7ZR3t0x', '2fBwtrNGDR', '2hD7F6aNeX', '2iZ8koO2ym', '2kqc1LN11g', '2n9NgRtU8d', '2nZN795ElE', '2oX8Sxtd9j', '2p5novAiw1', '2pIchTrYhO', '2s24E8Ztmn', '2uM7fckg05', '2vYnarMxhx', '2xoTGjUonN', '2zz5asidNu', '31DXaLi11a', '31LKoRI2uk', '32HF9rW3Vk', '33TTsNQvd6', '34VYVEyNRC', '34wOSg8qzE', '36TyWpjrhM', '36r1xSfQ4m', '37jLoYKJW6', '38Ye3SRAgO', '399JDe07SQ', '3AEw9Hdi10', '3BYePrWSjb', '3CCtI2BNyC', '3CL4oCI9AK', '3DWCAU8WWo', '3DqrArHtA8', '3EReOlkgyY', '3EmTI4u3vx', '3Ft6v4SXXU', '3H1zmaUJ03', '3Imt66gfxW', '3LL9NsHrp5', '3LgvvzCSAJ', '3LxIef2N7P', '3NDU7eAb3q', '3NhUk8tw7F', '3PVlAhTQ8r', '3SpFt2rpfo', '3U5x56jEPW', '3VeaJccSHL', '3X4zeQiK8R', '3YlvD63UHh', '3aNYwbe99n', '3aOiZdjrZ8', '3aixn3gMPc', '3aw5zcEcr8', '3b7ocZFugg', '3bSX7Af1eS', '3c8CtJ6gyG', '3dFDgqfxIa', '3dee8vycZM', '3egEVDGX18', '3gNCD4B1CG', '3gvVxd1mAw', '3h4OmRnZUm', '3i2zx4cwnO', '3iGMzi2bUV', '3ifPX69Vj1', '3nLQlAGPNI', '3oRUIeX6Yo', '3plSOb5dfa', '3qozY8UI24', '3r1mPbqwzm', '3roaBm5VHj', '3s81WYTprm', '3sOhXLkhN9', '3sYEQ2LPDE', '3uKvxafooi', '3vVBcLWUI9', '3ypEPYKO9K', '3zlAHQzn5z', '40zbzLymog', '41qDHgPb5L', '43K8zqXroN', '43oe5M7B1d', '458vNRdQX2', '46Kn7IZarU', '488ysf3bOv', '495cFzFbl8', '49QKzCgF9O', '4B9NgYhK50', '4CUbetefuZ', '4Cfrj4fqKl', '4DVgy7NDNc', '4DhDLA7zqp', '4FI1a0r5nE', '4GKeDSKbMz', '4HAnFLiDCw', '4HZuVTsZMg', '4ICxOVCxez', '4JOpQC5zWk', '4LP6UQ797T', '4NuXKUlsD0', '4ONR9cXtkf', '4OzC6XDih2', '4P4nnOcn00', '4PiGhxDTAW', '4PrXHtqlUo', '4T6Tl1xPvP', '4VwFOWmZpF', '4WrdbPHwkK', '4YCIw2Nzyt', '4YUpv5lscj', '4ZGDvYT6WG', '4Zwjix7qMZ', '4a9kxkicPu', '4cVKhYilvU', '4eB0NhGI2D', '4jTowPAo0j', '4ngwexB2JD', '4o6hTF563f', '4oNveM3PsX', '4pqIIqgiNv', '4sdjWoe7Pj', '4vSgRn4nZ8', '4x6ToBDQeu', '4xzu8DTYUj', '4y6akyO0eL', '50Ewvtyrdb', '51poC7Ig9A', '52VX8jKNNm', '53cLLdxRYI', '55A54RvdKP', '57KqSuFzLK', '58XsJNrjBo', '5AJ4zOjnSH', '5BdhxuloY6', '5BmVHrVl ...

# %%
images
# Out:
#      ML_posterior     imageID labels  truelabel type userIDs
# 0              []  00goZDyvwn     []         -1    T      []
# 1              []  02RBj3giIk     []         -1    T      []
# 2              []  03O7vKIljc     []         -1    T      []
# 3              []  04wd5cKqLP     []         -1    T      []
# 4              []  05qdhYROgx     []         -1    T      []
# 5              []  06Tlf7WxJ8     []         -1    T      []
# 6              []  07PXw7zxqA     []         -1    T      []
# 7              []  08pHp9bdqf     []         -1    T      []
# 8              []  0ALycEnWDj     []         -1    T      []
# 9              []  0Cmippk6vf     []         -1    T      []
# 10             []  0EFWeogLXX     []         -1    T      []
# 11             []  0FEVGrzLRS     []         -1    T      []
# 12             []  0GaIBrLl7J     []         -1    T      []
# 13             []  0L0XfnUWg9     []         -1    T      []
# 14             []  0OZFGbGEIq     []         -1    T      []
# 15             []  0PYjU3TSN1     []         -1    T      []
# 16             []  0R89IpOedS     []         -1    T      []
# 17             []  0RRPaWVMIk     []         -1    T      []
# 18             []  0Sug0tqkoL     []         -1    T      []
# 19             []  0VIzKFyRll     []         -1    T      []
# 20             []  0VWrQ6qp1z     []         -1    T      []
# 21             []  0VzQ4leQI7     []         -1    T      []
# 22             []  0WQobloijx     []         -1    T      []
# 23             []  0WzSMDFdZR     []         -1    T      []
# 24             []  0a0am0hT1S     []         -1    T      []
# 25             []  0fQWfzF83F     []         -1    T      []
# 26             []  0hTIwAtvOI     []         -1    T      []
# 27             []  0ilm5ybmll     []         -1    T      []
# 28             []  0k8l8LlhG6     []         -1    T      []
# 29             []  0keQ13ASBs     []         -1    T      []
# ...           ...         ...    ...        ...  ...     ...
# 2700           []  zP8dogXdwz     []         -1    T      []
# 2701           []  zQVROUGuRa     []         -1    T      []
# 2702           []  zQi8aTBjYx     []         -1    T      []
# 2703           []  zQvSgIxF3A     []         -1    T      []
# 2704           []  zRkPrLH8sZ     []         -1    T      []
# 2705           []  zStQTYUnZT     []         -1    T      []
# 2706           []  zTznD4fh3s     []         -1    T      []
# 2707           []  zWPvoQ1vgr     []         -1    T      []
# 2708           []  zWuXkP7QZe     []         -1    T      []
# 2709           []  zXSRTtIAMI     []         -1    T      []
# 2710           []  zYiMqHwnFf     []         -1    T      []
# 2711           []  zZDnaqEpLJ     []         -1    T      []
# 2712           []  zZSt8p3Eon     []         -1    T      []
# 2713           []  zaKr8yemnk     []         -1    T      []
# 2714           []  zaz8GbINGt     []         -1    T      []
# 2715           []  zcoiutpl8Z     []         -1    T      []
# 2716           []  zcyLSJ19an     []         -1    T      []
# 2717           []  zeL0LPBRka     []         -1    T      []
# 2718           []  zf5W7WtjhR     []         -1    T      []
# 2719           []  ziLuh1ReYd     []         -1    T      []
# 2720           []  zjUolCJR1x     []         -1    T      []
# 2721           []  zjaAgGBdgV     []         -1    T      []
# 2722           []  zkfi6xvKLz     []         -1    T      []
# 2723           []  zoQgUKRbxR     []         -1    T      []
# 2724           []  zpZq0UhUY6     []         -1    T      []
# 2725           []  zrikbtgjMK     []         -1    T      []
# 2726           []  zu6k6GNbcV     []         -1    T      []
# 2727           []  zwPIvpTO0V     []         -1    T      []
# 2728           []  zy9kPFsEsD     []         -1    T      []
# 2729           []  zzgFBWqnHb     []         -1    T      []
#
# [2730 rows x 6 columns]

# %%
#function to create lists of empty lists
def emptylist(x):
    elist = []
    for i in range(x):
        elist.append([])
    return elist

# %%
images = pd.DataFrame({'type':['T']*len(uniques),'labels':emptylist(len(uniques)),
                        'userIDs':emptylist(len(uniques)),'ML_posterior':emptylist(len(uniques)),
                        'truelabel':[-1]*len(uniques),'imageID':uniques})

# %%
#create dataframe, length of uniques, without labels or userIDs
images = pd.DataFrame({'type':['T']*len(uniques),'labels':emptylist(len(uniques)),
                        'userIDs':emptylist(len(uniques)),'ML_posterior':emptylist(len(uniques)),
                        'truelabel':[-1]*len(uniques),'imageID':uniques})

for unique_id in uniques: #iterate over unique imageIDs
    
    for locations in np.where((unique_id == classifications['imageID'])): #iterate over arrays of where unique imageID appears
        
        images_idx = np.where(unique_id == images['imageID'])[0][0] #find index of line in images where unique imageID appears
        
        for location in locations: #iterate over elements in array of locations in classifications where unique imageID appears
            
            images['labels'][images_idx].append(classifications.loc[[location],'label']) #append label
            images['userIDs'][images_idx].append(int(classifications.loc[[location],'userID'])) #append userID
            
            #classifications_line = classifications.loc[[location]]
            #images.loc[[images_idx],'labels',].append(classifications.loc[[location],'label'])
            #images.loc[[images_idx],'userIDs',].append(classifications.loc[[location],'userID'])
            
for imageID in images['imageID']:
    print(imageID)
    imageID = id_dict[imageID]
# Out:
# 00goZDyvwn
# 02RBj3giIk
# 03O7vKIljc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-359-06e857bb25c6> in <module>()
#      21 for imageID in images['imageID']:
#      22     print(imageID)
# ---> 23     imageID = id_dict[imageID]
#
# KeyError: '03O7vKIljc'

# %%
images = pd.DataFrame(np.zeros((len(uniques)columns=['type','labels','userIDs','ML_posterior','truelabel','imageID']) #create blank dataframe


for i in classifications: #iterate over classifications
    
    if not(i[6] == images['imageID'].any()): #if imageID is unique
        
        try: #to catch errors from not having userID
            
            line = pd.DataFrame([{'type':'T','labels':i[4],'userIDs':int(i[1]),'ML_posterior':[],'truelabel':-1,'imageID':i[6]}])
            #create line with proper values
            images = images.append(line,ignore_index=True) #append line to images dataframe
       
        except:
            
            pass
    
    else: #if imageID already exists in dataframe
        
        ix = images[images['imageID']==i[6]] #get index of row with corresponding imageID
        
        print(ix)
# Out:
#   File "<ipython-input-128-136e852c82a2>", line 2
#     print images
#                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print(len(np.unique(images['imageID'])))
# Out:
# 5460

# %%
print(images)
# Out:
#       ML_posterior     imageID          labels  truelabel type  userIDs
# 0               []  gd5ovM759R             BLP         -1    T   796717
# 1               []  7cZKPcHEY6             BLP         -1    T   796717
# 2               []  RvN3cptPEr       PWRLN60HZ         -1    T   796717
# 3               []  dUjd6wI7A7            KFSH         -1    T   796717
# 4               []  yBgD8GkFQV             BLP         -1    T   796717
# 5               []  8S7iCnCoEt             BLP         -1    T   796717
# 6               []  noDH1uFsHt             BLP         -1    T      123
# 7               []  zcv28lNmT4             BLP         -1    T      123
# 8               []  4Pbsza2PMU             BLP         -1    T      123
# 9               []  PCfcu7enPj            KFSH         -1    T      123
# 10              []  UrbMmvCAsu       PWRLN60HZ         -1    T      123
# 11              []  LUZjQW6GWU            KFSH         -1    T      123
# 12              []  bOug8xBctE            KFSH         -1    T      123
# 13              []  yHDVjGwiuV             BLP         -1    T      123
# 14              []  v8L7B9dQ0Y             BLP         -1    T      123
# 15              []  buHDMm2CTN             BLP         -1    T      123
# 16              []  R9ymFT9uoA       PWRLN60HZ         -1    T     4284
# 17              []  fRoPkFs3x0             BLP         -1    T     4284
# 18              []  pHYHa7ljsH          SCRTCH         -1    T     4284
# 19              []  0WzSMDFdZR  45MHZLGHTMDLTN         -1    T     4284
# 20              []  j2xetMMqag  45MHZLGHTMDLTN         -1    T     4284
# 21              []  ouVpdQVNDl         XTRMLLD         -1    T     4284
# 22              []  DrgJ06uE6U            KFSH         -1    T     4284
# 23              []  CtlgK7xjcJ            KFSH         -1    T     4284
# 24              []  7r2baEJH2n            KFSH         -1    T     4284
# 25              []  zWyPYTrOkc            KFSH         -1    T     4284
# 26              []  U0BNebjVF8             BLP         -1    T     4284
# 27              []  bkB9qm4aI2             BLP         -1    T     4284
# 28              []  w2db3RDWGS       PWRLN60HZ         -1    T     4284
# 29              []  ih9XuwKQ7Z       PWRLN60HZ         -1    T     4284
# ...            ...         ...             ...        ...  ...      ...
# 15059           []  lSt7URga3N             TMT         -1    T       82
# 15060           []  6ct3spNbQc     LWFRQNCBRST         -1    T       82
# 15061           []  TxIYLSSF2m     LWFRQNCBRST         -1    T       82
# 15062           []  W2J3BlDUbS            50HZ         -1    T       82
# 15063           []  YW8YilC0GD       PWRLN60HZ         -1    T       82
# 15064           []  reXCm2WM9L     LWFRQNCBRST         -1    T       82
# 15065           []  XCBuFsHkVE       LWFRQNCLN         -1    T       82
# 15066           []  IKV0EyYOMi             BLP         -1    T       82
# 15067           []  qnkjwEKzep       LWFRQNCLN         -1    T       82
# 15068           []  TCCK87W8ot         NNFTHBV         -1    T       82
# 15069           []  1N08oYzNoy             BLP         -1    T       82
# 15070           []  pcVmfFzp4z     LWFRQNCBRST         -1    T       82
# 15071           []  RjkRT44YNE          NGLTCH         -1    T     5209
# 15072           []  rr7Xr5oUdk            KFSH         -1    T  1500454
# 15073           []  xqvqwD3VPr       PWRLN60HZ         -1    T  1500454
# 15074           []  AAGbIxuAt6             BLP         -1    T  1500454
# 15075           []  PQ8A98YCxW       PWRLN60HZ         -1    T  1500454
# 15076           []  lE2NfUNTlU             BLP         -1    T  1500454
# 15077           []  IIH4yWsm1M         XTRMLLD         -1    T     5209
# 15078           []  3oRUIeX6Yo             BLP         -1    T  1500454
# 15079           []  hXtk5iBDjl       PWRLN60HZ         -1    T  1500454
# 15080           []  zQ2phPnpfe          NGLTCH         -1    T   796717
# 15081           []  j0xgPFl0E3          NGLTCH         -1    T   796717
# 15082           []  XBN6g4EMa2         XTRMLLD         -1    T     5209
# 15083           []  ZjmfidyDgt            KFSH         -1    T  1500454
# 15084           []  YraWMIbey9             BLP         -1    T  1500454
# 15085           []  yY4KpfCQIw       LWFRQNCLN         -1    T     2274
# 15086           []  NUN2yhpvPg     LWFRQNCBRST         -1    T     2274
# 15087           []  i7kFSq3b2u             HLX         -1    T     2274
# 15088           []  Nxu3wus6DO     LWFRQNCBRST         -1    T     5209
#
# [15089 rows x 6 columns]
