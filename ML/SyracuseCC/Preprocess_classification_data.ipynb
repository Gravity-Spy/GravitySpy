# %% [markdown]
# # Preprocess human classification data downloaded from Zooniverse

# %%
# %matplotlib inline
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## The human classification data

# %% [markdown]
# Two of the more important columns in the exported data are in JSON format: the subject and the annotations. So, some simple scripts to extract the relevant data. Unfortunately, the JSON seems to have changed over time, so the functions have to be flexible.

# %%
def ID_from_subject_data(subject_data):
    # given a string of JSON representing the subject data, extract and return the ID
    sd = json.loads(subject_data)
    sd1 = list(sd.values())[0]
    sd1k = sd1.keys()
    if 'ID' in sd1k:
        # easiest case: there's a subject ID in the JSON
        v = sd1['ID']
    elif 'Filename1' in sd1k:
        # otherwise, we can get it from the filename (I hope)
        v = sd1['Filename1'][3:13]
    else:
        # about 28 case where the subject data are in some weird format that this doesn't catch, which we ignore
        v = ''
        
    return v

# %%
# an example
ID_from_subject_data(classification_data['subject_data'][40000])
# Out:
# 'BMOSh2lK88'

# %% [markdown]
# _need to check that this is really working reliably given the number of observations that don't connect_

# %%
def user_choice_from_annotations(annotations):
    # given a string of JSON representing the annotation, extract and return the user's annotation
    a = json.loads(annotations)

    # not all users actually recorded a choice
    try:
        v = a[0]['value'][0]['choice']
    except (IndexError, KeyError): 
        # volunteer apparently didn't pick anything 
        v = ''
    
    return v

# %%
# example
user_choice_from_annotations(classification_data['annotations'][2])
# Out:
# '60HZPWRMNS'

# %% [markdown]
# ## Read data downloaded from Zooniverse

# %%
classification_data = pd.read_csv('160626 gravity-spy-classifications.csv',parse_dates=[7,],infer_datetime_format=True)

# %%
len(classification_data)
# Out:
# 51363

# %% [markdown]
# ## Add new columns to the data frame with the extracted data.

# %%
classification_data['subject_ID'] = classification_data['subject_data'].map(ID_from_subject_data)

# %%
classification_data['annotation'] = classification_data['annotations'].map(user_choice_from_annotations)

# %% [markdown]
# The uncaught cases.

# %%
classification_data[classification_data.subject_ID == '']
# Out:
#        classification_id  user_name    user_id               user_ip  \
# 9               10295716    mzevin1   796717.0  eb63336142b3fbe405a2
# 10              10296637    mzevin1   796717.0  eb63336142b3fbe405a2
# 11              10296695    mzevin1   796717.0  eb63336142b3fbe405a2
# 12              10297006     sbc538   386563.0  7c5f17b05d4804969561
# 13              10300327   crowston   336603.0  6084cdabaff2399fa800
# 14              10300333   crowston   336603.0  6084cdabaff2399fa800
# 15              10300339   crowston   336603.0  6084cdabaff2399fa800
# 16              10342622    mzevin1   796717.0  6c2a9dc19b43f157ea04
# 17              10342630    mzevin1   796717.0  6c2a9dc19b43f157ea04
# 18              10342635    mzevin1   796717.0  6c2a9dc19b43f157ea04
# 19              10342637    mzevin1   796717.0  6c2a9dc19b43f157ea04
# 20              10450661     sbc538   386563.0  57c8ca7d01b683697121
# 21              10465624    mzevin1   796717.0  48fabcdbb53bd0aabdc2
# 22              10465628    mzevin1   796717.0  48fabcdbb53bd0aabdc2
# 23              10481232    mzevin1   796717.0  f5609c0a6d17f8477430
# 24              10552370     sbc538   386563.0  d79e2d875735f40b3c10
# 25              10561376     sbc538   386563.0  d8004f73bc74eba65ffd
# 26              10562354   cavaglia  1455699.0  d8004f73bc74eba65ffd
# 27              10563078        ecm  1455689.0  d8004f73bc74eba65ffd
# 28              10563093        ecm  1455689.0  d8004f73bc74eba65ffd
# 29              10563129        ecm  1455689.0  d8004f73bc74eba65ffd
# 30              10563143        ecm  1455689.0  d8004f73bc74eba65ffd
# 31              10580306       hm99     2156.0  d8004f73bc74eba65ffd
# 32              10764932     sbc538   386563.0  1e4e939aa6254bbfc188
# 33              10875254  Jrsmith02   622741.0  51924ea0b5dc04d71056
# 34              10875321  Jrsmith02   622741.0  51924ea0b5dc04d71056
# 35              10875413  Jrsmith02   622741.0  51924ea0b5dc04d71056
# 20611           11740219   trouille   408711.0  9b54726d26a3eee95858
#
#        workflow_id                                      workflow_name  \
# 9             1479  Apprentice - Jump in here for advanced Glitch ...
# 10            1479  Apprentice - Jump in here for advanced Glitch ...
# 11            1479  Apprentice - Jump in here for advanced Glitch ...
# 12            1479  Apprentice - Jump in here for advanced Glitch ...
# 13            1479  Apprentice - Jump in here for advanced Glitch ...
# 14            1479  Apprentice - Jump in here for advanced Glitch ...
# 15            1479  Apprentice - Jump in here for advanced Glitch ...
# 16            1479  Apprentice - Jump in here for advanced Glitch ...
# 17            1479  Apprentice - Jump in here for advanced Glitch ...
# 18            1479  Apprentice - Jump in here for advanced Glitch ...
# 19            1479  Apprentice - Jump in here for advanced Glitch ...
# 20            1479  Apprentice - Jump in here for advanced Glitch ...
# 21            1479  Apprentice - Jump in here for advanced Glitch ...
# 22            1479  Apprentice - Jump in here for advanced Glitch ...
# 23            1610                                         Beginner 1
# 24            1479  Apprentice - Jump in here for advanced Glitch ...
# 25            1479  Apprentice - Jump in here for advanced Glitch ...
# 26            1610                                         Beginner 1
# 27            1479  Apprentice - Jump in here for advanced Glitch ...
# 28            1479  Apprentice - Jump in here for advanced Glitch ...
# 29            1479  Apprentice - Jump in here for advanced Glitch ...
# 30            1479  Apprentice - Jump in here for advanced Glitch ...
# 31            1479  Apprentice - Jump in here for advanced Glitch ...
# 32            1479  Apprentice - Jump in here for advanced Glitch ...
# 33            1479  Apprentice - Jump in here for advanced Glitch ...
# 34            1479  Apprentice - Jump in here for advanced Glitch ...
# 35            1479  Apprentice - Jump in here for advanced Glitch ...
# 20611         1610                                         Beginner 1
#
#        workflow_version          created_at  gold_standard  expert  \
# 9                 77.36 2016-03-04 16:40:18            NaN     NaN
# 10                77.36 2016-03-04 17:06:20            NaN     NaN
# 11                77.36 2016-03-04 17:07:57            NaN     NaN
# 12                77.36 2016-03-04 17:13:56            NaN     NaN
# 13                77.36 2016-03-04 19:08:00            NaN     NaN
# 14                77.36 2016-03-04 19:08:23            NaN     NaN
# 15                77.36 2016-03-04 19:08:45            NaN     NaN
# 16                77.36 2016-03-06 18:56:05            NaN     NaN
# 17                77.36 2016-03-06 18:56:25            NaN     NaN
# 18                77.36 2016-03-06 18:56:42            NaN     NaN
# 19                77.36 2016-03-06 18:56:49            NaN     NaN
# 20               147.42 2016-03-10 22:25:15            NaN     NaN
# 21               147.42 2016-03-11 16:35:05            NaN     NaN
# 22               148.42 2016-03-11 16:35:15            NaN     NaN
# 23                95.60 2016-03-11 23:21:27            NaN     NaN
# 24               186.49 2016-03-15 14:47:28            NaN     NaN
# 25               186.49 2016-03-15 22:19:08            NaN     NaN
# 26                95.60 2016-03-15 23:50:54            NaN     NaN
# 27               186.49 2016-03-16 00:44:38            NaN     NaN
# 28               186.49 2016-03-16 00:45:01            NaN     NaN
# 29               186.49 2016-03-16 00:45:56            NaN     NaN
# 30               186.49 2016-03-16 00:46:34            NaN     NaN
# 31               186.49 2016-03-16 22:11:40            NaN     NaN
# 32               186.49 2016-03-23 15:59:02            NaN     NaN
# 33               186.49 2016-03-29 15:50:43            NaN     NaN
# 34               186.49 2016-03-29 15:51:46            NaN     NaN
# 35               186.49 2016-03-29 15:52:44            NaN     NaN
# 20611             95.60 2016-04-27 03:12:16            NaN     NaN
#
#                                                 metadata  \
# 9      {"session":"65e4559affff1d4e2f0592b12c50a37aaf...
# 10     {"session":"65e4559affff1d4e2f0592b12c50a37aaf...
# 11     {"session":"d7610273636c2f3b10e72e803f719e11b3...
# 12     {"session":"bc89d79827eaa6352a0d07afd2d0d8f52c...
# 13     {"session":"8f4f780411ec563e0f42a271272c8b1209...
# 14     {"session":"8f4f780411ec563e0f42a271272c8b1209...
# 15     {"session":"8f4f780411ec563e0f42a271272c8b1209...
# 16     {"session":"9c44968912498ed3665e738ffc40467159...
# 17     {"session":"9c44968912498ed3665e738ffc40467159...
# 18     {"session":"9c44968912498ed3665e738ffc40467159...
# 19     {"session":"9c44968912498ed3665e738ffc40467159...
# 20     {"session":"36fe4083a58664686107474534e0616171...
# 21     {"session":"74a4e84bea7ae917dff3c88ebce50bff9a...
# 22     {"session":"74a4e84bea7ae917dff3c88ebce50bff9a...
# 23     {"session":"9c4f7a348d3aa4751747cb65f259abf397...
# 24     {"session":"cfddbe88797eb781b338dd67a9a3a3b4d3...
# 25     {"session":"af30be4f1f913a65ac225f996fdfcd0a24...
# 26     {"session":"5de310f91edf11529a02d44ca23b575f3c...
# 27     {"session":"f70c5077f236874329cf94582f1c08599f...
# 28     {"session":"f70c5077f236874329cf94582f1c08599f...
# 29     {"session":"f70c5077f236874329cf94582f1c08599f...
# 30     {"session":"f70c5077f236874329cf94582f1c08599f...
# 31     {"session":"8d4e67a0b5f9e0bfabcd7b3e67e3fdfb57...
# 32     {"session":"cc3571b038a0c8ccaa6f68c20cff57abc5...
# 33     {"session":"1b563cf900b300cb3ff0fd799faa0cfdb5...
# 34     {"session":"1b563cf900b300cb3ff0fd799faa0cfdb5...
# 35     {"session":"1b563cf900b300cb3ff0fd799faa0cfdb5...
# 20611  {"session":"5a3bae06313dac1fd13f2ada1b31b636fb...
#
#                                              annotations  \
# 9      [{"task":"T1","value":[{"choice":"NNFTHBV","an...
# 10     [{"task":"T1","value":[{"choice":"XTRMLLD","an...
# 11     [{"task":"T1","value":[{"choice":"NNFTHBV","an...
# 12     [{"task":"T1","value":[{"choice":"BLP","answer...
# 13     [{"task":"T1","value":[{"choice":"KFSH","answe...
# 14     [{"task":"T1","value":[{"choice":"NNFTHBV","an...
# 15     [{"task":"T1","value":[{"choice":"60HZPWRMNS",...
# 16     [{"task":"T1","value":[{"choice":"60HZPWRMNS",...
# 17                            [{"task":"T1","value":[]}]
# 18     [{"task":"T1","value":[{"choice":"SCTTRDLGHT",...
# 19     [{"task":"T1","value":[{"choice":"NNFTHBV","an...
# 20     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 21     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 22     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 23     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 24     [{"task":"T1","value":[{"choice":"KFSH","answe...
# 25     [{"task":"T1","value":[{"choice":"KFSH","answe...
# 26     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 27     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 28     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 29     [{"task":"T1","value":[{"choice":"KFSH","answe...
# 30     [{"task":"T1","value":[{"choice":"60HZPWRLN","...
# 31     [{"task":"T1","value":[{"choice":"BLP","answer...
# 32     [{"task":"T1","value":[{"choice":"DNTSGLTCH","...
# 33     [{"task":"T1","value":[{"choice":"WHSTL","answ...
# 34     [{"task":"T1","value":[{"choice":"NNFTHBV","an...
# 35     [{"task":"T1","value":[{"choice":"DNTSGLTCH","...
# 20611  [{"task":"T1","value":[{"choice":"BLP","answer...
#
#                                             subject_data  \
# 9      {"1688528":{"retired":null,"1":34,"20160302":2...
# 10     {"1688148":{"retired":null,"1":20,"20160302":2...
# 11     {"1688086":{"retired":null,"1":136,"20160302":...
# 12     {"1688085":{"retired":null,"1":135,"20160302":...
# 13     {"1687896":{"retired":null,"1":3,"20160302":20...
# 14     {"1688376":{"retired":null,"1":13,"20160302":2...
# 15     {"1689006":{"retired":null,"1":239,"20160302":...
# 16     {"1689037":{"retired":null,"1":270,"20160302":...
# 17     {"1688289":{"retired":null,"1":227,"20160302":...
# 18     {"1688981":{"retired":null,"1":135,"20160302":...
# 19     {"1690522":{"retired":null,"1":12,"20160302":2...
# 20     {"1692933":{"retired":null,"1":569,"20160302":...
# 21     {"1692749":{"retired":null,"1":385,"20160302":...
# 22     {"1692811":{"retired":null,"1":447,"20160302":...
# 23     {"1692858":{"retired":null,"1":494,"20160302":...
# 24     {"1688207":{"retired":null,"1":7,"20160302":20...
# 25     {"1688309":{"retired":null,"1":44,"20160302":2...
# 26     {"1692826":{"retired":null,"1":462,"20160302":...
# 27     {"1692698":{"retired":null,"1":334,"20160302":...
# 28     {"1692633":{"retired":null,"1":269,"20160302":...
# 29     {"1688454":{"retired":null,"1":64,"20160302":2...
# 30     {"1688751":{"retired":null,"1":123,"20160302":...
# 31     {"1688045":{"retired":null,"1":95,"20160302":2...
# 32     {"1692934":{"retired":null,"1":570,"20160302":...
# 33     {"1692634":{"retired":null,"1":270,"20160302":...
# 34     {"1688011":{"retired":null,"1":45,"20160302":2...
# 35     {"1688860":{"retired":null,"1":160,"20160302":...
# 20611  {"1692922":{"retired":null,"1":558,"20160302":...
#
#                    subject_ids subject_ID  annotation
# 9      1688528;1688528;1688528                NNFTHBV
# 10     1688148;1688148;1688148                XTRMLLD
# 11     1688086;1688086;1688086                NNFTHBV
# 12     1688085;1688085;1688085                    BLP
# 13     1687896;1687896;1687896                   KFSH
# 14     1688376;1688376;1688376                NNFTHBV
# 15     1689006;1689006;1689006             60HZPWRMNS
# 16     1689037;1689037;1689037             60HZPWRMNS
# 17     1688289;1688289;1688289
# 18     1688981;1688981;1688981             SCTTRDLGHT
# 19     1690522;1690522;1690522                NNFTHBV
# 20     1692933;1692933;1692933                  WHSTL
# 21     1692749;1692749;1692749                  WHSTL
# 22     1692811;1692811;1692811                  WHSTL
# 23     1692858;1692858;1692858                  WHSTL
# 24     1688207;1688207;1688207                   KFSH
# 25     1688309;1688309;1688309                   KFSH
# 26     1692826;1692826;1692826                  WHSTL
# 27     1692698;1692698;1692698                  WHSTL
# 28     1692633;1692633;1692633                  WHSTL
# 29     1688454;1688454;1688454                   KFSH
# 30     1688751;1688751;1688751              60HZPWRLN
# 31     1688045;1688045;1688045                    BLP
# 32     1692934;1692934;1692934              DNTSGLTCH
# 33     1692634;1692634;1692634                  WHSTL
# 34     1688011;1688011;1688011                NNFTHBV
# 35     1688860;1688860;1688860              DNTSGLTCH
# 20611  1692922;1692922;1692922                    BLP

# %% [markdown]
# ## A few sample statistics...

# %%
classification_by_user = classification_data.groupby('user_name').count()

# %%
classification_by_user['user_ip'].median()
# Out:
# 5.0

# %%
classification_data.groupby('annotation').count()['classification_id']
# Out:
# annotation
#                      103
# 45MHZLGHTMDLTN       458
# 50HZ                 195
# 60HZPWRLN              1
# 60HZPWRMNS             3
# BLP                12715
# CHRP                 655
# CLBRTNLN300HZ        386
# DNTSGLTCH           9897
# HLX                   54
# HRMNCS                 1
# KFSH                2856
# LGHTMDLTN             24
# LWFRQNCBRST         6154
# LWFRQNCLN           2300
# NGLTCH              1670
# NNFTHBV             4658
# PRDDVS               139
# PWRLN60HZ           3593
# RCMPRSSR50HZ          21
# RPTNGBLPS            214
# SCRTCH              1356
# SCTTRDLGHT          1810
# TMT                  318
# VLNHRMNC500HZ        192
# VLNMDHRMNC500HZ       36
# WHSTL                731
# WNDRNGLN             363
# XTRMLLD              460
# Name: classification_id, dtype: int64

# %% [markdown]
# ## Glitch classes
# The coding for the classes is different in the ML and Human classification, so a file to translate between them. Also, there are multiple codes for the same glitch class in the human file, so some lines have repeats. I marked a preferred code in case we ever want to move from the ML data to the code in Gravity Spy. Note that pandas can't handle an NA in an integer column, which is why Model_number is a float.

# %%
glitch_classes = pd.read_csv('glitch-classes.csv')

# %%
glitch_classes
# Out:
#     MLID                              Name            HCID  Preferred  \
# 0      1            45Mhz_Light_Modulation  45MHZLGHTMDLTN          1
# 1      1            45Mhz_Light_Modulation       LGHTMDLTN          0
# 2      2                             50_Hz            50HZ          1
# 3      2                             50_Hz    RCMPRSSR50HZ          0
# 4      3                              Blip             BLP          1
# 5      4                              Blob             NaN          1
# 6      5                             Chirp            CHRP          1
# 7      6                    Extremely_Loud         XTRMLLD          1
# 8      7                             Helix             HLX          1
# 9      8                          Koi_Fish            KFSH          1
# 10     9               Low_Frequency_Burst     LWFRQNCBRST          1
# 11    10               Low_Frequency_Lines       LWFRQNCLN          1
# 12    10  Low_Frequency_Noise_Fluctuations       LWFRQNCLN          1
# 13    11                         No_Glitch          NGLTCH          0
# 14    11                         No_Glitch       DNTSGLTCH          1
# 15    12                 None_of_the_Above         NNFTHBV          1
# 16    13                      Paired_Doves          PRDDVS          1
# 17    14                        Power_Line       60HZPWRLN          0
# 18    14                        Power_Line      60HZPWRMNS          0
# 19    14                        Power_Line       PWRLN60HZ          1
# 20    15                   Repeating_Blips       RPTNGBLPS          1
# 21    16                   Scattered_Light      SCTTRDLGHT          1
# 22    17                          Scratchy          SCRTCH          1
# 23    18                             Tomte             TMT          1
# 24    19                       Violin_Mode   VLNHRMNC500HZ          1
# 25    19                       Violin_Mode          HRMNCS          0
# 26    20                    Wandering_Line        WNDRNGLN          1
# 27    21                           Whistle           WHSTL          1
# 28    -1            Calibration_Line_300Hz   CLBRTNLN300HZ          1
#
#     Model_number
# 0            6.0
# 1            6.0
# 2           17.0
# 3           17.0
# 4            2.0
# 5            NaN
# 6            NaN
# 7           10.0
# 8           14.0
# 9            4.0
# 10           7.0
# 11           3.0
# 12           3.0
# 13          16.0
# 14          16.0
# 15           NaN
# 16          21.0
# 17          13.0
# 18          13.0
# 19          13.0
# 20          18.0
# 21           8.0
# 22           1.0
# 23           NaN
# 24           9.0
# 25           9.0
# 26          20.0
# 27           5.0
# 28          -1.0

# %% [markdown]
# Example use: make the mean confidences more readable

# %%
mean_scores = ML_data.loc[:,['label','confidence']].groupby('label').agg([np.mean,len])
mean_scores['MLID'] = mean_scores.index
mean_scores = pd.merge(mean_scores, glitch_classes[glitch_classes.Preferred==1], on='MLID')
mean_scores
# Out:
#     MLID  (confidence, mean)  (confidence, len)  (MLID, )  \
# 0      1            0.464230               39.0         1
# 1      2            0.355556               14.0         2
# 2      3            0.659265            11098.0         3
# 3      6            0.873134             2630.0         6
# 4      7            0.317086              689.0         7
# 5      8            0.413845               75.0         8
# 6      9            0.508804               58.0         9
# 7     10            0.294796               25.0        10
# 8     10            0.294796               25.0        10
# 9     11            0.571973            33206.0        11
# 10    13            0.511657               70.0        13
# 11    14            0.383636               18.0        14
# 12    15            0.352976              430.0        15
# 13    16            0.399760              153.0        16
# 14    17            0.359556              190.0        17
# 15    19            0.319048               20.0        19
# 16    20            0.433194               53.0        20
# 17    21            0.422926              182.0        21
#
#                                 Name            HCID  Preferred  Model_number
# 0             45Mhz_Light_Modulation  45MHZLGHTMDLTN          1           6.0
# 1                              50_Hz            50HZ          1          17.0
# 2                               Blip             BLP          1           2.0
# 3                     Extremely_Loud         XTRMLLD          1          10.0
# 4                              Helix             HLX          1          14.0
# 5                           Koi_Fish            KFSH          1           4.0
# 6                Low_Frequency_Burst     LWFRQNCBRST          1           7.0
# 7                Low_Frequency_Lines       LWFRQNCLN          1           3.0
# 8   Low_Frequency_Noise_Fluctuations       LWFRQNCLN          1           3.0
# 9                          No_Glitch       DNTSGLTCH          1          16.0
# 10                      Paired_Doves          PRDDVS          1          21.0
# 11                        Power_Line       PWRLN60HZ          1          13.0
# 12                   Repeating_Blips       RPTNGBLPS          1          18.0
# 13                   Scattered_Light      SCTTRDLGHT          1           8.0
# 14                          Scratchy          SCRTCH          1           1.0
# 15                       Violin_Mode   VLNHRMNC500HZ          1           9.0
# 16                    Wandering_Line        WNDRNGLN          1          20.0
# 17                           Whistle           WHSTL          1           5.0

# %% [markdown]
# ## Add ML labels to classification data
# Merge the human data with the translation to the ML coding system and drop most of the columns. I chose to keep user_id instead of user_name in an attempt to make the data more private. It occurs to me that we should filter out internal users who've been debugging or doing demos, but I was assured that they all were serious. Still, the learning parameters are probably different. There are 51224 classifications in total but 27 without a subject_ID due to the problem mentioned above.

# %%
human_data_cols = ['user_id', 'subject_ID', 'created_at', 'annotation', 'workflow_id', 'workflow_version']
human_data = pd.merge(classification_data.loc[classification_data.annotation!='', human_data_cols], \
                      glitch_classes, left_on='annotation', right_on='HCID')
human_data.drop(['annotation','HCID','Preferred'], inplace=True, axis=1)

# %%
human_data.head()
# Out:
#     user_id  subject_ID          created_at  workflow_id  workflow_version  \
# 0  336603.0  HTlgwFjWZn 2016-02-02 16:10:39         1479             44.60
# 1  336603.0  6rkFgYSBKl 2016-02-02 16:21:35         1479             44.60
# 2  336603.0  IbPP81GsPI 2016-02-02 16:26:48         1479             44.60
# 3  386563.0             2016-03-04 17:13:56         1479             77.36
# 4    2156.0             2016-03-16 22:11:40         1479            186.49
#
#    MLID  Name  Model_number
# 0     3  Blip           2.0
# 1     3  Blip           2.0
# 2     3  Blip           2.0
# 3     3  Blip           2.0
# 4     3  Blip           2.0

# %%
len(human_data)
# Out:
# 53524

# %% [markdown]
# ## Save data for reuse

# %%
classifications_store = pd.HDFStore('160626 data.h5')
# classifications_store['classification_data'] = classification_data
del classifications_store['human_data']
classifications_store['human_data'] = human_data
classifications_store.close()
